# %%
# Tensorflow Keras and rest of the packages
import tensorflow as tf
import keras as keras
from tensorflow.keras import models,Model
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
import scipy

# %%
plt.rcParams.update({
    'font.size': 14,           # Tamaño base de la fuente
    'axes.labelsize': 16,      # Tamaño de las etiquetas de los ejes (xlabel, ylabel)
    'axes.titlesize': 18,      # Tamaño del título de la gráfica
    'xtick.labelsize': 14,     # Tamaño de los números de la escala X
    'ytick.labelsize': 14,     # Tamaño de los números de la escala Y
    'legend.fontsize': 14,     # Tamaño del texto de la leyenda
    'figure.titlesize': 20     # Tamaño del título general de la figura (si usas suptitle)
})

# %%
def nn_model(activation,neurons_layer,n_layers):
    input=Input(shape=(neurons_layer[0],))
    x=input
    for hidden_layer_neurons in neurons_layer[1:-1]: 
        x=Dense(hidden_layer_neurons,activation=activation)(x)
    output=Dense(neurons_layer[n_layers-1])(x)
    return input,output

# %%
@keras.saving.register_keras_serializable()#Esto hace que se pueda guardar el modelo y cargarlo sin problemas despues
class EVE_PINN(tf.keras.Model):# Esta clase va a heredar de la clase Model de Keras, lo que nos permite usar todos los metodos de la clase Model y ademas definir nuestros propios metodos
    def set_step_dx(self,dx): #Este metodo inicializa la clase
        self.dx=dx #Lo que hace esto es que al objeto que luego instanciamos le asigna el atributo dx, que va a ser espaciado entre puntos
    def set_V(self,V):
        self.V=V
    def set_max_min(self,xmax,xmin):
        self.xmax=xmax
        self.xmin=xmin
    def train_step(self, data):#Metodo que tiene internamente la clase Model del API de Keras
        x, y_exact = data

        #Change initial conditions for the PINN
        x_max=self.xmax
        x_min=self.xmin
        x_max=tf.constant([x_max],dtype=tf.float32)
        x_min=tf.constant([x_min],dtype=tf.float32)
        xi = tf.reshape(x,(x.shape[0],1))#Reconversion del batch de entrada a un vector columna
        unit = tf.constant(1.0, dtype=tf.float32)
        unit = tf.reshape(unit,shape=xi[0].shape)
        V=tf.constant(self.V, dtype=tf.float32)
        # loss set to zero
        print(V.shape)
        # Averaged eigenvalue
        cero=tf.constant(0.0, dtype=tf.float32)
        # Spatial mesh
        dx = tf.constant(self.dx,dtype=tf.float32)

        with tf.GradientTape() as tape:
            ymax=self(x_max,training=False)
            ymin=self(x_min,training=False)
            # Calculate the second derivative dy2/dx2
            with tf.GradientTape() as tape1:
                tape1.watch(xi)
                with tf.GradientTape() as tape2:
                    tape2.watch(xi)#Watch le dice en que tensor se tiene que fijar para los calculos, aqui le decimos que mire el batch de entrada porque luego lo utilizamos para calcular la salida, esto es asi porque tape solo se fija en tensores variables y xi es constante 
                    y_NN =self(xi,training=False)#Cálculo de la y_NN para todos los datos, self(xi) hace el paso hacia delante del batch de entrada, y multplicamos por hard_condition para asegurar que la salida cumple las condiciones de contorno. Training=false porque esto solo sirve para calcular la funcion de perdida, es decir, estamos haciendo un predict de los datos xi de entrada
                    print(y_NN.shape)#Esto devolvera cual es el tamaño de la salida, que sera de otro vector columna, cada elemento la salida de cada dato de entrada del batch
                    tape2.watch(y_NN)#Ahora que esta calculada la salida, nos fijamos en el tensor de salida, de forma que ya podremos hacer la derivada
                dy_dx_NN = tape2.gradient(y_NN, xi)#Calcula la derivada de la salida respecto a la entrada, nos devolvera otro vector
                tape1.watch(y_NN)#De nuevo, se tiene que fijar
                tape1.watch(dy_dx_NN)#...
            d2y_dx2_NN = tf.squeeze(tape1.gradient(dy_dx_NN, xi))#Segunda derivada
            y_NN = tf.squeeze(y_NN)#Squeeze elimina las dimensiones de tamaño a 1 en lso tensores, osea si tenemos un vector que seria un tensor de shape(y,1) al hacer squeeze pasa a ser solo de shape(y,)
            tape.watch(xi)
            tape.watch(y_NN)
            tape.watch(dy_dx_NN)
            tape.watch(d2y_dx2_NN)
    
            num = tf.reduce_sum(y_NN*(-d2y_dx2_NN+V*y_NN))#Esto es el producto escalar de y con la segunda derivada de y, no se multiplica por dx porque se va a ir luego al ser un cociente num/den
            den = tf.reduce_sum(tf.square(y_NN)) # Could this be zero? #Norma al cuadrado de y
            M = num/den #Funcio de perdidad, que intentamos que cuando sea minima coincida con el autoestado fundamental
            M = tf.reshape(M,shape=xi[0].shape)#Reconvertimos en tensor de tamaño 0 porque era un esacalar, a un tensor de tamaño, que solo tiene un elemento que es el escalar.


            I = tf.math.reduce_sum(tf.square(y_NN))
            I = I*dx
            I = tf.reshape(I,shape=xi[0].shape)#Se van creando copias de I hasta que llegamos al tensor que es ahora si la morma al cuadrado multiplicada por el factor dx de discretizacion, tambien es de dimension 1con el reshape

            #Loss= ODE+ boundary/initial conditions
            lossDE = self.compiled_loss(-d2y_dx2_NN+V*y_NN, M*y_NN) #Esta loss lo que tiene interesante es que self.compiled_loss va a recibir como primer argumento el valor real bueno, y como segundo al valor predicho. Luego, cuando llamamos al metodo compile y le pasamos que tipo de metrica queremos, hara cuentas con ello
            loss = lossDE + self.compiled_loss(I,unit) + self.compiled_loss(ymax,cero)+self.compiled_loss(ymin,cero) #  Esta loss es el autovalor mas la condicion de normalizacion, esta es con la que entrenamos
            kinetic = tf.reduce_sum(y_NN * (-d2y_dx2_NN)) / tf.reduce_sum(tf.square(y_NN))
            potential = tf.reduce_sum(y_NN * (V * y_NN)) / tf.reduce_sum(tf.square(y_NN))

        gradients = tape.gradient(loss, self.trainable_weights)#Calcula la derivada de la funcion de perdida respecto a los parametros entrenables
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))#Zip empareja cada derivada de la lista gradientes con el parametro respecto al que se ha derivad0, de forma que le pasamos este tensor al optimizador que aplicara los gradientes y actualiza los parametros
        self.compiled_metrics.update_state(y_exact, y_NN)#Por ultimo, se actualiza el estado respecto al paso anterior con la y_NN calculada en este nuevo paso con los parametros anteriores
        metrics = {m.name: m.result() for m in self.metrics}#Dado que entiendo que el metodo self.compiled_metrics.updatestate actualiza las metricas como atributo del objeto en self.metrics. {} Crea un diccionario, en el que el formato_:_ indica clave:valor asociado 
        metrics['DE']=lossDE
        metrics['loss']=loss
        metrics['I']=I
        metrics['E']=M
        metrics['ymax']=ymax
        metrics['ymin']=ymin
        metrics['Kinetic']=kinetic
        metrics['Potential']=potential
        return metrics#Este diccionario creado que devuelve el metodo traning_step es el que utiliza model.fit para calcular las metricas

# %%
## Custom metric
@keras.saving.register_keras_serializable()#La serializamos para que despues al cargar el modelo, no tengamos que haber definido previamente la funcion, simplemente la habra guardado ya.
def mse_odd_even_sol(y_true, y_pred):
    return tf.minimum(tf.reduce_mean(tf.square(y_pred - y_true)),tf.reduce_mean(tf.square(y_pred + y_true)))#Devuelve el minimo entre y_NN con +-y_real

# %%
n_train = 500  
# Definition of the function domain
xmin=-6
xmax=6
L=4
a=L/2
V0=3
x_train,step_dx = np.linspace(xmin,xmax,n_train,retstep=True)#No se coge ni el cero ni el uno porque los hemos forzad a ser cero al multiplicar por x*(1-x) a la yNN
print("dx=",step_dx)
V=np.zeros_like(x_train)
for i in range(len(x_train)):
    if x_train[i]<=-a or x_train[i]>=a:
        V[i]=V0
    else:
        V[i]=0

# The solution y(x) for training and validation datasets
plt.plot(x_train,V)
# Out:
# dx= 0.02404809619238477

# %%
# Build the model
checkpoint_callback = ModelCheckpoint(
    filepath=f"E_exc_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.weights.h5",
    monitor="mse_odd_even_sol",
    save_best_only=True,
    save_weights_only=True,
    mode="min",
    verbose=1,
)#Esto hace que cuando se lo pasemos a model.fit nos guarde solo los parametros del modelo en variacional_E_fundamental.h5 siempre que la perdida sea menor que en la anterior epoca
csv_logger =tf.keras.callbacks.CSVLogger(f'Metricas_Res_pozo_finito_E_exc_L_{L}_n_{n_train}.csv', append=False)

# %% [markdown]
# **AUTOVALOR EXCITADO**

# %%
def ecuacion(E):
    rho=np.sqrt(V0-E)
    k=np.sqrt(E)
    return rho/k+1/np.tan(k*a)
E=scipy.optimize.root_scalar(ecuacion,bracket=[0.5,1.6],method='bisect')
print(E)
# Out:
#       converged: True
#            flag: converged
#  function_calls: 41
#      iterations: 39
#            root: 1.419657947120322
#          method: bisect

# %% [markdown]
# **AUTOESTADO EXCITADO**

# %%
rho=np.sqrt(V0-E.root)
k=np.sqrt(E.root)
I1=np.exp(-L*rho)/(2*rho)
I2=a-np.sin(k*L)/(2*k)
I3=np.exp(-L*rho)/(2*rho)
fact=np.exp(-rho*a)/(np.cos(k*a))
C=1/np.sqrt(I1+np.square(fact)*I2+I3)
fi=np.zeros(n_train)
for i,x in enumerate(x_train):
    if x<=-a:
        fi[i]=C*np.exp(rho*x)
    elif x>=a:
        fi[i]=-C*np.exp(-rho*x)
    elif (x>-a or x<-a):
        fi[i]=C*fact*np.sin(k*x)
print(step_dx*sum(fi**2))
plt.plot(x_train,fi)
plt.axvline(-L / 2, linestyle="--", color="k")
plt.axvline(L / 2, linestyle="--", color="k")
plt.grid(True)
# Out:
# 1.000143424752543

# %%
xi = tf.reshape(
    tf.constant(x_train, dtype=tf.float32),
    (-1, 1)
)

rho_tf = tf.constant(rho, dtype=tf.float32)
k_tf = tf.constant(k, dtype=tf.float32)
C_tf = tf.constant(C, dtype=tf.float32)
fact_tf = tf.constant(fact, dtype=tf.float32)
a_tf = tf.constant(a, dtype=tf.float32)

with tf.GradientTape() as tape2:
    tape2.watch(xi)

    with tf.GradientTape() as tape1:
        tape1.watch(xi)

        fi_tf = tf.where(
            xi <= -a_tf,
            C_tf * tf.exp(rho_tf * xi),
            tf.where(
                xi >= a_tf,
                C_tf * tf.exp(-rho_tf * xi),
                C_tf * fact_tf * tf.cos(k_tf * xi)
            )
        )

    dy_dx = tape1.gradient(fi_tf, xi)

d2fi_dx2 = tape2.gradient(dy_dx, xi)

fi_tf = tf.squeeze(fi_tf)
d2fi_dx2 = tf.squeeze(d2fi_dx2)

V_tf = tf.constant(V, dtype=tf.float32)

num = tf.reduce_sum(
    fi_tf * (-d2fi_dx2 + V_tf * fi_tf)
)
den = tf.reduce_sum(tf.square(fi_tf))

M = num / den
print(M.numpy())
# Out:
# 1.419658

# %%
# Input and output neurons (from the data)
neurons_layer=[1, 50, 50, 50, 1]
n_layers=5


# Define the model
activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

model = EVE_PINN(input,output)
model.set_max_min(xmax,xmin)
model.set_step_dx(step_dx)
model.set_V(V)
#model.load_weights('C:\TFG\PINNS\PINNS\Pozo_infinito\Estado_fundamental_copia-1.keras')
#Define the metrics, optimizer and loss
metrics = [mse_odd_even_sol] #tf.keras.metrics.MeanSquaredError()
lr=0.001
optimizer = Adam(learning_rate=lr)

model.compile(loss='mse',
          optimizer=optimizer,
          metrics=metrics,
          run_eagerly=False)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "eve_pinn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,251 (20.51 KB)
#  Trainable params: 5,251 (20.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 2000 # 5000        
history = model.fit(x_train,fi, batch_size=n_train, epochs=epochs,
                  callbacks=[checkpoint_callback,csv_logger],shuffle=False)#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca
# Out:
# Epoch 1/2000
# (500,)
# (500, 1)
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:696: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight, training)`.
#   warnings.warn(
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:671: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# (500,)
# (500, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - DE: 0.0760 - E: 2.4008 - I: 0.7128 - Kinetic: 0.2035 - Potential: 2.1973 - mse_odd_even_sol: 0.0427 - loss: 0.2112 - ymax: 0.1624 - ymin: -0.1624
# Epoch 1: mse_odd_even_sol improved from None to 0.04271, saving model to E_exc_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1: finished saving model to E_exc_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - DE: 0.0760 - E: 2.4008 - I: 0.7128 - Kinetic: 0.2035 - Potential: 2.1973 - mse_odd_even_sol: 0.0427 - loss: 0.2112 - ymax: 0.1624 - ymin: -0.1624
# Epoch 2/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.2454 - E: 2.5938 - I: 2.9157 - Kinetic: 0.1249 - Potential: 2.4688 - mse_odd_even_sol: 0.1545 - loss: 4.4050 - ymax: 0.4948 - ymin: -0.4948
# Epoch 2: mse_odd_even_sol did not improve from 0.04271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.2454 - E: 2.5938 - I: 2.9157 - Kinetic: 0.1249 - Potential: 2.4688 - mse_odd_even_sol: 0.1545 - loss: 4.4050 - ymax: 0.4948 - ymin: -0.4948
# Epoch 3/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.1150 - E: 2.4820 - I: 1.1732 - Kinetic: 0.1686 - Potential: 2.3133 - mse_odd_even_sol: 0.0605 - loss: 0.2735 - ymax: 0.2552 - ymin: -0.2515
# Epoch 3: mse_odd_even_sol did not improve from 0.04271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - DE: 0.1150 - E: 2.4820 - I: 1.1732 - Kinetic: 0.1686 - Potential: 2.3133 - mse_odd_even_sol: 0.0605 - loss: 0.2735 - ymax: 0.2552 - ymin: -0.2515
# Epoch 4/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0409 - E: 2.2082 - I: 0.3343 - Kinetic: 0.2969 - Potential: 1.9113 - mse_odd_even_sol: 0.0342 - loss: 0.4886 - ymax: 0.0394 - ymin: -0.0554
# Epoch 4: mse_odd_even_sol improved from 0.04271 to 0.03417, saving model to E_exc_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 4: finished saving model to E_exc_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - DE: 0.0409 - E: 2.2082 - I: 0.3343 - Kinetic: 0.2969 - Potential: 1.9113 - mse_odd_even_sol: 0.0342 - loss: 0.4886 - ymax: 0.0394 - ymin: -0.0554
# Epoch 5/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - DE: 0.0132 - E: 1.9769 - I: 0.1027 - Kinetic: 0.5114 - Potential: 1.4655 - mse_odd_even_sol: 0.0469 - loss: 0.8408 - ymax: -0.1227 - ymin: 0.0860
# Epoch 5: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0132 - E: 1.9769 - I: 0.1027 - Kinetic: 0.5114 - Potential: 1.4655 - mse_odd_even_sol: 0.0469 - loss: 0.8408 - ymax: -0.1227 - ymin: 0.0860
# Epoch 6/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0086 - E: 2.7598 - I: 0.1561 - Kinetic: 0.1980 - Potential: 2.5618 - mse_odd_even_sol: 0.0768 - loss: 0.8246 - ymax: -0.2549 - ymin: 0.1972
# Epoch 6: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0086 - E: 2.7598 - I: 0.1561 - Kinetic: 0.1980 - Potential: 2.5618 - mse_odd_even_sol: 0.0768 - loss: 0.8246 - ymax: -0.2549 - ymin: 0.1972
# Epoch 7/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0109 - E: 2.9323 - I: 0.3919 - Kinetic: 0.0598 - Potential: 2.8725 - mse_odd_even_sol: 0.1119 - loss: 0.6107 - ymax: -0.3773 - ymin: 0.2960
# Epoch 7: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0109 - E: 2.9323 - I: 0.3919 - Kinetic: 0.0598 - Potential: 2.8725 - mse_odd_even_sol: 0.1119 - loss: 0.6107 - ymax: -0.3773 - ymin: 0.2960
# Epoch 8/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0249 - E: 2.9192 - I: 0.7877 - Kinetic: 0.0344 - Potential: 2.8848 - mse_odd_even_sol: 0.1225 - loss: 0.4677 - ymax: -0.4961 - ymin: 0.3892
# Epoch 8: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0249 - E: 2.9192 - I: 0.7877 - Kinetic: 0.0344 - Potential: 2.8848 - mse_odd_even_sol: 0.1225 - loss: 0.4677 - ymax: -0.4961 - ymin: 0.3892
# Epoch 9/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0466 - E: 2.8950 - I: 1.2701 - Kinetic: 0.0308 - Potential: 2.8642 - mse_odd_even_sol: 0.1430 - loss: 0.7011 - ymax: -0.6000 - ymin: 0.4706
# Epoch 9: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0466 - E: 2.8950 - I: 1.2701 - Kinetic: 0.0308 - Potential: 2.8642 - mse_odd_even_sol: 0.1430 - loss: 0.7011 - ymax: -0.6000 - ymin: 0.4706
# Epoch 10/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0591 - E: 2.8929 - I: 1.6012 - Kinetic: 0.0314 - Potential: 2.8615 - mse_odd_even_sol: 0.1587 - loss: 1.1245 - ymax: -0.6555 - ymin: 0.5237
# Epoch 10: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0591 - E: 2.8929 - I: 1.6012 - Kinetic: 0.0314 - Potential: 2.8615 - mse_odd_even_sol: 0.1587 - loss: 1.1245 - ymax: -0.6555 - ymin: 0.5237
# Epoch 11/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0557 - E: 2.9023 - I: 1.5934 - Kinetic: 0.0318 - Potential: 2.8705 - mse_odd_even_sol: 0.1574 - loss: 1.1091 - ymax: -0.6497 - ymin: 0.5285
# Epoch 11: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0557 - E: 2.9023 - I: 1.5934 - Kinetic: 0.0318 - Potential: 2.8705 - mse_odd_even_sol: 0.1574 - loss: 1.1091 - ymax: -0.6497 - ymin: 0.5285
# Epoch 12/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - DE: 0.0414 - E: 2.9198 - I: 1.3219 - Kinetic: 0.0318 - Potential: 2.8880 - mse_odd_even_sol: 0.1432 - loss: 0.7462 - ymax: -0.5982 - ymin: 0.4933
# Epoch 12: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0414 - E: 2.9198 - I: 1.3219 - Kinetic: 0.0318 - Potential: 2.8880 - mse_odd_even_sol: 0.1432 - loss: 0.7462 - ymax: -0.5982 - ymin: 0.4933
# Epoch 13/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0256 - E: 2.9445 - I: 0.9766 - Kinetic: 0.0329 - Potential: 2.9116 - mse_odd_even_sol: 0.1269 - loss: 0.4960 - ymax: -0.5261 - ymin: 0.4395
# Epoch 13: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - DE: 0.0256 - E: 2.9445 - I: 0.9766 - Kinetic: 0.0329 - Potential: 2.9116 - mse_odd_even_sol: 0.1269 - loss: 0.4960 - ymax: -0.5261 - ymin: 0.4395
# Epoch 14/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0138 - E: 2.9729 - I: 0.6857 - Kinetic: 0.0369 - Potential: 2.9359 - mse_odd_even_sol: 0.1152 - loss: 0.4666 - ymax: -0.4538 - ymin: 0.3849
# Epoch 14: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0138 - E: 2.9729 - I: 0.6857 - Kinetic: 0.0369 - Potential: 2.9359 - mse_odd_even_sol: 0.1152 - loss: 0.4666 - ymax: -0.4538 - ymin: 0.3849
# Epoch 15/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0068 - E: 2.9993 - I: 0.4843 - Kinetic: 0.0456 - Potential: 2.9536 - mse_odd_even_sol: 0.1089 - loss: 0.5418 - ymax: -0.3926 - ymin: 0.3390
# Epoch 15: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0068 - E: 2.9993 - I: 0.4843 - Kinetic: 0.0456 - Potential: 2.9536 - mse_odd_even_sol: 0.1089 - loss: 0.5418 - ymax: -0.3926 - ymin: 0.3390
# Epoch 16/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0033 - E: 3.0186 - I: 0.3588 - Kinetic: 0.0588 - Potential: 2.9598 - mse_odd_even_sol: 0.1062 - loss: 0.6270 - ymax: -0.3460 - ymin: 0.3047
# Epoch 16: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0033 - E: 3.0186 - I: 0.3588 - Kinetic: 0.0588 - Potential: 2.9598 - mse_odd_even_sol: 0.1062 - loss: 0.6270 - ymax: -0.3460 - ymin: 0.3047
# Epoch 17/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.0018 - E: 3.0295 - I: 0.2865 - Kinetic: 0.0733 - Potential: 2.9562 - mse_odd_even_sol: 0.1053 - loss: 0.6887 - ymax: -0.3136 - ymin: 0.2820
# Epoch 17: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0018 - E: 3.0295 - I: 0.2865 - Kinetic: 0.0733 - Potential: 2.9562 - mse_odd_even_sol: 0.1053 - loss: 0.6887 - ymax: -0.3136 - ymin: 0.2820
# Epoch 18/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0011 - E: 3.0354 - I: 0.2494 - Kinetic: 0.0844 - Potential: 2.9510 - mse_odd_even_sol: 0.1029 - loss: 0.7236 - ymax: -0.2938 - ymin: 0.2697
# Epoch 18: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.0011 - E: 3.0354 - I: 0.2494 - Kinetic: 0.0844 - Potential: 2.9510 - mse_odd_even_sol: 0.1029 - loss: 0.7236 - ymax: -0.2938 - ymin: 0.2697
# Epoch 19/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - DE: 6.9832e-04 - E: 3.0407 - I: 0.2369 - Kinetic: 0.0881 - Potential: 2.9527 - mse_odd_even_sol: 0.1013 - loss: 0.7353 - ymax: -0.2849 - ymin: 0.2666
# Epoch 19: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - DE: 6.9832e-04 - E: 3.0407 - I: 0.2369 - Kinetic: 0.0881 - Potential: 2.9527 - mse_odd_even_sol: 0.1013 - loss: 0.7353 - ymax: -0.2849 - ymin: 0.2666
# Epoch 20/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 4.3979e-04 - E: 3.0470 - I: 0.2445 - Kinetic: 0.0835 - Potential: 2.9634 - mse_odd_even_sol: 0.1031 - loss: 0.7268 - ymax: -0.2858 - ymin: 0.2719
# Epoch 20: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 4.3979e-04 - E: 3.0470 - I: 0.2445 - Kinetic: 0.0835 - Potential: 2.9634 - mse_odd_even_sol: 0.1031 - loss: 0.7268 - ymax: -0.2858 - ymin: 0.2719
# Epoch 21/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 3.5479e-04 - E: 3.0515 - I: 0.2720 - Kinetic: 0.0731 - Potential: 2.9784 - mse_odd_even_sol: 0.1033 - loss: 0.6988 - ymax: -0.2954 - ymin: 0.2850
# Epoch 21: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 3.5479e-04 - E: 3.0515 - I: 0.2720 - Kinetic: 0.0731 - Potential: 2.9784 - mse_odd_even_sol: 0.1033 - loss: 0.6988 - ymax: -0.2954 - ymin: 0.2850
# Epoch 22/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 6.9950e-04 - E: 3.0504 - I: 0.3226 - Kinetic: 0.0607 - Potential: 2.9897 - mse_odd_even_sol: 0.1029 - loss: 0.6511 - ymax: -0.3133 - ymin: 0.3056
# Epoch 22: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 6.9950e-04 - E: 3.0504 - I: 0.3226 - Kinetic: 0.0607 - Potential: 2.9897 - mse_odd_even_sol: 0.1029 - loss: 0.6511 - ymax: -0.3133 - ymin: 0.3056
# Epoch 23/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0019 - E: 3.0416 - I: 0.4016 - Kinetic: 0.0497 - Potential: 2.9918 - mse_odd_even_sol: 0.1033 - loss: 0.5860 - ymax: -0.3389 - ymin: 0.3334
# Epoch 23: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0019 - E: 3.0416 - I: 0.4016 - Kinetic: 0.0497 - Potential: 2.9918 - mse_odd_even_sol: 0.1033 - loss: 0.5860 - ymax: -0.3389 - ymin: 0.3334
# Epoch 24/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0044 - E: 3.0260 - I: 0.5145 - Kinetic: 0.0420 - Potential: 2.9839 - mse_odd_even_sol: 0.1051 - loss: 0.5129 - ymax: -0.3712 - ymin: 0.3675
# Epoch 24: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0044 - E: 3.0260 - I: 0.5145 - Kinetic: 0.0420 - Potential: 2.9839 - mse_odd_even_sol: 0.1051 - loss: 0.5129 - ymax: -0.3712 - ymin: 0.3675
# Epoch 25/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0086 - E: 3.0068 - I: 0.6626 - Kinetic: 0.0377 - Potential: 2.9691 - mse_odd_even_sol: 0.1089 - loss: 0.4536 - ymax: -0.4080 - ymin: 0.4060
# Epoch 25: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0086 - E: 3.0068 - I: 0.6626 - Kinetic: 0.0377 - Potential: 2.9691 - mse_odd_even_sol: 0.1089 - loss: 0.4536 - ymax: -0.4080 - ymin: 0.4060
# Epoch 26/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - DE: 0.0143 - E: 2.9880 - I: 0.8357 - Kinetic: 0.0360 - Potential: 2.9520 - mse_odd_even_sol: 0.1146 - loss: 0.4378 - ymax: -0.4456 - ymin: 0.4450
# Epoch 26: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - DE: 0.0143 - E: 2.9880 - I: 0.8357 - Kinetic: 0.0360 - Potential: 2.9520 - mse_odd_even_sol: 0.1146 - loss: 0.4378 - ymax: -0.4456 - ymin: 0.4450
# Epoch 27/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0205 - E: 2.9726 - I: 1.0043 - Kinetic: 0.0357 - Potential: 2.9369 - mse_odd_even_sol: 0.1210 - loss: 0.4782 - ymax: -0.4780 - ymin: 0.4788
# Epoch 27: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0205 - E: 2.9726 - I: 1.0043 - Kinetic: 0.0357 - Potential: 2.9369 - mse_odd_even_sol: 0.1210 - loss: 0.4782 - ymax: -0.4780 - ymin: 0.4788
# Epoch 28/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0252 - E: 2.9628 - I: 1.1229 - Kinetic: 0.0360 - Potential: 2.9268 - mse_odd_even_sol: 0.1257 - loss: 0.5392 - ymax: -0.4985 - ymin: 0.5005
# Epoch 28: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.0252 - E: 2.9628 - I: 1.1229 - Kinetic: 0.0360 - Potential: 2.9268 - mse_odd_even_sol: 0.1257 - loss: 0.5392 - ymax: -0.4985 - ymin: 0.5005
# Epoch 29/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.0267 - E: 2.9596 - I: 1.1521 - Kinetic: 0.0363 - Potential: 2.9233 - mse_odd_even_sol: 0.1267 - loss: 0.5569 - ymax: -0.5021 - ymin: 0.5050
# Epoch 29: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0267 - E: 2.9596 - I: 1.1521 - Kinetic: 0.0363 - Potential: 2.9233 - mse_odd_even_sol: 0.1267 - loss: 0.5569 - ymax: -0.5021 - ymin: 0.5050
# Epoch 30/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0246 - E: 2.9627 - I: 1.0877 - Kinetic: 0.0365 - Potential: 2.9262 - mse_odd_even_sol: 0.1234 - loss: 0.5136 - ymax: -0.4887 - ymin: 0.4924
# Epoch 30: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.0246 - E: 2.9627 - I: 1.0877 - Kinetic: 0.0365 - Potential: 2.9262 - mse_odd_even_sol: 0.1234 - loss: 0.5136 - ymax: -0.4887 - ymin: 0.4924
# Epoch 31/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0203 - E: 2.9706 - I: 0.9630 - Kinetic: 0.0367 - Potential: 2.9339 - mse_odd_even_sol: 0.1178 - loss: 0.4551 - ymax: -0.4635 - ymin: 0.4676
# Epoch 31: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0203 - E: 2.9706 - I: 0.9630 - Kinetic: 0.0367 - Potential: 2.9339 - mse_odd_even_sol: 0.1178 - loss: 0.4551 - ymax: -0.4635 - ymin: 0.4676
# Epoch 32/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0156 - E: 2.9813 - I: 0.8235 - Kinetic: 0.0372 - Potential: 2.9442 - mse_odd_even_sol: 0.1119 - loss: 0.4264 - ymax: -0.4334 - ymin: 0.4379
# Epoch 32: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0156 - E: 2.9813 - I: 0.8235 - Kinetic: 0.0372 - Potential: 2.9442 - mse_odd_even_sol: 0.1119 - loss: 0.4264 - ymax: -0.4334 - ymin: 0.4379
# Epoch 33/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0117 - E: 2.9923 - I: 0.7023 - Kinetic: 0.0382 - Potential: 2.9541 - mse_odd_even_sol: 0.1072 - loss: 0.4322 - ymax: -0.4050 - ymin: 0.4097
# Epoch 33: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0117 - E: 2.9923 - I: 0.7023 - Kinetic: 0.0382 - Potential: 2.9541 - mse_odd_even_sol: 0.1072 - loss: 0.4322 - ymax: -0.4050 - ymin: 0.4097
# Epoch 34/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0092 - E: 3.0012 - I: 0.6146 - Kinetic: 0.0395 - Potential: 2.9617 - mse_odd_even_sol: 0.1041 - loss: 0.4540 - ymax: -0.3824 - ymin: 0.3874
# Epoch 34: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.0092 - E: 3.0012 - I: 0.6146 - Kinetic: 0.0395 - Potential: 2.9617 - mse_odd_even_sol: 0.1041 - loss: 0.4540 - ymax: -0.3824 - ymin: 0.3874
# Epoch 35/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0079 - E: 3.0063 - I: 0.5637 - Kinetic: 0.0406 - Potential: 2.9658 - mse_odd_even_sol: 0.1022 - loss: 0.4728 - ymax: -0.3678 - ymin: 0.3732
# Epoch 35: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0079 - E: 3.0063 - I: 0.5637 - Kinetic: 0.0406 - Potential: 2.9658 - mse_odd_even_sol: 0.1022 - loss: 0.4728 - ymax: -0.3678 - ymin: 0.3732
# Epoch 36/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0076 - E: 3.0069 - I: 0.5476 - Kinetic: 0.0410 - Potential: 2.9659 - mse_odd_even_sol: 0.1013 - loss: 0.4786 - ymax: -0.3619 - ymin: 0.3678
# Epoch 36: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0076 - E: 3.0069 - I: 0.5476 - Kinetic: 0.0410 - Potential: 2.9659 - mse_odd_even_sol: 0.1013 - loss: 0.4786 - ymax: -0.3619 - ymin: 0.3678
# Epoch 37/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0084 - E: 3.0028 - I: 0.5636 - Kinetic: 0.0408 - Potential: 2.9620 - mse_odd_even_sol: 0.1012 - loss: 0.4693 - ymax: -0.3644 - ymin: 0.3709
# Epoch 37: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0084 - E: 3.0028 - I: 0.5636 - Kinetic: 0.0408 - Potential: 2.9620 - mse_odd_even_sol: 0.1012 - loss: 0.4693 - ymax: -0.3644 - ymin: 0.3709
# Epoch 38/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0102 - E: 2.9948 - I: 0.6092 - Kinetic: 0.0402 - Potential: 2.9546 - mse_odd_even_sol: 0.1020 - loss: 0.4485 - ymax: -0.3743 - ymin: 0.3815
# Epoch 38: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0102 - E: 2.9948 - I: 0.6092 - Kinetic: 0.0402 - Potential: 2.9546 - mse_odd_even_sol: 0.1020 - loss: 0.4485 - ymax: -0.3743 - ymin: 0.3815
# Epoch 39/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0130 - E: 2.9839 - I: 0.6807 - Kinetic: 0.0397 - Potential: 2.9443 - mse_odd_even_sol: 0.1038 - loss: 0.4249 - ymax: -0.3897 - ymin: 0.3977
# Epoch 39: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0130 - E: 2.9839 - I: 0.6807 - Kinetic: 0.0397 - Potential: 2.9443 - mse_odd_even_sol: 0.1038 - loss: 0.4249 - ymax: -0.3897 - ymin: 0.3977
# Epoch 40/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0166 - E: 2.9721 - I: 0.7703 - Kinetic: 0.0396 - Potential: 2.9325 - mse_odd_even_sol: 0.1063 - loss: 0.4096 - ymax: -0.4080 - ymin: 0.4168
# Epoch 40: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.0166 - E: 2.9721 - I: 0.7703 - Kinetic: 0.0396 - Potential: 2.9325 - mse_odd_even_sol: 0.1063 - loss: 0.4096 - ymax: -0.4080 - ymin: 0.4168
# Epoch 41/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0206 - E: 2.9611 - I: 0.8636 - Kinetic: 0.0398 - Potential: 2.9212 - mse_odd_even_sol: 0.1093 - loss: 0.4102 - ymax: -0.4258 - ymin: 0.4354
# Epoch 41: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0206 - E: 2.9611 - I: 0.8636 - Kinetic: 0.0398 - Potential: 2.9212 - mse_odd_even_sol: 0.1093 - loss: 0.4102 - ymax: -0.4258 - ymin: 0.4354
# Epoch 42/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - DE: 0.0242 - E: 2.9525 - I: 0.9398 - Kinetic: 0.0403 - Potential: 2.9122 - mse_odd_even_sol: 0.1118 - loss: 0.4226 - ymax: -0.4392 - ymin: 0.4494
# Epoch 42: mse_odd_even_sol did not improve from 0.03417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - DE: 0.0242 - E: 2.9525 - I: 0.9398 - Kinetic: 0.0403 - Potential: 2.9122 - mse_odd_even_sol: 0.1118 - loss: 0.4226 - ymax: -0.4392 - ymin: 0.4494
# Epoch 43/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - DE: 0.0262 - E: 2.9474 - I: 0.9786 - Kinetic: 0.0409 - Potential: 2.9065 - mse_odd_even_sol: 0.1129 - loss: 0.4320 - ymax: -0.4449 - ymin: 0.4554
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 epochs = 2000 # 5000
# ----> 2 history = model.fit(x_train,fi, batch_size=n_train, epochs=epochs,
#       3                   callbacks=[checkpoint_callback,csv_logger],shuffle=False)#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:397, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     395 callbacks.on_epoch_begin(epoch)
#     396 with epoch_iterator.catch_stop_iteration():
# --> 397     for begin_step, end_step, iterator in epoch_iterator:
#     398         callbacks.on_train_batch_begin(begin_step)
#     399         logs = self.train_function(iterator)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:765, in TFEpochIterator.__next__(self)
#     764 def __next__(self):
# --> 765     return next(self._epoch_iterator)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\epoch_iterator.py:125, in EpochIterator._enumerate_iterator(self)
#     119         yield (
#     120             step,
#     121             step + self.steps_per_execution - 1,
#     122             self._current_iterator,
#     123         )
#     124     if self._num_batches and self._steps_seen >= self._num_batches:
# --> 125         self._current_iterator = iter(self._get_iterator())
#     126         self._steps_seen = 0
#     127 else:
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
name=f'Res_E_exc_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.keras'
model.save(name)

# %%
plt.plot(history.history['mse_odd_even_sol'],label='ECM')
plt.plot(history.history['loss'],label='Pérdida')
plt.plot(history.history['I'],label= 'Norma')
#plt.title('Método variacional pozo infinito')
plt.xlabel('Épocas')
plt.yscale("log")
plt.grid(True, linestyle="--")
plt.legend()
Imagen_metricas=f'Métricas_Res_E_exc_pozo_finito_L_{L}_n_{n_train}'
plt.savefig(Imagen_metricas, dpi=300, bbox_inches='tight')

# %%
neurons_layer=[1, 50, 50, 50, 1]
n_layers=5

# Define the model
input,output = nn_model(activation,neurons_layer,n_layers)

cloned_model = EVE_PINN(input,output)
cloned_model.load_weights(f"E_exc_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.weights.h5")

# %%
y_best=cloned_model.predict(x_train)
y_best=np.reshape(y_best,x_train.shape)
y_NN=model.predict(x_train)
y_NN=np.reshape(y_NN,n_train)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
#plt.plot(x_train,y_NN,lw=8,label=r'$y_{pred}$ (x)')
plt.plot(x_train,y_best,lw=8,label=r'$y_{PINN}$ (x)')
plt.plot(x_train,-fi, lw=4, linestyle='--',label=r'$y_{sol}$ (x)')
plt.xlabel('x')
plt.grid(True, linestyle="--")
plt.legend()
Imagen_y_NN=f'Res_E_exc_pozo_infinito_L_{L}_n_{n_train}'
plt.savefig(Imagen_y_NN, dpi=300, bbox_inches='tight')

# %% [markdown]
# ***FUNDAMENTAL***

# %%
@keras.saving.register_keras_serializable()#Esto hace que se pueda guardar el modelo y cargarlo sin problemas despues
class EVE_PINN(tf.keras.Model):# Esta clase va a heredar de la clase Model de Keras, lo que nos permite usar todos los metodos de la clase Model y ademas definir nuestros propios metodos
    def set_step_dx(self,dx): #Este metodo inicializa la clase
        self.dx=dx #Lo que hace esto es que al objeto que luego instanciamos le asigna el atributo dx, que va a ser espaciado entre puntos
    def set_V(self,V):
        self.V=V
    def fi_1(self,fi_1):
        self.fi_1=fi_1
    def set_max_min(self,xmax,xmin):
        self.xmax=xmax
        self.xmin=xmin
    def train_step(self, data):#Metodo que tiene internamente la clase Model del API de Keras
        x, y_exact = data

        #Change initial conditions for the PINN
        x_max=self.xmax
        x_min=self.xmin
        x_max=tf.constant([x_max],dtype=tf.float32)
        x_min=tf.constant([x_min],dtype=tf.float32)
        xi = tf.reshape(x,(x.shape[0],1))#Reconversion del batch de entrada a un vector columna
        unit = tf.constant(1.0, dtype=tf.float32)
        unit = tf.reshape(unit,shape=xi[0].shape)
        V=tf.constant(self.V, dtype=tf.float32)
        # loss set to zero
        print(V.shape)
        # Averaged eigenvalue
        cero=tf.constant(0.0, dtype=tf.float32)
        # Spatial mesh
        dx = tf.constant(self.dx,dtype=tf.float32)
        fi_1=tf.constant(self.fi_1,dtype=tf.float32)
        print(fi_1.shape)
        with tf.GradientTape() as tape:
            ymax=self(x_max,training=False)
            ymin=self(x_min,training=False)
            # Calculate the second derivative dy2/dx2
            with tf.GradientTape() as tape1:
                tape1.watch(xi)
                with tf.GradientTape() as tape2:
                    tape2.watch(xi)#Watch le dice en que tensor se tiene que fijar para los calculos, aqui le decimos que mire el batch de entrada porque luego lo utilizamos para calcular la salida, esto es asi porque tape solo se fija en tensores variables y xi es constante 
                    y_NN =self(xi,training=False)#Cálculo de la y_NN para todos los datos, self(xi) hace el paso hacia delante del batch de entrada, y multplicamos por hard_condition para asegurar que la salida cumple las condiciones de contorno. Training=false porque esto solo sirve para calcular la funcion de perdida, es decir, estamos haciendo un predict de los datos xi de entrada
                    print(y_NN.shape)#Esto devolvera cual es el tamaño de la salida, que sera de otro vector columna, cada elemento la salida de cada dato de entrada del batch
                    tape2.watch(y_NN)#Ahora que esta calculada la salida, nos fijamos en el tensor de salida, de forma que ya podremos hacer la derivada
                dy_dx_NN = tape2.gradient(y_NN, xi)#Calcula la derivada de la salida respecto a la entrada, nos devolvera otro vector
                tape1.watch(y_NN)#De nuevo, se tiene que fijar
                tape1.watch(dy_dx_NN)#...
            d2y_dx2_NN = tf.squeeze(tape1.gradient(dy_dx_NN, xi))#Segunda derivada
            y_NN = tf.squeeze(y_NN)#Squeeze elimina las dimensiones de tamaño a 1 en lso tensores, osea si tenemos un vector que seria un tensor de shape(y,1) al hacer squeeze pasa a ser solo de shape(y,)
            tape.watch(xi)
            tape.watch(y_NN)
            tape.watch(dy_dx_NN)
            tape.watch(d2y_dx2_NN)
    
            num = tf.reduce_sum(y_NN*(-d2y_dx2_NN+V*y_NN))#Esto es el producto escalar de y con la segunda derivada de y, no se multiplica por dx porque se va a ir luego al ser un cociente num/den
            den = tf.reduce_sum(tf.square(y_NN)) # Could this be zero? #Norma al cuadrado de y
            M = num/den #Funcio de perdidad, que intentamos que cuando sea minima coincida con el autoestado fundamental
            M = tf.reshape(M,shape=xi[0].shape)#Reconvertimos en tensor de tamaño 0 porque era un esacalar, a un tensor de tamaño, que solo tiene un elemento que es el escalar.
            
            H = tf.constant(100.0,dtype=tf.float32)
            num_1=tf.reduce_sum(y_NN*fi_1)**2
            den_1=tf.reduce_sum(tf.square(y_NN))*tf.reduce_sum(tf.square(fi_1))
            Schwartz=num_1/den_1
            Schwartz=tf.reshape(Schwartz,shape=xi[0].shape)

            I = tf.math.reduce_sum(tf.square(y_NN))
            I = I*dx
            I = tf.reshape(I,shape=xi[0].shape)#Se van creando copias de I hasta que llegamos al tensor que es ahora si la morma al cuadrado multiplicada por el factor dx de discretizacion, tambien es de dimension 1con el reshape

            #Loss= ODE+ boundary/initial conditions
            lossDE = self.compiled_loss(-d2y_dx2_NN+V*y_NN, M*y_NN) #Esta loss lo que tiene interesante es que self.compiled_loss va a recibir como primer argumento el valor real bueno, y como segundo al valor predicho. Luego, cuando llamamos al metodo compile y le pasamos que tipo de metrica queremos, hara cuentas con ello
            loss = 100*lossDE + 10*self.compiled_loss(I,unit) +H*Schwartz +10*self.compiled_loss(ymax,cero)+10*self.compiled_loss(ymin,cero) #  Esta loss es el autovalor mas la condicion de normalizacion, esta es con la que entrenamos
            kinetic = tf.reduce_sum(y_NN * (-d2y_dx2_NN)) / tf.reduce_sum(tf.square(y_NN))
            potential = tf.reduce_sum(y_NN * (V * y_NN)) / tf.reduce_sum(tf.square(y_NN))

        gradients = tape.gradient(loss, self.trainable_weights)#Calcula la derivada de la funcion de perdida respecto a los parametros entrenables
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))#Zip empareja cada derivada de la lista gradientes con el parametro respecto al que se ha derivad0, de forma que le pasamos este tensor al optimizador que aplicara los gradientes y actualiza los parametros
        self.compiled_metrics.update_state(y_exact, y_NN)#Por ultimo, se actualiza el estado respecto al paso anterior con la y_NN calculada en este nuevo paso con los parametros anteriores
        metrics = {m.name: m.result() for m in self.metrics}#Dado que entiendo que el metodo self.compiled_metrics.updatestate actualiza las metricas como atributo del objeto en self.metrics. {} Crea un diccionario, en el que el formato_:_ indica clave:valor asociado 
        metrics['DE']=lossDE
        metrics['loss']=loss
        metrics['I']=I
        metrics['E']=M
        metrics['ymax']=ymax
        metrics['ymin']=ymin
        metrics['Kinetic']=kinetic
        metrics['Potential']=potential
        return metrics#Este diccionario creado que devuelve el metodo traning_step es el que utiliza model.fit para calcular las metricas

# %%
## Custom metric
@keras.saving.register_keras_serializable()#La serializamos para que despues al cargar el modelo, no tengamos que haber definido previamente la funcion, simplemente la habra guardado ya.
def mse_odd_even_sol(y_true, y_pred):
    return tf.minimum(tf.reduce_mean(tf.square(y_pred - y_true)),tf.reduce_mean(tf.square(y_pred + y_true)))#Devuelve el minimo entre y_NN con +-y_real

# %%
n_train = 500  
# Definition of the function domain
xmin=-6
xmax=6
L=4
a=L/2
V0=3
x_train,step_dx = np.linspace(xmin,xmax,n_train,retstep=True)#No se coge ni el cero ni el uno porque los hemos forzad a ser cero al multiplicar por x*(1-x) a la yNN
print("dx=",step_dx)
V=np.zeros_like(x_train)
for i in range(len(x_train)):
    if x_train[i]<=-a or x_train[i]>=a:
        V[i]=V0
    else:
        V[i]=0

# The solution y(x) for training and validation datasets
plt.plot(x_train,V)
# Out:
# dx= 0.02404809619238477

# %%
# Build the model
checkpoint_callback = ModelCheckpoint(
    filepath=f"E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.weights.h5",
    monitor="mse_odd_even_sol",
    save_best_only=True,
    save_weights_only=True,
    mode="min",
    verbose=1,
)#Esto hace que cuando se lo pasemos a model.fit nos guarde solo los parametros del modelo en variacional_E_fundamental.h5 siempre que la perdida sea menor que en la anterior epoca
csv_logger =tf.keras.callbacks.CSVLogger(f'Metricas_Res_E_fund_pozo_finito_L_{L}_n_{n_train}.csv', append=False)

# %%
def ecuacion(E):
    rho=np.sqrt(V0-E)
    k=np.sqrt(E)
    return rho/k-np.tan(k*a)
E=scipy.optimize.root_scalar(ecuacion,bracket=[0.2,0.5],method='bisect')
print(E)
# Out:
#       converged: True
#            flag: converged
#  function_calls: 40
#      iterations: 38
#            root: 0.3678660235727875
#          method: bisect

# %%
rho=np.sqrt(V0-E.root)
k=np.sqrt(E.root)
I1=np.exp(-L*rho)/(2*rho)
I2=a*(1+np.sin(k*L)/(k*L))
I3=np.exp(-L*rho)/(2*rho)
fact=np.exp(-rho*a)/(np.cos(k*a))
C=1/np.sqrt(I1+np.square(fact)*I2+I3)
fi=np.zeros(n_train)
for i,x in enumerate(x_train):
    if x<=-a:
        fi[i]=C*np.exp(rho*x)
    elif x>=a:
        fi[i]=C*np.exp(-rho*x)
    elif (x>-a or x<-a):
        fi[i]=C*fact*np.cos(k*x)
print(step_dx*sum(fi**2))
plt.plot(x_train,fi)
plt.axvline(-L / 2, linestyle="--", color="k")
plt.axvline(L / 2, linestyle="--", color="k")
plt.grid(True)
# Out:
# 0.9999998884417445

# %%
xi = tf.reshape(
    tf.constant(x_train, dtype=tf.float32),
    (-1, 1)
)

rho_tf = tf.constant(rho, dtype=tf.float32)
k_tf = tf.constant(k, dtype=tf.float32)
C_tf = tf.constant(C, dtype=tf.float32)
fact_tf = tf.constant(fact, dtype=tf.float32)
a_tf = tf.constant(a, dtype=tf.float32)

with tf.GradientTape() as tape2:
    tape2.watch(xi)

    with tf.GradientTape() as tape1:
        tape1.watch(xi)

        fi_tf = tf.where(
            xi <= -a_tf,
            C_tf * tf.exp(rho_tf * xi),
            tf.where(
                xi >= a_tf,
                C_tf * tf.exp(-rho_tf * xi),
                C_tf * fact_tf * tf.cos(k_tf * xi)
            )
        )

    dy_dx = tape1.gradient(fi_tf, xi)

d2fi_dx2 = tape2.gradient(dy_dx, xi)

fi_tf = tf.squeeze(fi_tf)
d2fi_dx2 = tf.squeeze(d2fi_dx2)

V_tf = tf.constant(V, dtype=tf.float32)

num = tf.reduce_sum(
    fi_tf * (-d2fi_dx2 + V_tf * fi_tf)
)
den = tf.reduce_sum(tf.square(fi_tf))

M = num / den
print(M.numpy())
# Out:
# 0.367866

# %%
# Input and output neurons (from the data)
neurons_layer=[1, 50, 50, 50, 1]
n_layers=5


# Define the model
input,output = nn_model(activation,neurons_layer,n_layers)

best_fund_model = EVE_PINN(input,output)
best_fund_model.load_weights(f"C:\TFG\PINNS\PINNS\Pozo_finito\Residuo\Primer excitado\E_exc_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.weights.h5")
y_NN_1=best_fund_model.predict(x_train)
fi_1=np.reshape(y_NN_1,n_train)

activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

model = EVE_PINN(input,output)
model.set_max_min(xmax,xmin)
model.set_step_dx(step_dx)
model.set_V(V)
model.fi_1(fi_1)
#model.load_weights('C:\TFG\PINNS\PINNS\Pozo_infinito\Estado_fundamental_copia-1.keras')
#Define the metrics, optimizer and loss
metrics = [mse_odd_even_sol] #tf.keras.metrics.MeanSquaredError()
lr=0.001
optimizer = Adam(learning_rate=lr)

model.compile(loss='mse',
          optimizer=optimizer,
          metrics=metrics,
          run_eagerly=False)

model.summary()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Model: "eve_pinn_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,251 (20.51 KB)
#  Trainable params: 5,251 (20.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 3000 # 5000        
history = model.fit(x_train,fi, batch_size=n_train, epochs=epochs,
                  callbacks=[checkpoint_callback,csv_logger],shuffle=False)#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca
# Out:
# Epoch 1/3000
# (500,)
# (500,)
# (500, 1)
# (500,)
# (500,)
# (500, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - DE: 0.0295 - E: 2.8213 - I: 0.6589 - Kinetic: 0.0384 - Potential: 2.7829 - mse_odd_even_sol: 0.1380 - loss: 23.8361 - ymax: 0.3459 - ymin: -0.3459
# Epoch 1: mse_odd_even_sol improved from None to 0.13796, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - DE: 0.0295 - E: 2.8213 - I: 0.6589 - Kinetic: 0.0384 - Potential: 2.7829 - mse_odd_even_sol: 0.1380 - loss: 23.8361 - ymax: 0.3459 - ymin: -0.3459
# Epoch 2/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.0045 - E: 2.8818 - I: 0.1651 - Kinetic: -0.0074 - Potential: 2.8892 - mse_odd_even_sol: 0.0892 - loss: 15.9741 - ymax: 0.2259 - ymin: -0.1955
# Epoch 2: mse_odd_even_sol improved from 0.13796 to 0.08917, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 2: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - DE: 0.0045 - E: 2.8818 - I: 0.1651 - Kinetic: -0.0074 - Potential: 2.8892 - mse_odd_even_sol: 0.0892 - loss: 15.9741 - ymax: 0.2259 - ymin: -0.1955
# Epoch 3/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0106 - E: 2.3117 - I: 0.0730 - Kinetic: 0.2269 - Potential: 2.0848 - mse_odd_even_sol: 0.0750 - loss: 51.8124 - ymax: 0.0235 - ymin: 0.0324
# Epoch 3: mse_odd_even_sol improved from 0.08917 to 0.07504, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 3: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - DE: 0.0106 - E: 2.3117 - I: 0.0730 - Kinetic: 0.2269 - Potential: 2.0848 - mse_odd_even_sol: 0.0750 - loss: 51.8124 - ymax: 0.0235 - ymin: 0.0324
# Epoch 4/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0622 - E: 2.6833 - I: 0.7691 - Kinetic: 0.1120 - Potential: 2.5713 - mse_odd_even_sol: 0.1278 - loss: 35.9172 - ymax: -0.2178 - ymin: 0.2939
# Epoch 4: mse_odd_even_sol did not improve from 0.07504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.0622 - E: 2.6833 - I: 0.7691 - Kinetic: 0.1120 - Potential: 2.5713 - mse_odd_even_sol: 0.1278 - loss: 35.9172 - ymax: -0.2178 - ymin: 0.2939
# Epoch 5/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.1342 - E: 2.7392 - I: 1.9519 - Kinetic: 0.0902 - Potential: 2.6490 - mse_odd_even_sol: 0.2220 - loss: 51.1584 - ymax: -0.4194 - ymin: 0.5122
# Epoch 5: mse_odd_even_sol did not improve from 0.07504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.1342 - E: 2.7392 - I: 1.9519 - Kinetic: 0.0902 - Potential: 2.6490 - mse_odd_even_sol: 0.2220 - loss: 51.1584 - ymax: -0.4194 - ymin: 0.5122
# Epoch 6/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.1084 - E: 2.7263 - I: 1.5104 - Kinetic: 0.0910 - Potential: 2.6353 - mse_odd_even_sol: 0.1821 - loss: 40.8354 - ymax: -0.3505 - ymin: 0.4560
# Epoch 6: mse_odd_even_sol did not improve from 0.07504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - DE: 0.1084 - E: 2.7263 - I: 1.5104 - Kinetic: 0.0910 - Potential: 2.6353 - mse_odd_even_sol: 0.1821 - loss: 40.8354 - ymax: -0.3505 - ymin: 0.4560
# Epoch 7/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0693 - E: 2.6811 - I: 0.8498 - Kinetic: 0.0960 - Potential: 2.5851 - mse_odd_even_sol: 0.1248 - loss: 32.9896 - ymax: -0.2260 - ymin: 0.3414
# Epoch 7: mse_odd_even_sol did not improve from 0.07504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0693 - E: 2.6811 - I: 0.8498 - Kinetic: 0.0960 - Potential: 2.5851 - mse_odd_even_sol: 0.1248 - loss: 32.9896 - ymax: -0.2260 - ymin: 0.3414
# Epoch 8/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0424 - E: 2.5713 - I: 0.4119 - Kinetic: 0.1004 - Potential: 2.4709 - mse_odd_even_sol: 0.0863 - loss: 31.5436 - ymax: -0.1093 - ymin: 0.2334
# Epoch 8: mse_odd_even_sol did not improve from 0.07504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.0424 - E: 2.5713 - I: 0.4119 - Kinetic: 0.1004 - Potential: 2.4709 - mse_odd_even_sol: 0.0863 - loss: 31.5436 - ymax: -0.1093 - ymin: 0.2334
# Epoch 9/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0273 - E: 2.3038 - I: 0.1905 - Kinetic: 0.0906 - Potential: 2.2132 - mse_odd_even_sol: 0.0655 - loss: 27.4666 - ymax: -0.0125 - ymin: 0.1465
# Epoch 9: mse_odd_even_sol improved from 0.07504 to 0.06551, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 9: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - DE: 0.0273 - E: 2.3038 - I: 0.1905 - Kinetic: 0.0906 - Potential: 2.2132 - mse_odd_even_sol: 0.0655 - loss: 27.4666 - ymax: -0.0125 - ymin: 0.1465
# Epoch 10/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - DE: 0.0180 - E: 1.7574 - I: 0.1010 - Kinetic: 0.0196 - Potential: 1.7377 - mse_odd_even_sol: 0.0548 - loss: 11.6570 - ymax: 0.1022 - ymin: 0.0452
# Epoch 10: mse_odd_even_sol improved from 0.06551 to 0.05480, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 10: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.0180 - E: 1.7574 - I: 0.1010 - Kinetic: 0.0196 - Potential: 1.7377 - mse_odd_even_sol: 0.0548 - loss: 11.6570 - ymax: 0.1022 - ymin: 0.0452
# Epoch 11/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0312 - E: 2.2931 - I: 0.2415 - Kinetic: 0.0072 - Potential: 2.2860 - mse_odd_even_sol: 0.0633 - loss: 17.3439 - ymax: 0.2486 - ymin: -0.0884
# Epoch 11: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.0312 - E: 2.2931 - I: 0.2415 - Kinetic: 0.0072 - Potential: 2.2860 - mse_odd_even_sol: 0.0633 - loss: 17.3439 - ymax: 0.2486 - ymin: -0.0884
# Epoch 12/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0497 - E: 2.5043 - I: 0.4917 - Kinetic: 0.0255 - Potential: 2.4787 - mse_odd_even_sol: 0.0809 - loss: 21.9103 - ymax: 0.3450 - ymin: -0.1717
# Epoch 12: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0497 - E: 2.5043 - I: 0.4917 - Kinetic: 0.0255 - Potential: 2.4787 - mse_odd_even_sol: 0.0809 - loss: 21.9103 - ymax: 0.3450 - ymin: -0.1717
# Epoch 13/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0680 - E: 2.5735 - I: 0.7485 - Kinetic: 0.0338 - Potential: 2.5396 - mse_odd_even_sol: 0.0991 - loss: 24.4306 - ymax: 0.4159 - ymin: -0.2297
# Epoch 13: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0680 - E: 2.5735 - I: 0.7485 - Kinetic: 0.0338 - Potential: 2.5396 - mse_odd_even_sol: 0.0991 - loss: 24.4306 - ymax: 0.4159 - ymin: -0.2297
# Epoch 14/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0822 - E: 2.5957 - I: 0.9393 - Kinetic: 0.0373 - Potential: 2.5584 - mse_odd_even_sol: 0.1121 - loss: 26.4717 - ymax: 0.4606 - ymin: -0.2627
# Epoch 14: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0822 - E: 2.5957 - I: 0.9393 - Kinetic: 0.0373 - Potential: 2.5584 - mse_odd_even_sol: 0.1121 - loss: 26.4717 - ymax: 0.4606 - ymin: -0.2627
# Epoch 15/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0888 - E: 2.5888 - I: 0.9988 - Kinetic: 0.0378 - Potential: 2.5511 - mse_odd_even_sol: 0.1147 - loss: 27.1854 - ymax: 0.4741 - ymin: -0.2660
# Epoch 15: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0888 - E: 2.5888 - I: 0.9988 - Kinetic: 0.0378 - Potential: 2.5511 - mse_odd_even_sol: 0.1147 - loss: 27.1854 - ymax: 0.4741 - ymin: -0.2660
# Epoch 16/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0870 - E: 2.5541 - I: 0.9193 - Kinetic: 0.0359 - Potential: 2.5182 - mse_odd_even_sol: 0.1062 - loss: 26.1254 - ymax: 0.4569 - ymin: -0.2404
# Epoch 16: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0870 - E: 2.5541 - I: 0.9193 - Kinetic: 0.0359 - Potential: 2.5182 - mse_odd_even_sol: 0.1062 - loss: 26.1254 - ymax: 0.4569 - ymin: -0.2404
# Epoch 17/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0794 - E: 2.4836 - I: 0.7521 - Kinetic: 0.0315 - Potential: 2.4522 - mse_odd_even_sol: 0.0908 - loss: 23.9529 - ymax: 0.4162 - ymin: -0.1926
# Epoch 17: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0794 - E: 2.4836 - I: 0.7521 - Kinetic: 0.0315 - Potential: 2.4522 - mse_odd_even_sol: 0.0908 - loss: 23.9529 - ymax: 0.4162 - ymin: -0.1926
# Epoch 18/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0690 - E: 2.3568 - I: 0.5597 - Kinetic: 0.0238 - Potential: 2.3329 - mse_odd_even_sol: 0.0735 - loss: 21.0609 - ymax: 0.3591 - ymin: -0.1290
# Epoch 18: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0690 - E: 2.3568 - I: 0.5597 - Kinetic: 0.0238 - Potential: 2.3329 - mse_odd_even_sol: 0.0735 - loss: 21.0609 - ymax: 0.3591 - ymin: -0.1290
# Epoch 19/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0575 - E: 2.1316 - I: 0.3864 - Kinetic: 0.0124 - Potential: 2.1192 - mse_odd_even_sol: 0.0578 - loss: 16.7525 - ymax: 0.2875 - ymin: -0.0508
# Epoch 19: mse_odd_even_sol did not improve from 0.05480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0575 - E: 2.1316 - I: 0.3864 - Kinetic: 0.0124 - Potential: 2.1192 - mse_odd_even_sol: 0.0578 - loss: 16.7525 - ymax: 0.2875 - ymin: -0.0508
# Epoch 20/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0474 - E: 1.8213 - I: 0.2751 - Kinetic: 0.0038 - Potential: 1.8175 - mse_odd_even_sol: 0.0471 - loss: 11.1998 - ymax: 0.1969 - ymin: 0.0467
# Epoch 20: mse_odd_even_sol improved from 0.05480 to 0.04707, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 20: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - DE: 0.0474 - E: 1.8213 - I: 0.2751 - Kinetic: 0.0038 - Potential: 1.8175 - mse_odd_even_sol: 0.0471 - loss: 11.1998 - ymax: 0.1969 - ymin: 0.0467
# Epoch 21/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - DE: 0.0506 - E: 1.8302 - I: 0.2869 - Kinetic: 0.0193 - Potential: 1.8109 - mse_odd_even_sol: 0.0468 - loss: 12.2731 - ymax: 0.0978 - ymin: 0.1518
# Epoch 21: mse_odd_even_sol improved from 0.04707 to 0.04680, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 21: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - DE: 0.0506 - E: 1.8302 - I: 0.2869 - Kinetic: 0.0193 - Potential: 1.8109 - mse_odd_even_sol: 0.0468 - loss: 12.2731 - ymax: 0.0978 - ymin: 0.1518
# Epoch 22/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0619 - E: 2.0289 - I: 0.3726 - Kinetic: 0.0354 - Potential: 1.9935 - mse_odd_even_sol: 0.0528 - loss: 16.5777 - ymax: 0.0349 - ymin: 0.2203
# Epoch 22: mse_odd_even_sol did not improve from 0.04680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.0619 - E: 2.0289 - I: 0.3726 - Kinetic: 0.0354 - Potential: 1.9935 - mse_odd_even_sol: 0.0528 - loss: 16.5777 - ymax: 0.0349 - ymin: 0.2203
# Epoch 23/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0694 - E: 2.1131 - I: 0.4353 - Kinetic: 0.0407 - Potential: 2.0724 - mse_odd_even_sol: 0.0567 - loss: 18.4014 - ymax: 0.0098 - ymin: 0.2514
# Epoch 23: mse_odd_even_sol did not improve from 0.04680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0694 - E: 2.1131 - I: 0.4353 - Kinetic: 0.0407 - Potential: 2.0724 - mse_odd_even_sol: 0.0567 - loss: 18.4014 - ymax: 0.0098 - ymin: 0.2514
# Epoch 24/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0715 - E: 2.0958 - I: 0.4445 - Kinetic: 0.0393 - Potential: 2.0566 - mse_odd_even_sol: 0.0560 - loss: 18.1545 - ymax: 0.0159 - ymin: 0.2520
# Epoch 24: mse_odd_even_sol did not improve from 0.04680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0715 - E: 2.0958 - I: 0.4445 - Kinetic: 0.0393 - Potential: 2.0566 - mse_odd_even_sol: 0.0560 - loss: 18.1545 - ymax: 0.0159 - ymin: 0.2520
# Epoch 25/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0687 - E: 1.9947 - I: 0.4083 - Kinetic: 0.0319 - Potential: 1.9627 - mse_odd_even_sol: 0.0515 - loss: 16.1150 - ymax: 0.0496 - ymin: 0.2253
# Epoch 25: mse_odd_even_sol did not improve from 0.04680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0687 - E: 1.9947 - I: 0.4083 - Kinetic: 0.0319 - Potential: 1.9627 - mse_odd_even_sol: 0.0515 - loss: 16.1150 - ymax: 0.0496 - ymin: 0.2253
# Epoch 26/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0635 - E: 1.8426 - I: 0.3610 - Kinetic: 0.0187 - Potential: 1.8239 - mse_odd_even_sol: 0.0460 - loss: 12.7669 - ymax: 0.1084 - ymin: 0.1735
# Epoch 26: mse_odd_even_sol improved from 0.04680 to 0.04604, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 26: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - DE: 0.0635 - E: 1.8426 - I: 0.3610 - Kinetic: 0.0187 - Potential: 1.8239 - mse_odd_even_sol: 0.0460 - loss: 12.7669 - ymax: 0.1084 - ymin: 0.1735
# Epoch 27/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.0622 - E: 1.7799 - I: 0.3534 - Kinetic: 0.0063 - Potential: 1.7736 - mse_odd_even_sol: 0.0441 - loss: 10.8458 - ymax: 0.1837 - ymin: 0.1044
# Epoch 27: mse_odd_even_sol improved from 0.04604 to 0.04409, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 27: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - DE: 0.0622 - E: 1.7799 - I: 0.3534 - Kinetic: 0.0063 - Potential: 1.7736 - mse_odd_even_sol: 0.0441 - loss: 10.8458 - ymax: 0.1837 - ymin: 0.1044
# Epoch 28/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0685 - E: 1.8809 - I: 0.4039 - Kinetic: 0.0041 - Potential: 1.8767 - mse_odd_even_sol: 0.0473 - loss: 12.3480 - ymax: 0.2517 - ymin: 0.0410
# Epoch 28: mse_odd_even_sol did not improve from 0.04409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0685 - E: 1.8809 - I: 0.4039 - Kinetic: 0.0041 - Potential: 1.8767 - mse_odd_even_sol: 0.0473 - loss: 12.3480 - ymax: 0.2517 - ymin: 0.0410
# Epoch 29/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - DE: 0.0757 - E: 1.9862 - I: 0.4656 - Kinetic: 0.0066 - Potential: 1.9795 - mse_odd_even_sol: 0.0517 - loss: 14.3043 - ymax: 0.2945 - ymin: 0.0020
# Epoch 29: mse_odd_even_sol did not improve from 0.04409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.0757 - E: 1.9862 - I: 0.4656 - Kinetic: 0.0066 - Potential: 1.9795 - mse_odd_even_sol: 0.0517 - loss: 14.3043 - ymax: 0.2945 - ymin: 0.0020
# Epoch 30/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0791 - E: 2.0217 - I: 0.4948 - Kinetic: 0.0078 - Potential: 2.0138 - mse_odd_even_sol: 0.0535 - loss: 15.0296 - ymax: 0.3093 - ymin: -0.0097
# Epoch 30: mse_odd_even_sol did not improve from 0.04409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.0791 - E: 2.0217 - I: 0.4948 - Kinetic: 0.0078 - Potential: 2.0138 - mse_odd_even_sol: 0.0535 - loss: 15.0296 - ymax: 0.3093 - ymin: -0.0097
# Epoch 31/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0781 - E: 1.9880 - I: 0.4805 - Kinetic: 0.0068 - Potential: 1.9813 - mse_odd_even_sol: 0.0519 - loss: 14.4103 - ymax: 0.2986 - ymin: 0.0037
# Epoch 31: mse_odd_even_sol did not improve from 0.04409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.0781 - E: 1.9880 - I: 0.4805 - Kinetic: 0.0068 - Potential: 1.9813 - mse_odd_even_sol: 0.0519 - loss: 14.4103 - ymax: 0.2986 - ymin: 0.0037
# Epoch 32/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.0739 - E: 1.9020 - I: 0.4384 - Kinetic: 0.0046 - Potential: 1.8974 - mse_odd_even_sol: 0.0480 - loss: 12.8129 - ymax: 0.2656 - ymin: 0.0388
# Epoch 32: mse_odd_even_sol did not improve from 0.04409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0739 - E: 1.9020 - I: 0.4384 - Kinetic: 0.0046 - Potential: 1.8974 - mse_odd_even_sol: 0.0480 - loss: 12.8129 - ymax: 0.2656 - ymin: 0.0388
# Epoch 33/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - DE: 0.0696 - E: 1.8124 - I: 0.3996 - Kinetic: 0.0044 - Potential: 1.8080 - mse_odd_even_sol: 0.0447 - loss: 11.2966 - ymax: 0.2165 - ymin: 0.0892
# Epoch 33: mse_odd_even_sol did not improve from 0.04409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0696 - E: 1.8124 - I: 0.3996 - Kinetic: 0.0044 - Potential: 1.8080 - mse_odd_even_sol: 0.0447 - loss: 11.2966 - ymax: 0.2165 - ymin: 0.0892
# Epoch 34/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0689 - E: 1.7954 - I: 0.3905 - Kinetic: 0.0091 - Potential: 1.7863 - mse_odd_even_sol: 0.0441 - loss: 11.3316 - ymax: 0.1637 - ymin: 0.1421
# Epoch 34: mse_odd_even_sol improved from 0.04409 to 0.04408, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 34: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - DE: 0.0689 - E: 1.7954 - I: 0.3905 - Kinetic: 0.0091 - Potential: 1.7863 - mse_odd_even_sol: 0.0441 - loss: 11.3316 - ymax: 0.1637 - ymin: 0.1421
# Epoch 35/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0710 - E: 1.8422 - I: 0.4042 - Kinetic: 0.0154 - Potential: 1.8268 - mse_odd_even_sol: 0.0456 - loss: 12.5218 - ymax: 0.1240 - ymin: 0.1808
# Epoch 35: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.0710 - E: 1.8422 - I: 0.4042 - Kinetic: 0.0154 - Potential: 1.8268 - mse_odd_even_sol: 0.0456 - loss: 12.5218 - ymax: 0.1240 - ymin: 0.1808
# Epoch 36/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0720 - E: 1.8756 - I: 0.4124 - Kinetic: 0.0184 - Potential: 1.8572 - mse_odd_even_sol: 0.0468 - loss: 13.2328 - ymax: 0.1071 - ymin: 0.1964
# Epoch 36: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.0720 - E: 1.8756 - I: 0.4124 - Kinetic: 0.0184 - Potential: 1.8572 - mse_odd_even_sol: 0.0468 - loss: 13.2328 - ymax: 0.1071 - ymin: 0.1964
# Epoch 37/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0701 - E: 1.8631 - I: 0.4006 - Kinetic: 0.0170 - Potential: 1.8462 - mse_odd_even_sol: 0.0463 - loss: 12.8365 - ymax: 0.1138 - ymin: 0.1881
# Epoch 37: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0701 - E: 1.8631 - I: 0.4006 - Kinetic: 0.0170 - Potential: 1.8462 - mse_odd_even_sol: 0.0463 - loss: 12.8365 - ymax: 0.1138 - ymin: 0.1881
# Epoch 38/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0665 - E: 1.8219 - I: 0.3776 - Kinetic: 0.0119 - Potential: 1.8100 - mse_odd_even_sol: 0.0450 - loss: 11.7010 - ymax: 0.1405 - ymin: 0.1595
# Epoch 38: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0665 - E: 1.8219 - I: 0.3776 - Kinetic: 0.0119 - Potential: 1.8100 - mse_odd_even_sol: 0.0450 - loss: 11.7010 - ymax: 0.1405 - ymin: 0.1595
# Epoch 39/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - DE: 0.0638 - E: 1.8036 - I: 0.3633 - Kinetic: 0.0064 - Potential: 1.7972 - mse_odd_even_sol: 0.0446 - loss: 10.9143 - ymax: 0.1788 - ymin: 0.1187
# Epoch 39: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0638 - E: 1.8036 - I: 0.3633 - Kinetic: 0.0064 - Potential: 1.7972 - mse_odd_even_sol: 0.0446 - loss: 10.9143 - ymax: 0.1788 - ymin: 0.1187
# Epoch 40/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - DE: 0.0635 - E: 1.8385 - I: 0.3668 - Kinetic: 0.0038 - Potential: 1.8347 - mse_odd_even_sol: 0.0458 - loss: 11.2195 - ymax: 0.2150 - ymin: 0.0793
# Epoch 40: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0635 - E: 1.8385 - I: 0.3668 - Kinetic: 0.0038 - Potential: 1.8347 - mse_odd_even_sol: 0.0458 - loss: 11.2195 - ymax: 0.2150 - ymin: 0.0793
# Epoch 41/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.0636 - E: 1.8861 - I: 0.3742 - Kinetic: 0.0036 - Potential: 1.8825 - mse_odd_even_sol: 0.0475 - loss: 11.9031 - ymax: 0.2368 - ymin: 0.0538
# Epoch 41: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0636 - E: 1.8861 - I: 0.3742 - Kinetic: 0.0036 - Potential: 1.8825 - mse_odd_even_sol: 0.0475 - loss: 11.9031 - ymax: 0.2368 - ymin: 0.0538
# Epoch 42/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0622 - E: 1.9008 - I: 0.3679 - Kinetic: 0.0037 - Potential: 1.8971 - mse_odd_even_sol: 0.0480 - loss: 12.0507 - ymax: 0.2390 - ymin: 0.0476
# Epoch 42: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.0622 - E: 1.9008 - I: 0.3679 - Kinetic: 0.0037 - Potential: 1.8971 - mse_odd_even_sol: 0.0480 - loss: 12.0507 - ymax: 0.2390 - ymin: 0.0476
# Epoch 43/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.0591 - E: 1.8742 - I: 0.3454 - Kinetic: 0.0033 - Potential: 1.8709 - mse_odd_even_sol: 0.0472 - loss: 11.4925 - ymax: 0.2223 - ymin: 0.0604
# Epoch 43: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0591 - E: 1.8742 - I: 0.3454 - Kinetic: 0.0033 - Potential: 1.8709 - mse_odd_even_sol: 0.0472 - loss: 11.4925 - ymax: 0.2223 - ymin: 0.0604
# Epoch 44/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0554 - E: 1.8327 - I: 0.3188 - Kinetic: 0.0039 - Potential: 1.8287 - mse_odd_even_sol: 0.0461 - loss: 10.7516 - ymax: 0.1914 - ymin: 0.0872
# Epoch 44: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0554 - E: 1.8327 - I: 0.3188 - Kinetic: 0.0039 - Potential: 1.8287 - mse_odd_even_sol: 0.0461 - loss: 10.7516 - ymax: 0.1914 - ymin: 0.0872
# Epoch 45/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0531 - E: 1.8202 - I: 0.3022 - Kinetic: 0.0071 - Potential: 1.8131 - mse_odd_even_sol: 0.0460 - loss: 10.6465 - ymax: 0.1562 - ymin: 0.1180
# Epoch 45: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0531 - E: 1.8202 - I: 0.3022 - Kinetic: 0.0071 - Potential: 1.8131 - mse_odd_even_sol: 0.0460 - loss: 10.6465 - ymax: 0.1562 - ymin: 0.1180
# Epoch 46/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0519 - E: 1.8408 - I: 0.2956 - Kinetic: 0.0111 - Potential: 1.8297 - mse_odd_even_sol: 0.0467 - loss: 11.1313 - ymax: 0.1297 - ymin: 0.1398
# Epoch 46: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0519 - E: 1.8408 - I: 0.2956 - Kinetic: 0.0111 - Potential: 1.8297 - mse_odd_even_sol: 0.0467 - loss: 11.1313 - ymax: 0.1297 - ymin: 0.1398
# Epoch 47/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0503 - E: 1.8538 - I: 0.2871 - Kinetic: 0.0125 - Potential: 1.8414 - mse_odd_even_sol: 0.0472 - loss: 11.3236 - ymax: 0.1205 - ymin: 0.1443
# Epoch 47: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0503 - E: 1.8538 - I: 0.2871 - Kinetic: 0.0125 - Potential: 1.8414 - mse_odd_even_sol: 0.0472 - loss: 11.3236 - ymax: 0.1205 - ymin: 0.1443
# Epoch 48/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.0478 - E: 1.8421 - I: 0.2722 - Kinetic: 0.0101 - Potential: 1.8319 - mse_odd_even_sol: 0.0472 - loss: 10.8837 - ymax: 0.1300 - ymin: 0.1303
# Epoch 48: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0478 - E: 1.8421 - I: 0.2722 - Kinetic: 0.0101 - Potential: 1.8319 - mse_odd_even_sol: 0.0472 - loss: 10.8837 - ymax: 0.1300 - ymin: 0.1303
# Epoch 49/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0453 - E: 1.8326 - I: 0.2590 - Kinetic: 0.0060 - Potential: 1.8266 - mse_odd_even_sol: 0.0473 - loss: 10.3871 - ymax: 0.1521 - ymin: 0.1037
# Epoch 49: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0453 - E: 1.8326 - I: 0.2590 - Kinetic: 0.0060 - Potential: 1.8266 - mse_odd_even_sol: 0.0473 - loss: 10.3871 - ymax: 0.1521 - ymin: 0.1037
# Epoch 50/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0439 - E: 1.8540 - I: 0.2539 - Kinetic: 0.0032 - Potential: 1.8508 - mse_odd_even_sol: 0.0481 - loss: 10.5003 - ymax: 0.1751 - ymin: 0.0761
# Epoch 50: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0439 - E: 1.8540 - I: 0.2539 - Kinetic: 0.0032 - Potential: 1.8508 - mse_odd_even_sol: 0.0481 - loss: 10.5003 - ymax: 0.1751 - ymin: 0.0761
# Epoch 51/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0428 - E: 1.8821 - I: 0.2504 - Kinetic: 0.0024 - Potential: 1.8796 - mse_odd_even_sol: 0.0491 - loss: 10.8463 - ymax: 0.1867 - ymin: 0.0598
# Epoch 51: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0428 - E: 1.8821 - I: 0.2504 - Kinetic: 0.0024 - Potential: 1.8796 - mse_odd_even_sol: 0.0491 - loss: 10.8463 - ymax: 0.1867 - ymin: 0.0598
# Epoch 52/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0410 - E: 1.8819 - I: 0.2397 - Kinetic: 0.0023 - Potential: 1.8796 - mse_odd_even_sol: 0.0493 - loss: 10.7575 - ymax: 0.1818 - ymin: 0.0604
# Epoch 52: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0410 - E: 1.8819 - I: 0.2397 - Kinetic: 0.0023 - Potential: 1.8796 - mse_odd_even_sol: 0.0493 - loss: 10.7575 - ymax: 0.1818 - ymin: 0.0604
# Epoch 53/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - DE: 0.0388 - E: 1.8590 - I: 0.2239 - Kinetic: 0.0032 - Potential: 1.8558 - mse_odd_even_sol: 0.0491 - loss: 10.3293 - ymax: 0.1621 - ymin: 0.0759
# Epoch 53: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0388 - E: 1.8590 - I: 0.2239 - Kinetic: 0.0032 - Potential: 1.8558 - mse_odd_even_sol: 0.0491 - loss: 10.3293 - ymax: 0.1621 - ymin: 0.0759
# Epoch 54/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.0371 - E: 1.8505 - I: 0.2121 - Kinetic: 0.0061 - Potential: 1.8443 - mse_odd_even_sol: 0.0492 - loss: 10.2417 - ymax: 0.1366 - ymin: 0.0973
# Epoch 54: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0371 - E: 1.8505 - I: 0.2121 - Kinetic: 0.0061 - Potential: 1.8443 - mse_odd_even_sol: 0.0492 - loss: 10.2417 - ymax: 0.1366 - ymin: 0.0973
# Epoch 55/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.0360 - E: 1.8642 - I: 0.2056 - Kinetic: 0.0093 - Potential: 1.8548 - mse_odd_even_sol: 0.0498 - loss: 10.5381 - ymax: 0.1186 - ymin: 0.1113
# Epoch 55: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0360 - E: 1.8642 - I: 0.2056 - Kinetic: 0.0093 - Potential: 1.8548 - mse_odd_even_sol: 0.0498 - loss: 10.5381 - ymax: 0.1186 - ymin: 0.1113
# Epoch 56/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0346 - E: 1.8683 - I: 0.1979 - Kinetic: 0.0093 - Potential: 1.8589 - mse_odd_even_sol: 0.0502 - loss: 10.5188 - ymax: 0.1165 - ymin: 0.1095
# Epoch 56: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0346 - E: 1.8683 - I: 0.1979 - Kinetic: 0.0093 - Potential: 1.8589 - mse_odd_even_sol: 0.0502 - loss: 10.5188 - ymax: 0.1165 - ymin: 0.1095
# Epoch 57/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0330 - E: 1.8621 - I: 0.1891 - Kinetic: 0.0061 - Potential: 1.8559 - mse_odd_even_sol: 0.0504 - loss: 10.1811 - ymax: 0.1293 - ymin: 0.0930
# Epoch 57: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0330 - E: 1.8621 - I: 0.1891 - Kinetic: 0.0061 - Potential: 1.8559 - mse_odd_even_sol: 0.0504 - loss: 10.1811 - ymax: 0.1293 - ymin: 0.0930
# Epoch 58/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - DE: 0.0318 - E: 1.8742 - I: 0.1842 - Kinetic: 0.0030 - Potential: 1.8713 - mse_odd_even_sol: 0.0510 - loss: 10.1803 - ymax: 0.1467 - ymin: 0.0720
# Epoch 58: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - DE: 0.0318 - E: 1.8742 - I: 0.1842 - Kinetic: 0.0030 - Potential: 1.8713 - mse_odd_even_sol: 0.0510 - loss: 10.1803 - ymax: 0.1467 - ymin: 0.0720
# Epoch 59/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0309 - E: 1.8937 - I: 0.1808 - Kinetic: 0.0018 - Potential: 1.8919 - mse_odd_even_sol: 0.0517 - loss: 10.4023 - ymax: 0.1554 - ymin: 0.0597
# Epoch 59: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0309 - E: 1.8937 - I: 0.1808 - Kinetic: 0.0018 - Potential: 1.8919 - mse_odd_even_sol: 0.0517 - loss: 10.4023 - ymax: 0.1554 - ymin: 0.0597
# Epoch 60/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0297 - E: 1.8907 - I: 0.1733 - Kinetic: 0.0020 - Potential: 1.8887 - mse_odd_even_sol: 0.0519 - loss: 10.2816 - ymax: 0.1490 - ymin: 0.0629
# Epoch 60: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0297 - E: 1.8907 - I: 0.1733 - Kinetic: 0.0020 - Potential: 1.8887 - mse_odd_even_sol: 0.0519 - loss: 10.2816 - ymax: 0.1490 - ymin: 0.0629
# Epoch 61/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0285 - E: 1.8787 - I: 0.1644 - Kinetic: 0.0041 - Potential: 1.8747 - mse_odd_even_sol: 0.0520 - loss: 10.0636 - ymax: 0.1314 - ymin: 0.0775
# Epoch 61: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - DE: 0.0285 - E: 1.8787 - I: 0.1644 - Kinetic: 0.0041 - Potential: 1.8747 - mse_odd_even_sol: 0.0520 - loss: 10.0636 - ymax: 0.1314 - ymin: 0.0775
# Epoch 62/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.0276 - E: 1.8848 - I: 0.1589 - Kinetic: 0.0073 - Potential: 1.8775 - mse_odd_even_sol: 0.0524 - loss: 10.2061 - ymax: 0.1144 - ymin: 0.0916
# Epoch 62: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0276 - E: 1.8848 - I: 0.1589 - Kinetic: 0.0073 - Potential: 1.8775 - mse_odd_even_sol: 0.0524 - loss: 10.2061 - ymax: 0.1144 - ymin: 0.0916
# Epoch 63/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0268 - E: 1.8914 - I: 0.1542 - Kinetic: 0.0080 - Potential: 1.8834 - mse_odd_even_sol: 0.0528 - loss: 10.2668 - ymax: 0.1099 - ymin: 0.0932
# Epoch 63: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0268 - E: 1.8914 - I: 0.1542 - Kinetic: 0.0080 - Potential: 1.8834 - mse_odd_even_sol: 0.0528 - loss: 10.2668 - ymax: 0.1099 - ymin: 0.0932
# Epoch 64/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0258 - E: 1.8895 - I: 0.1489 - Kinetic: 0.0053 - Potential: 1.8843 - mse_odd_even_sol: 0.0530 - loss: 10.0573 - ymax: 0.1194 - ymin: 0.0810
# Epoch 64: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.0258 - E: 1.8895 - I: 0.1489 - Kinetic: 0.0053 - Potential: 1.8843 - mse_odd_even_sol: 0.0530 - loss: 10.0573 - ymax: 0.1194 - ymin: 0.0810
# Epoch 65/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.0251 - E: 1.9008 - I: 0.1459 - Kinetic: 0.0024 - Potential: 1.8984 - mse_odd_even_sol: 0.0535 - loss: 10.0947 - ymax: 0.1326 - ymin: 0.0652
# Epoch 65: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0251 - E: 1.9008 - I: 0.1459 - Kinetic: 0.0024 - Potential: 1.8984 - mse_odd_even_sol: 0.0535 - loss: 10.0947 - ymax: 0.1326 - ymin: 0.0652
# Epoch 66/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0244 - E: 1.9120 - I: 0.1429 - Kinetic: 0.0016 - Potential: 1.9105 - mse_odd_even_sol: 0.0540 - loss: 10.2022 - ymax: 0.1366 - ymin: 0.0587
# Epoch 66: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0244 - E: 1.9120 - I: 0.1429 - Kinetic: 0.0016 - Potential: 1.9105 - mse_odd_even_sol: 0.0540 - loss: 10.2022 - ymax: 0.1366 - ymin: 0.0587
# Epoch 67/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0236 - E: 1.9064 - I: 0.1374 - Kinetic: 0.0026 - Potential: 1.9037 - mse_odd_even_sol: 0.0541 - loss: 10.0488 - ymax: 0.1272 - ymin: 0.0659
# Epoch 67: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0236 - E: 1.9064 - I: 0.1374 - Kinetic: 0.0026 - Potential: 1.9037 - mse_odd_even_sol: 0.0541 - loss: 10.0488 - ymax: 0.1272 - ymin: 0.0659
# Epoch 68/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.0229 - E: 1.9062 - I: 0.1327 - Kinetic: 0.0055 - Potential: 1.9007 - mse_odd_even_sol: 0.0544 - loss: 10.0435 - ymax: 0.1125 - ymin: 0.0785
# Epoch 68: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - DE: 0.0229 - E: 1.9062 - I: 0.1327 - Kinetic: 0.0055 - Potential: 1.9007 - mse_odd_even_sol: 0.0544 - loss: 10.0435 - ymax: 0.1125 - ymin: 0.0785
# Epoch 69/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0224 - E: 1.9136 - I: 0.1296 - Kinetic: 0.0070 - Potential: 1.9066 - mse_odd_even_sol: 0.0547 - loss: 10.1426 - ymax: 0.1055 - ymin: 0.0834
# Epoch 69: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0224 - E: 1.9136 - I: 0.1296 - Kinetic: 0.0070 - Potential: 1.9066 - mse_odd_even_sol: 0.0547 - loss: 10.1426 - ymax: 0.1055 - ymin: 0.0834
# Epoch 70/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0217 - E: 1.9141 - I: 0.1261 - Kinetic: 0.0051 - Potential: 1.9091 - mse_odd_even_sol: 0.0550 - loss: 10.0169 - ymax: 0.1115 - ymin: 0.0755
# Epoch 70: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0217 - E: 1.9141 - I: 0.1261 - Kinetic: 0.0051 - Potential: 1.9091 - mse_odd_even_sol: 0.0550 - loss: 10.0169 - ymax: 0.1115 - ymin: 0.0755
# Epoch 71/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0212 - E: 1.9226 - I: 0.1239 - Kinetic: 0.0023 - Potential: 1.9202 - mse_odd_even_sol: 0.0553 - loss: 10.0303 - ymax: 0.1222 - ymin: 0.0629
# Epoch 71: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0212 - E: 1.9226 - I: 0.1239 - Kinetic: 0.0023 - Potential: 1.9202 - mse_odd_even_sol: 0.0553 - loss: 10.0303 - ymax: 0.1222 - ymin: 0.0629
# Epoch 72/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0207 - E: 1.9307 - I: 0.1217 - Kinetic: 0.0016 - Potential: 1.9291 - mse_odd_even_sol: 0.0557 - loss: 10.0915 - ymax: 0.1248 - ymin: 0.0585
# Epoch 72: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.0207 - E: 1.9307 - I: 0.1217 - Kinetic: 0.0016 - Potential: 1.9291 - mse_odd_even_sol: 0.0557 - loss: 10.0915 - ymax: 0.1248 - ymin: 0.0585
# Epoch 73/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0202 - E: 1.9278 - I: 0.1178 - Kinetic: 0.0031 - Potential: 1.9247 - mse_odd_even_sol: 0.0558 - loss: 9.9844 - ymax: 0.1160 - ymin: 0.0657
# Epoch 73: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0202 - E: 1.9278 - I: 0.1178 - Kinetic: 0.0031 - Potential: 1.9247 - mse_odd_even_sol: 0.0558 - loss: 9.9844 - ymax: 0.1160 - ymin: 0.0657
# Epoch 74/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0198 - E: 1.9317 - I: 0.1150 - Kinetic: 0.0056 - Potential: 1.9261 - mse_odd_even_sol: 0.0561 - loss: 10.0319 - ymax: 0.1051 - ymin: 0.0751
# Epoch 74: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0198 - E: 1.9317 - I: 0.1150 - Kinetic: 0.0056 - Potential: 1.9261 - mse_odd_even_sol: 0.0561 - loss: 10.0319 - ymax: 0.1051 - ymin: 0.0751
# Epoch 75/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.0193 - E: 1.9362 - I: 0.1126 - Kinetic: 0.0058 - Potential: 1.9304 - mse_odd_even_sol: 0.0563 - loss: 10.0385 - ymax: 0.1036 - ymin: 0.0750
# Epoch 75: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0193 - E: 1.9362 - I: 0.1126 - Kinetic: 0.0058 - Potential: 1.9304 - mse_odd_even_sol: 0.0563 - loss: 10.0385 - ymax: 0.1036 - ymin: 0.0750
# Epoch 76/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0189 - E: 1.9395 - I: 0.1105 - Kinetic: 0.0033 - Potential: 1.9362 - mse_odd_even_sol: 0.0566 - loss: 9.9678 - ymax: 0.1116 - ymin: 0.0656
# Epoch 76: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0189 - E: 1.9395 - I: 0.1105 - Kinetic: 0.0033 - Potential: 1.9362 - mse_odd_even_sol: 0.0566 - loss: 9.9678 - ymax: 0.1116 - ymin: 0.0656
# Epoch 77/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0185 - E: 1.9484 - I: 0.1091 - Kinetic: 0.0017 - Potential: 1.9468 - mse_odd_even_sol: 0.0569 - loss: 10.0333 - ymax: 0.1176 - ymin: 0.0583
# Epoch 77: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.0185 - E: 1.9484 - I: 0.1091 - Kinetic: 0.0017 - Potential: 1.9468 - mse_odd_even_sol: 0.0569 - loss: 10.0333 - ymax: 0.1176 - ymin: 0.0583
# Epoch 78/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0181 - E: 1.9496 - I: 0.1066 - Kinetic: 0.0024 - Potential: 1.9472 - mse_odd_even_sol: 0.0571 - loss: 9.9831 - ymax: 0.1133 - ymin: 0.0613
# Epoch 78: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0181 - E: 1.9496 - I: 0.1066 - Kinetic: 0.0024 - Potential: 1.9472 - mse_odd_even_sol: 0.0571 - loss: 9.9831 - ymax: 0.1133 - ymin: 0.0613
# Epoch 79/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0178 - E: 1.9519 - I: 0.1041 - Kinetic: 0.0047 - Potential: 1.9473 - mse_odd_even_sol: 0.0572 - loss: 9.9804 - ymax: 0.1039 - ymin: 0.0695
# Epoch 79: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0178 - E: 1.9519 - I: 0.1041 - Kinetic: 0.0047 - Potential: 1.9473 - mse_odd_even_sol: 0.0572 - loss: 9.9804 - ymax: 0.1039 - ymin: 0.0695
# Epoch 80/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0175 - E: 1.9571 - I: 0.1023 - Kinetic: 0.0054 - Potential: 1.9517 - mse_odd_even_sol: 0.0575 - loss: 10.0071 - ymax: 0.1010 - ymin: 0.0713
# Epoch 80: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0175 - E: 1.9571 - I: 0.1023 - Kinetic: 0.0054 - Potential: 1.9517 - mse_odd_even_sol: 0.0575 - loss: 10.0071 - ymax: 0.1010 - ymin: 0.0713
# Epoch 81/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0171 - E: 1.9605 - I: 0.1007 - Kinetic: 0.0033 - Potential: 1.9572 - mse_odd_even_sol: 0.0577 - loss: 9.9533 - ymax: 0.1071 - ymin: 0.0642
# Epoch 81: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0171 - E: 1.9605 - I: 0.1007 - Kinetic: 0.0033 - Potential: 1.9572 - mse_odd_even_sol: 0.0577 - loss: 9.9533 - ymax: 0.1071 - ymin: 0.0642
# Epoch 82/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0168 - E: 1.9680 - I: 0.0996 - Kinetic: 0.0018 - Potential: 1.9662 - mse_odd_even_sol: 0.0580 - loss: 9.9961 - ymax: 0.1122 - ymin: 0.0580
# Epoch 82: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0168 - E: 1.9680 - I: 0.0996 - Kinetic: 0.0018 - Potential: 1.9662 - mse_odd_even_sol: 0.0580 - loss: 9.9961 - ymax: 0.1122 - ymin: 0.0580
# Epoch 83/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0165 - E: 1.9701 - I: 0.0976 - Kinetic: 0.0025 - Potential: 1.9676 - mse_odd_even_sol: 0.0581 - loss: 9.9594 - ymax: 0.1085 - ymin: 0.0608
# Epoch 83: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0165 - E: 1.9701 - I: 0.0976 - Kinetic: 0.0025 - Potential: 1.9676 - mse_odd_even_sol: 0.0581 - loss: 9.9594 - ymax: 0.1085 - ymin: 0.0608
# Epoch 84/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0163 - E: 1.9738 - I: 0.0958 - Kinetic: 0.0046 - Potential: 1.9692 - mse_odd_even_sol: 0.0583 - loss: 9.9681 - ymax: 0.1009 - ymin: 0.0674
# Epoch 84: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0163 - E: 1.9738 - I: 0.0958 - Kinetic: 0.0046 - Potential: 1.9692 - mse_odd_even_sol: 0.0583 - loss: 9.9681 - ymax: 0.1009 - ymin: 0.0674
# Epoch 85/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0160 - E: 1.9784 - I: 0.0944 - Kinetic: 0.0047 - Potential: 1.9737 - mse_odd_even_sol: 0.0585 - loss: 9.9701 - ymax: 0.1000 - ymin: 0.0675
# Epoch 85: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - DE: 0.0160 - E: 1.9784 - I: 0.0944 - Kinetic: 0.0047 - Potential: 1.9737 - mse_odd_even_sol: 0.0585 - loss: 9.9701 - ymax: 0.1000 - ymin: 0.0675
# Epoch 86/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.0157 - E: 1.9830 - I: 0.0932 - Kinetic: 0.0027 - Potential: 1.9803 - mse_odd_even_sol: 0.0587 - loss: 9.9473 - ymax: 0.1058 - ymin: 0.0609
# Epoch 86: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0157 - E: 1.9830 - I: 0.0932 - Kinetic: 0.0027 - Potential: 1.9803 - mse_odd_even_sol: 0.0587 - loss: 9.9473 - ymax: 0.1058 - ymin: 0.0609
# Epoch 87/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0155 - E: 1.9890 - I: 0.0922 - Kinetic: 0.0019 - Potential: 1.9872 - mse_odd_even_sol: 0.0589 - loss: 9.9705 - ymax: 0.1081 - ymin: 0.0577
# Epoch 87: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0155 - E: 1.9890 - I: 0.0922 - Kinetic: 0.0019 - Potential: 1.9872 - mse_odd_even_sol: 0.0589 - loss: 9.9705 - ymax: 0.1081 - ymin: 0.0577
# Epoch 88/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0152 - E: 1.9916 - I: 0.0905 - Kinetic: 0.0032 - Potential: 1.9884 - mse_odd_even_sol: 0.0591 - loss: 9.9388 - ymax: 0.1029 - ymin: 0.0622
# Epoch 88: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0152 - E: 1.9916 - I: 0.0905 - Kinetic: 0.0032 - Potential: 1.9884 - mse_odd_even_sol: 0.0591 - loss: 9.9388 - ymax: 0.1029 - ymin: 0.0622
# Epoch 89/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0150 - E: 1.9967 - I: 0.0892 - Kinetic: 0.0046 - Potential: 1.9922 - mse_odd_even_sol: 0.0592 - loss: 9.9621 - ymax: 0.0982 - ymin: 0.0662
# Epoch 89: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0150 - E: 1.9967 - I: 0.0892 - Kinetic: 0.0046 - Potential: 1.9922 - mse_odd_even_sol: 0.0592 - loss: 9.9621 - ymax: 0.0982 - ymin: 0.0662
# Epoch 90/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.0148 - E: 2.0008 - I: 0.0881 - Kinetic: 0.0035 - Potential: 1.9973 - mse_odd_even_sol: 0.0594 - loss: 9.9372 - ymax: 0.1008 - ymin: 0.0629
# Epoch 90: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0148 - E: 2.0008 - I: 0.0881 - Kinetic: 0.0035 - Potential: 1.9973 - mse_odd_even_sol: 0.0594 - loss: 9.9372 - ymax: 0.1008 - ymin: 0.0629
# Epoch 91/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0146 - E: 2.0068 - I: 0.0873 - Kinetic: 0.0020 - Potential: 2.0047 - mse_odd_even_sol: 0.0596 - loss: 9.9510 - ymax: 0.1051 - ymin: 0.0579
# Epoch 91: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - DE: 0.0146 - E: 2.0068 - I: 0.0873 - Kinetic: 0.0020 - Potential: 2.0047 - mse_odd_even_sol: 0.0596 - loss: 9.9510 - ymax: 0.1051 - ymin: 0.0579
# Epoch 92/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0144 - E: 2.0109 - I: 0.0861 - Kinetic: 0.0025 - Potential: 2.0084 - mse_odd_even_sol: 0.0598 - loss: 9.9370 - ymax: 0.1032 - ymin: 0.0593
# Epoch 92: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0144 - E: 2.0109 - I: 0.0861 - Kinetic: 0.0025 - Potential: 2.0084 - mse_odd_even_sol: 0.0598 - loss: 9.9370 - ymax: 0.1032 - ymin: 0.0593
# Epoch 93/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.0142 - E: 2.0155 - I: 0.0849 - Kinetic: 0.0040 - Potential: 2.0114 - mse_odd_even_sol: 0.0599 - loss: 9.9411 - ymax: 0.0981 - ymin: 0.0639
# Epoch 93: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0142 - E: 2.0155 - I: 0.0849 - Kinetic: 0.0040 - Potential: 2.0114 - mse_odd_even_sol: 0.0599 - loss: 9.9411 - ymax: 0.0981 - ymin: 0.0639
# Epoch 94/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0140 - E: 2.0203 - I: 0.0839 - Kinetic: 0.0038 - Potential: 2.0164 - mse_odd_even_sol: 0.0601 - loss: 9.9354 - ymax: 0.0983 - ymin: 0.0631
# Epoch 94: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.0140 - E: 2.0203 - I: 0.0839 - Kinetic: 0.0038 - Potential: 2.0164 - mse_odd_even_sol: 0.0601 - loss: 9.9354 - ymax: 0.0983 - ymin: 0.0631
# Epoch 95/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0138 - E: 2.0256 - I: 0.0831 - Kinetic: 0.0023 - Potential: 2.0233 - mse_odd_even_sol: 0.0603 - loss: 9.9335 - ymax: 0.1024 - ymin: 0.0585
# Epoch 95: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0138 - E: 2.0256 - I: 0.0831 - Kinetic: 0.0023 - Potential: 2.0233 - mse_odd_even_sol: 0.0603 - loss: 9.9335 - ymax: 0.1024 - ymin: 0.0585
# Epoch 96/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0136 - E: 2.0307 - I: 0.0822 - Kinetic: 0.0023 - Potential: 2.0284 - mse_odd_even_sol: 0.0604 - loss: 9.9323 - ymax: 0.1021 - ymin: 0.0582
# Epoch 96: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0136 - E: 2.0307 - I: 0.0822 - Kinetic: 0.0023 - Potential: 2.0284 - mse_odd_even_sol: 0.0604 - loss: 9.9323 - ymax: 0.1021 - ymin: 0.0582
# Epoch 97/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0135 - E: 2.0353 - I: 0.0811 - Kinetic: 0.0037 - Potential: 2.0317 - mse_odd_even_sol: 0.0606 - loss: 9.9276 - ymax: 0.0978 - ymin: 0.0622
# Epoch 97: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.0135 - E: 2.0353 - I: 0.0811 - Kinetic: 0.0037 - Potential: 2.0317 - mse_odd_even_sol: 0.0606 - loss: 9.9276 - ymax: 0.0978 - ymin: 0.0622
# Epoch 98/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0133 - E: 2.0406 - I: 0.0803 - Kinetic: 0.0038 - Potential: 2.0368 - mse_odd_even_sol: 0.0607 - loss: 9.9281 - ymax: 0.0971 - ymin: 0.0624
# Epoch 98: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0133 - E: 2.0406 - I: 0.0803 - Kinetic: 0.0038 - Potential: 2.0368 - mse_odd_even_sol: 0.0607 - loss: 9.9281 - ymax: 0.0971 - ymin: 0.0624
# Epoch 99/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.0131 - E: 2.0459 - I: 0.0796 - Kinetic: 0.0025 - Potential: 2.0434 - mse_odd_even_sol: 0.0609 - loss: 9.9229 - ymax: 0.1006 - ymin: 0.0585
# Epoch 99: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.0131 - E: 2.0459 - I: 0.0796 - Kinetic: 0.0025 - Potential: 2.0434 - mse_odd_even_sol: 0.0609 - loss: 9.9229 - ymax: 0.1006 - ymin: 0.0585
# Epoch 100/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.0129 - E: 2.0513 - I: 0.0788 - Kinetic: 0.0023 - Potential: 2.0490 - mse_odd_even_sol: 0.0611 - loss: 9.9233 - ymax: 0.1007 - ymin: 0.0580
# Epoch 100: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0129 - E: 2.0513 - I: 0.0788 - Kinetic: 0.0023 - Potential: 2.0490 - mse_odd_even_sol: 0.0611 - loss: 9.9233 - ymax: 0.1007 - ymin: 0.0580
# Epoch 101/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.0128 - E: 2.0564 - I: 0.0779 - Kinetic: 0.0035 - Potential: 2.0529 - mse_odd_even_sol: 0.0612 - loss: 9.9189 - ymax: 0.0970 - ymin: 0.0613
# Epoch 101: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0128 - E: 2.0564 - I: 0.0779 - Kinetic: 0.0035 - Potential: 2.0529 - mse_odd_even_sol: 0.0612 - loss: 9.9189 - ymax: 0.0970 - ymin: 0.0613
# Epoch 102/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0127 - E: 2.0619 - I: 0.0771 - Kinetic: 0.0036 - Potential: 2.0583 - mse_odd_even_sol: 0.0614 - loss: 9.9180 - ymax: 0.0966 - ymin: 0.0614
# Epoch 102: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0127 - E: 2.0619 - I: 0.0771 - Kinetic: 0.0036 - Potential: 2.0583 - mse_odd_even_sol: 0.0614 - loss: 9.9180 - ymax: 0.0966 - ymin: 0.0614
# Epoch 103/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0125 - E: 2.0675 - I: 0.0765 - Kinetic: 0.0025 - Potential: 2.0651 - mse_odd_even_sol: 0.0615 - loss: 9.9152 - ymax: 0.0996 - ymin: 0.0582
# Epoch 103: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.0125 - E: 2.0675 - I: 0.0765 - Kinetic: 0.0025 - Potential: 2.0651 - mse_odd_even_sol: 0.0615 - loss: 9.9152 - ymax: 0.0996 - ymin: 0.0582
# Epoch 104/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.0123 - E: 2.0731 - I: 0.0758 - Kinetic: 0.0025 - Potential: 2.0706 - mse_odd_even_sol: 0.0617 - loss: 9.9126 - ymax: 0.0992 - ymin: 0.0582
# Epoch 104: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0123 - E: 2.0731 - I: 0.0758 - Kinetic: 0.0025 - Potential: 2.0706 - mse_odd_even_sol: 0.0617 - loss: 9.9126 - ymax: 0.0992 - ymin: 0.0582
# Epoch 105/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0122 - E: 2.0788 - I: 0.0750 - Kinetic: 0.0036 - Potential: 2.0752 - mse_odd_even_sol: 0.0618 - loss: 9.9117 - ymax: 0.0962 - ymin: 0.0610
# Epoch 105: mse_odd_even_sol did not improve from 0.04408
# ...
# Epoch 790/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0108 - E: 3.3063 - I: 0.8721 - Kinetic: 0.4256 - Potential: 2.8807 - mse_odd_even_sol: 0.1540 - loss: 1.8108 - ymax: 0.2370 - ymin: -0.0275
# Epoch 790: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - DE: 0.0108 - E: 3.3063 - I: 0.8721 - Kinetic: 0.4256 - Potential: 2.8807 - mse_odd_even_sol: 0.1540 - loss: 1.8108 - ymax: 0.2370 - ymin: -0.0275
# Epoch 791/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0106 - E: 3.3103 - I: 0.8731 - Kinetic: 0.4282 - Potential: 2.8821 - mse_odd_even_sol: 0.1541 - loss: 1.7853 - ymax: 0.2348 - ymin: -0.0287
# Epoch 791: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0106 - E: 3.3103 - I: 0.8731 - Kinetic: 0.4282 - Potential: 2.8821 - mse_odd_even_sol: 0.1541 - loss: 1.7853 - ymax: 0.2348 - ymin: -0.0287
# Epoch 792/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0105 - E: 3.3144 - I: 0.8741 - Kinetic: 0.4309 - Potential: 2.8835 - mse_odd_even_sol: 0.1542 - loss: 1.7597 - ymax: 0.2326 - ymin: -0.0298
# Epoch 792: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0105 - E: 3.3144 - I: 0.8741 - Kinetic: 0.4309 - Potential: 2.8835 - mse_odd_even_sol: 0.1542 - loss: 1.7597 - ymax: 0.2326 - ymin: -0.0298
# Epoch 793/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.0104 - E: 3.3185 - I: 0.8752 - Kinetic: 0.4336 - Potential: 2.8849 - mse_odd_even_sol: 0.1543 - loss: 1.7341 - ymax: 0.2303 - ymin: -0.0308
# Epoch 793: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.0104 - E: 3.3185 - I: 0.8752 - Kinetic: 0.4336 - Potential: 2.8849 - mse_odd_even_sol: 0.1543 - loss: 1.7341 - ymax: 0.2303 - ymin: -0.0308
# Epoch 794/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0102 - E: 3.3226 - I: 0.8762 - Kinetic: 0.4364 - Potential: 2.8862 - mse_odd_even_sol: 0.1544 - loss: 1.7085 - ymax: 0.2279 - ymin: -0.0318
# Epoch 794: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0102 - E: 3.3226 - I: 0.8762 - Kinetic: 0.4364 - Potential: 2.8862 - mse_odd_even_sol: 0.1544 - loss: 1.7085 - ymax: 0.2279 - ymin: -0.0318
# Epoch 795/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0101 - E: 3.3267 - I: 0.8772 - Kinetic: 0.4392 - Potential: 2.8876 - mse_odd_even_sol: 0.1546 - loss: 1.6830 - ymax: 0.2256 - ymin: -0.0327
# Epoch 795: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.0101 - E: 3.3267 - I: 0.8772 - Kinetic: 0.4392 - Potential: 2.8876 - mse_odd_even_sol: 0.1546 - loss: 1.6830 - ymax: 0.2256 - ymin: -0.0327
# Epoch 796/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0100 - E: 3.3308 - I: 0.8783 - Kinetic: 0.4420 - Potential: 2.8888 - mse_odd_even_sol: 0.1547 - loss: 1.6574 - ymax: 0.2232 - ymin: -0.0336
# Epoch 796: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0100 - E: 3.3308 - I: 0.8783 - Kinetic: 0.4420 - Potential: 2.8888 - mse_odd_even_sol: 0.1547 - loss: 1.6574 - ymax: 0.2232 - ymin: -0.0336
# Epoch 797/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0099 - E: 3.3350 - I: 0.8794 - Kinetic: 0.4449 - Potential: 2.8901 - mse_odd_even_sol: 0.1548 - loss: 1.6319 - ymax: 0.2207 - ymin: -0.0344
# Epoch 797: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - DE: 0.0099 - E: 3.3350 - I: 0.8794 - Kinetic: 0.4449 - Potential: 2.8901 - mse_odd_even_sol: 0.1548 - loss: 1.6319 - ymax: 0.2207 - ymin: -0.0344
# Epoch 798/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0097 - E: 3.3391 - I: 0.8805 - Kinetic: 0.4479 - Potential: 2.8913 - mse_odd_even_sol: 0.1549 - loss: 1.6065 - ymax: 0.2182 - ymin: -0.0351
# Epoch 798: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0097 - E: 3.3391 - I: 0.8805 - Kinetic: 0.4479 - Potential: 2.8913 - mse_odd_even_sol: 0.1549 - loss: 1.6065 - ymax: 0.2182 - ymin: -0.0351
# Epoch 799/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0096 - E: 3.3433 - I: 0.8815 - Kinetic: 0.4509 - Potential: 2.8924 - mse_odd_even_sol: 0.1550 - loss: 1.5812 - ymax: 0.2157 - ymin: -0.0358
# Epoch 799: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0096 - E: 3.3433 - I: 0.8815 - Kinetic: 0.4509 - Potential: 2.8924 - mse_odd_even_sol: 0.1550 - loss: 1.5812 - ymax: 0.2157 - ymin: -0.0358
# Epoch 800/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0095 - E: 3.3475 - I: 0.8827 - Kinetic: 0.4539 - Potential: 2.8935 - mse_odd_even_sol: 0.1551 - loss: 1.5560 - ymax: 0.2132 - ymin: -0.0364
# Epoch 800: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0095 - E: 3.3475 - I: 0.8827 - Kinetic: 0.4539 - Potential: 2.8935 - mse_odd_even_sol: 0.1551 - loss: 1.5560 - ymax: 0.2132 - ymin: -0.0364
# Epoch 801/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.0094 - E: 3.3516 - I: 0.8838 - Kinetic: 0.4570 - Potential: 2.8946 - mse_odd_even_sol: 0.1552 - loss: 1.5309 - ymax: 0.2106 - ymin: -0.0370
# Epoch 801: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0094 - E: 3.3516 - I: 0.8838 - Kinetic: 0.4570 - Potential: 2.8946 - mse_odd_even_sol: 0.1552 - loss: 1.5309 - ymax: 0.2106 - ymin: -0.0370
# Epoch 802/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.0093 - E: 3.3558 - I: 0.8849 - Kinetic: 0.4601 - Potential: 2.8957 - mse_odd_even_sol: 0.1553 - loss: 1.5059 - ymax: 0.2080 - ymin: -0.0375
# Epoch 802: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - DE: 0.0093 - E: 3.3558 - I: 0.8849 - Kinetic: 0.4601 - Potential: 2.8957 - mse_odd_even_sol: 0.1553 - loss: 1.5059 - ymax: 0.2080 - ymin: -0.0375
# Epoch 803/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0091 - E: 3.3599 - I: 0.8860 - Kinetic: 0.4633 - Potential: 2.8967 - mse_odd_even_sol: 0.1555 - loss: 1.4812 - ymax: 0.2054 - ymin: -0.0379
# Epoch 803: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0091 - E: 3.3599 - I: 0.8860 - Kinetic: 0.4633 - Potential: 2.8967 - mse_odd_even_sol: 0.1555 - loss: 1.4812 - ymax: 0.2054 - ymin: -0.0379
# Epoch 804/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0090 - E: 3.3641 - I: 0.8872 - Kinetic: 0.4665 - Potential: 2.8976 - mse_odd_even_sol: 0.1556 - loss: 1.4566 - ymax: 0.2027 - ymin: -0.0383
# Epoch 804: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0090 - E: 3.3641 - I: 0.8872 - Kinetic: 0.4665 - Potential: 2.8976 - mse_odd_even_sol: 0.1556 - loss: 1.4566 - ymax: 0.2027 - ymin: -0.0383
# Epoch 805/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0089 - E: 3.3682 - I: 0.8883 - Kinetic: 0.4697 - Potential: 2.8985 - mse_odd_even_sol: 0.1557 - loss: 1.4323 - ymax: 0.2001 - ymin: -0.0387
# Epoch 805: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0089 - E: 3.3682 - I: 0.8883 - Kinetic: 0.4697 - Potential: 2.8985 - mse_odd_even_sol: 0.1557 - loss: 1.4323 - ymax: 0.2001 - ymin: -0.0387
# Epoch 806/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.0088 - E: 3.3724 - I: 0.8895 - Kinetic: 0.4730 - Potential: 2.8994 - mse_odd_even_sol: 0.1558 - loss: 1.4082 - ymax: 0.1974 - ymin: -0.0390
# Epoch 806: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.0088 - E: 3.3724 - I: 0.8895 - Kinetic: 0.4730 - Potential: 2.8994 - mse_odd_even_sol: 0.1558 - loss: 1.4082 - ymax: 0.1974 - ymin: -0.0390
# Epoch 807/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.0087 - E: 3.3765 - I: 0.8907 - Kinetic: 0.4763 - Potential: 2.9002 - mse_odd_even_sol: 0.1559 - loss: 1.3843 - ymax: 0.1947 - ymin: -0.0392
# Epoch 807: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0087 - E: 3.3765 - I: 0.8907 - Kinetic: 0.4763 - Potential: 2.9002 - mse_odd_even_sol: 0.1559 - loss: 1.3843 - ymax: 0.1947 - ymin: -0.0392
# Epoch 808/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.0086 - E: 3.3806 - I: 0.8918 - Kinetic: 0.4796 - Potential: 2.9010 - mse_odd_even_sol: 0.1560 - loss: 1.3608 - ymax: 0.1919 - ymin: -0.0394
# Epoch 808: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.0086 - E: 3.3806 - I: 0.8918 - Kinetic: 0.4796 - Potential: 2.9010 - mse_odd_even_sol: 0.1560 - loss: 1.3608 - ymax: 0.1919 - ymin: -0.0394
# Epoch 809/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0085 - E: 3.3847 - I: 0.8930 - Kinetic: 0.4830 - Potential: 2.9017 - mse_odd_even_sol: 0.1562 - loss: 1.3375 - ymax: 0.1892 - ymin: -0.0395
# Epoch 809: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - DE: 0.0085 - E: 3.3847 - I: 0.8930 - Kinetic: 0.4830 - Potential: 2.9017 - mse_odd_even_sol: 0.1562 - loss: 1.3375 - ymax: 0.1892 - ymin: -0.0395
# Epoch 810/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0084 - E: 3.3888 - I: 0.8942 - Kinetic: 0.4864 - Potential: 2.9024 - mse_odd_even_sol: 0.1563 - loss: 1.3145 - ymax: 0.1864 - ymin: -0.0396
# Epoch 810: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0084 - E: 3.3888 - I: 0.8942 - Kinetic: 0.4864 - Potential: 2.9024 - mse_odd_even_sol: 0.1563 - loss: 1.3145 - ymax: 0.1864 - ymin: -0.0396
# Epoch 811/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0083 - E: 3.3929 - I: 0.8954 - Kinetic: 0.4898 - Potential: 2.9031 - mse_odd_even_sol: 0.1564 - loss: 1.2918 - ymax: 0.1837 - ymin: -0.0397
# Epoch 811: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0083 - E: 3.3929 - I: 0.8954 - Kinetic: 0.4898 - Potential: 2.9031 - mse_odd_even_sol: 0.1564 - loss: 1.2918 - ymax: 0.1837 - ymin: -0.0397
# Epoch 812/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0082 - E: 3.3969 - I: 0.8966 - Kinetic: 0.4932 - Potential: 2.9037 - mse_odd_even_sol: 0.1565 - loss: 1.2695 - ymax: 0.1809 - ymin: -0.0397
# Epoch 812: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.0082 - E: 3.3969 - I: 0.8966 - Kinetic: 0.4932 - Potential: 2.9037 - mse_odd_even_sol: 0.1565 - loss: 1.2695 - ymax: 0.1809 - ymin: -0.0397
# Epoch 813/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0081 - E: 3.4009 - I: 0.8978 - Kinetic: 0.4967 - Potential: 2.9042 - mse_odd_even_sol: 0.1567 - loss: 1.2475 - ymax: 0.1782 - ymin: -0.0396
# Epoch 813: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0081 - E: 3.4009 - I: 0.8978 - Kinetic: 0.4967 - Potential: 2.9042 - mse_odd_even_sol: 0.1567 - loss: 1.2475 - ymax: 0.1782 - ymin: -0.0396
# Epoch 814/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - DE: 0.0080 - E: 3.4049 - I: 0.8991 - Kinetic: 0.5001 - Potential: 2.9047 - mse_odd_even_sol: 0.1568 - loss: 1.2259 - ymax: 0.1754 - ymin: -0.0395
# Epoch 814: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - DE: 0.0080 - E: 3.4049 - I: 0.8991 - Kinetic: 0.5001 - Potential: 2.9047 - mse_odd_even_sol: 0.1568 - loss: 1.2259 - ymax: 0.1754 - ymin: -0.0395
# Epoch 815/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0079 - E: 3.4088 - I: 0.9003 - Kinetic: 0.5036 - Potential: 2.9052 - mse_odd_even_sol: 0.1569 - loss: 1.2046 - ymax: 0.1726 - ymin: -0.0394
# Epoch 815: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.0079 - E: 3.4088 - I: 0.9003 - Kinetic: 0.5036 - Potential: 2.9052 - mse_odd_even_sol: 0.1569 - loss: 1.2046 - ymax: 0.1726 - ymin: -0.0394
# Epoch 816/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0078 - E: 3.4127 - I: 0.9015 - Kinetic: 0.5071 - Potential: 2.9057 - mse_odd_even_sol: 0.1570 - loss: 1.1837 - ymax: 0.1698 - ymin: -0.0393
# Epoch 816: mse_odd_even_sol did not improve from 0.04408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - DE: 0.0078 - E: 3.4127 - I: 0.9015 - Kinetic: 0.5071 - Potential: 2.9057 - mse_odd_even_sol: 0.1570 - loss: 1.1837 - ymax: 0.1698 - ymin: -0.0393
# Epoch 817/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 epochs = 3000 # 5000
# ----> 2 history = model.fit(x_train,fi, batch_size=n_train, epochs=epochs,
#       3                   callbacks=[checkpoint_callback,csv_logger],shuffle=False)#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:397, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     395 callbacks.on_epoch_begin(epoch)
#     396 with epoch_iterator.catch_stop_iteration():
# --> 397     for begin_step, end_step, iterator in epoch_iterator:
#     398         callbacks.on_train_batch_begin(begin_step)
#     399         logs = self.train_function(iterator)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:765, in TFEpochIterator.__next__(self)
#     764 def __next__(self):
# --> 765     return next(self._epoch_iterator)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\epoch_iterator.py:111, in EpochIterator._enumerate_iterator(self)
#     109 if steps_per_epoch > 0:
#     110     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 111         self._current_iterator = iter(self._get_iterator())
#     112         self._steps_seen = 0
#     113     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
name=f'Res_E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.keras'
model.save(name)

# %%
plt.plot(history.history['mse_odd_even_sol'],label='ECM')
plt.plot(history.history['loss'],label='Pérdida')
plt.plot(history.history['I'],label= 'Norma')
#plt.title('Método variacional pozo infinito')
plt.xlabel('Épocas')
plt.yscale("log")
plt.grid(True, linestyle="--")
plt.legend()
Imagen_metricas=f'Métricas_Res_E_fund_pozo_finito_L_{L}_n_{n_train}'
plt.savefig(Imagen_metricas, dpi=300, bbox_inches='tight')

# %%
neurons_layer=[1, 50, 50, 50, 1]
n_layers=5

# Define the model
activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

cloned_model = EVE_PINN(input,output)
cloned_model.load_weights("C:\TFG\PINNS\PINNS\Pozo_finito\Residuo\Fundamental_malo\E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5")

# %%
y_best=cloned_model.predict(x_train)
y_best=np.reshape(y_best,x_train.shape)
y_NN=model.predict(x_train)
y_NN=np.reshape(y_NN,n_train)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
#plt.plot(x_train,y_NN,lw=8,label=r'$y_{PINN}$ (x)')
plt.plot(x_train,-y_best,lw=8,label=r'$y_{PINN}$ (x)')
plt.plot(x_train,fi, lw=4, linestyle='--',label=r'$y_{sol}$ (x)')
plt.xlabel('x')
plt.grid(True, linestyle="--")
plt.legend()
Imagen_y_NN=f'Res_E_fund_pozo_infinito_L_{L}_n_{n_train}'
plt.savefig(Imagen_y_NN, dpi=300, bbox_inches='tight')
