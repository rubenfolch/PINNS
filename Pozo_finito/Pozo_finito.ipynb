# %%
# Tensorflow Keras and rest of the packages
import tensorflow as tf
import keras as keras
from tensorflow.keras import models,Model
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
import scipy

# %%
plt.rcParams.update({
    'font.size': 14,           # Tamaño base de la fuente
    'axes.labelsize': 16,      # Tamaño de las etiquetas de los ejes (xlabel, ylabel)
    'axes.titlesize': 18,      # Tamaño del título de la gráfica
    'xtick.labelsize': 14,     # Tamaño de los números de la escala X
    'ytick.labelsize': 14,     # Tamaño de los números de la escala Y
    'legend.fontsize': 14,     # Tamaño del texto de la leyenda
    'figure.titlesize': 20     # Tamaño del título general de la figura (si usas suptitle)
})

# %%
def nn_model(activation,neurons_layer,n_layers):
    input=Input(shape=(neurons_layer[0],))
    x=input
    for hidden_layer_neurons in neurons_layer[1:-1]: 
        x=Dense(hidden_layer_neurons,activation=activation)(x)
    output=Dense(neurons_layer[n_layers-1])(x)
    return input,output

# %%
@keras.saving.register_keras_serializable()#Esto hace que se pueda guardar el modelo y cargarlo sin problemas despues
class EVE_PINN(tf.keras.Model):# Esta clase va a heredar de la clase Model de Keras, lo que nos permite usar todos los metodos de la clase Model y ademas definir nuestros propios metodos
    def set_step_dx(self,dx): #Este metodo inicializa la clase
        self.dx=dx #Lo que hace esto es que al objeto que luego instanciamos le asigna el atributo dx, que va a ser espaciado entre puntos
    def set_V(self,V):
        self.V=V
    def set_max_min(self,xmax,xmin):
        self.xmax=xmax
        self.xmin=xmin
    def train_step(self, data):#Metodo que tiene internamente la clase Model del API de Keras
        x, y_exact = data

        #Change initial conditions for the PINN
        x_max=self.xmax
        x_min=self.xmin
        x_max=tf.constant([x_max],dtype=tf.float32)
        x_min=tf.constant([x_min],dtype=tf.float32)
        xi = tf.reshape(x,(x.shape[0],1))#Reconversion del batch de entrada a un vector columna
        unit = tf.constant(1.0, dtype=tf.float32)
        unit = tf.reshape(unit,shape=xi[0].shape)
        V=tf.constant(self.V, dtype=tf.float32)
        # loss set to zero
        lossDE = tf.constant(0.0, dtype=tf.float32)
        print(V.shape)
        # Averaged eigenvalue
        cero=tf.constant(0.0, dtype=tf.float32)
        # Spatial mesh
        dx = tf.constant(self.dx,dtype=tf.float32)

        with tf.GradientTape() as tape:
            ymax=self(x_max,training=False)
            ymin=self(x_min,training=False)
            # Calculate the second derivative dy2/dx2
            with tf.GradientTape() as tape1:
                tape1.watch(xi)
                with tf.GradientTape() as tape2:
                    tape2.watch(xi)#Watch le dice en que tensor se tiene que fijar para los calculos, aqui le decimos que mire el batch de entrada porque luego lo utilizamos para calcular la salida, esto es asi porque tape solo se fija en tensores variables y xi es constante 
                    y_NN =self(xi,training=False)#Cálculo de la y_NN para todos los datos, self(xi) hace el paso hacia delante del batch de entrada, y multplicamos por hard_condition para asegurar que la salida cumple las condiciones de contorno. Training=false porque esto solo sirve para calcular la funcion de perdida, es decir, estamos haciendo un predict de los datos xi de entrada
                    print(y_NN.shape)#Esto devolvera cual es el tamaño de la salida, que sera de otro vector columna, cada elemento la salida de cada dato de entrada del batch
                    tape2.watch(y_NN)#Ahora que esta calculada la salida, nos fijamos en el tensor de salida, de forma que ya podremos hacer la derivada
                dy_dx_NN = tape2.gradient(y_NN, xi)#Calcula la derivada de la salida respecto a la entrada, nos devolvera otro vector
                tape1.watch(y_NN)#De nuevo, se tiene que fijar
                tape1.watch(dy_dx_NN)#...
            d2y_dx2_NN = tf.squeeze(tape1.gradient(dy_dx_NN, xi))#Segunda derivada
            y_NN = tf.squeeze(y_NN)#Squeeze elimina las dimensiones de tamaño a 1 en lso tensores, osea si tenemos un vector que seria un tensor de shape(y,1) al hacer squeeze pasa a ser solo de shape(y,)
            tape.watch(xi)
            tape.watch(y_NN)
            tape.watch(dy_dx_NN)
            tape.watch(d2y_dx2_NN)
    
            num = tf.reduce_sum(y_NN*(-d2y_dx2_NN+V*y_NN))#Esto es el producto escalar de y con la segunda derivada de y, no se multiplica por dx porque se va a ir luego al ser un cociente num/den
            den = tf.reduce_sum(tf.square(y_NN)) # Could this be zero? #Norma al cuadrado de y
            M = num/den #Funcio de perdidad, que intentamos que cuando sea minima coincida con el autoestado fundamental
            M = tf.reshape(M,shape=xi[0].shape)#Reconvertimos en tensor de tamaño 0 porque era un esacalar, a un tensor de tamaño, que solo tiene un elemento que es el escalar.


            I = tf.math.reduce_sum(tf.square(y_NN))
            I = I*dx
            I = tf.reshape(I,shape=xi[0].shape)#Se van creando copias de I hasta que llegamos al tensor que es ahora si la morma al cuadrado multiplicada por el factor dx de discretizacion, tambien es de dimension 1con el reshape

            #Loss= ODE+ boundary/initial conditions
            lossDE = self.compiled_loss(-d2y_dx2_NN+V*y_NN, M*y_NN) #Esta loss lo que tiene interesante es que self.compiled_loss va a recibir como primer argumento el valor real bueno, y como segundo al valor predicho. Luego, cuando llamamos al metodo compile y le pasamos que tipo de metrica queremos, hara cuentas con ello
            loss = lossDE + self.compiled_loss(I,unit) + self.compiled_loss(ymax,cero)+self.compiled_loss(ymin,cero) #  Esta loss es el autovalor mas la condicion de normalizacion, esta es con la que entrenamos
            kinetic = tf.reduce_sum(y_NN * (-d2y_dx2_NN)) / tf.reduce_sum(tf.square(y_NN))
            potential = tf.reduce_sum(y_NN * (V * y_NN)) / tf.reduce_sum(tf.square(y_NN))

        gradients = tape.gradient(loss, self.trainable_weights)#Calcula la derivada de la funcion de perdida respecto a los parametros entrenables
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))#Zip empareja cada derivada de la lista gradientes con el parametro respecto al que se ha derivad0, de forma que le pasamos este tensor al optimizador que aplicara los gradientes y actualiza los parametros
        self.compiled_metrics.update_state(y_exact, y_NN)#Por ultimo, se actualiza el estado respecto al paso anterior con la y_NN calculada en este nuevo paso con los parametros anteriores
        metrics = {m.name: m.result() for m in self.metrics}#Dado que entiendo que el metodo self.compiled_metrics.updatestate actualiza las metricas como atributo del objeto en self.metrics. {} Crea un diccionario, en el que el formato_:_ indica clave:valor asociado 
        metrics['DE']=lossDE
        metrics['loss']=loss
        metrics['I']=I
        metrics['E']=M
        metrics['ymax']=ymax
        metrics['ymin']=ymin
        metrics['Kinetic']=kinetic
        metrics['Potential']=potential
        return metrics#Este diccionario creado que devuelve el metodo traning_step es el que utiliza model.fit para calcular las metricas

# %%
## Custom metric
@keras.saving.register_keras_serializable()#La serializamos para que despues al cargar el modelo, no tengamos que haber definido previamente la funcion, simplemente la habra guardado ya.
def mse_odd_even_sol(y_true, y_pred):
    return tf.minimum(tf.reduce_mean(tf.square(y_pred - y_true)),tf.reduce_mean(tf.square(y_pred + y_true)))#Devuelve el minimo entre y_NN con +-y_real

# %%
n_train = 500  # 500 for Sergio's estimation, 10 for Javi's
# Avoid the boundaries: ¿derivaties ill-defined at the boundaries?
#xmin = 0.0 + (1.0-0.0)/(2*n_train)#xmin que no es cero, es cero mas un delta
#xmax = 0.0 + (1.0-0.0)/(2*n_train) + (n_train-1)*(1.0-0.0)/n_train  #1 menos ese mismo delta, es decir, 1-xmin
# Definition of the function domain
xmin=-6
xmax=6
L=4
a=L/2
V0=3
x_train,step_dx = np.linspace(xmin,xmax,n_train,retstep=True)#No se coge ni el cero ni el uno porque los hemos forzad a ser cero al multiplicar por x*(1-x) a la yNN
print("dx=",step_dx)
V=np.zeros_like(x_train)
for i in range(len(x_train)):
    if x_train[i]<=-a or x_train[i]>=a:
        V[i]=V0
    else:
        V[i]=0

# The solution y(x) for training and validation datasets
plt.plot(x_train,V)
# Out:
# dx= 0.02404809619238477

# %%
# Build the model
checkpoint_callback = ModelCheckpoint(
    filepath=f"E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.weights.h5",
    monitor="loss",
    save_best_only=True,
    save_weights_only=True,
    mode="min",
    verbose=1,
)#Esto hace que cuando se lo pasemos a model.fit nos guarde solo los parametros del modelo en variacional_E_fundamental.h5 siempre que la perdida sea menor que en la anterior epoca

# %% [markdown]
# **AUTOVALOR FUNDAMENTAL**

# %%
def ecuacion(E):
    rho=np.sqrt(V0-E)
    k=np.sqrt(E)
    return rho/k-np.tan(k*a)
E=scipy.optimize.root_scalar(ecuacion,bracket=[0.2,0.5],method='bisect')
print(E)
# Out:
#       converged: True
#            flag: converged
#  function_calls: 40
#      iterations: 38
#            root: 0.3678660235727875
#          method: bisect

# %% [markdown]
# **AUTOESTADO FUNDAMENTAL**

# %%
rho=np.sqrt(V0-E.root)
k=np.sqrt(E.root)
I1=np.exp(-L*rho)/(2*rho)
I2=a*(1+np.sin(k*L)/(k*L))
I3=np.exp(-L*rho)/(2*rho)
fact=np.exp(-rho*a)/(np.cos(k*a))
C=1/np.sqrt(I1+np.square(fact)*I2+I3)
fi=np.zeros(n_train)
for i,x in enumerate(x_train):
    if x<=-a:
        fi[i]=C*np.exp(rho*x)
    elif x>=a:
        fi[i]=C*np.exp(-rho*x)
    elif (x>-a or x<-a):
        fi[i]=C*fact*np.cos(k*x)
print(step_dx*sum(fi**2))
plt.plot(x_train,fi)
plt.axvline(-L / 2, linestyle="--", color="k")
plt.axvline(L / 2, linestyle="--", color="k")
plt.grid(True)
# Out:
# 0.9999998884417445

# %%
def ecuacion(E):
    rho=np.sqrt(V0-E)
    k=np.sqrt(E)
    return rho/k+1/np.tan(k*a)
E=scipy.optimize.root_scalar(ecuacion,bracket=[0.5,1.6],method='bisect')
print(E)
# Out:
#       converged: True
#            flag: converged
#  function_calls: 41
#      iterations: 39
#            root: 1.419657947120322
#          method: bisect

# %%
rho=np.sqrt(V0-E.root)
k=np.sqrt(E.root)
I1=np.exp(-L*rho)/(2*rho)
I2=a-np.sin(k*L)/(2*k)
I3=np.exp(-L*rho)/(2*rho)
fact=np.exp(-rho*a)/(np.cos(k*a))
C=1/np.sqrt(I1+np.square(fact)*I2+I3)
fi=np.zeros(n_train)
for i,x in enumerate(x_train):
    if x<=-a:
        fi[i]=C*np.exp(rho*x)
    elif x>=a:
        fi[i]=-C*np.exp(-rho*x)
    elif (x>-a or x<-a):
        fi[i]=C*fact*np.sin(k*x)
print(step_dx*sum(fi**2))
plt.plot(x_train,fi)
plt.axvline(-L / 2, linestyle="--", color="k")
plt.axvline(L / 2, linestyle="--", color="k")
plt.grid(True)
# Out:
# 0.9997717253324889

# %%
xi = tf.reshape(
    tf.constant(x_train, dtype=tf.float32),
    (-1, 1)
)

rho_tf = tf.constant(rho, dtype=tf.float32)
k_tf = tf.constant(k, dtype=tf.float32)
C_tf = tf.constant(C, dtype=tf.float32)
fact_tf = tf.constant(fact, dtype=tf.float32)
a_tf = tf.constant(a, dtype=tf.float32)

with tf.GradientTape() as tape2:
    tape2.watch(xi)

    with tf.GradientTape() as tape1:
        tape1.watch(xi)

        fi_tf = tf.where(
            xi <= -a_tf,
            C_tf * tf.exp(rho_tf * xi),
            tf.where(
                xi >= a_tf,
                C_tf * tf.exp(-rho_tf * xi),
                C_tf * fact_tf * tf.cos(k_tf * xi)
            )
        )

    dy_dx = tape1.gradient(fi_tf, xi)

d2fi_dx2 = tape2.gradient(dy_dx, xi)

fi_tf = tf.squeeze(fi_tf)
d2fi_dx2 = tf.squeeze(d2fi_dx2)

V_tf = tf.constant(V, dtype=tf.float32)

num = tf.reduce_sum(
    fi_tf * (-d2fi_dx2 + V_tf * fi_tf)
)
den = tf.reduce_sum(tf.square(fi_tf))

M = num / den
print(M.numpy())
# Out:
# 0.367866

# %%
# Input and output neurons (from the data)
neurons_layer=[1, 50, 50, 50, 1]
n_layers=5


# Define the model
activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

model = EVE_PINN(input,output)
model.set_max_min(xmax,xmin)
model.set_step_dx(step_dx)
model.set_V(V)
#model.load_weights('C:\TFG\PINNS\PINNS\Pozo_infinito\Estado_fundamental_copia-1.keras')
#Define the metrics, optimizer and loss
metrics = [mse_odd_even_sol] #tf.keras.metrics.MeanSquaredError()
lr=0.001
optimizer = Adam(learning_rate=lr)

model.compile(loss='mse',
          optimizer=optimizer,
          metrics=metrics,
          run_eagerly=False)

model.summary()
# Out:
# Model: "eve_pinn_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,251 (20.51 KB)
#  Trainable params: 5,251 (20.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 2000 # 5000        
history = model.fit(x_train,fi, batch_size=n_train, epochs=epochs,
                  callbacks=[checkpoint_callback],shuffle=False)#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca
# Out:
# Epoch 1/2000
# (500,)
# (500, 1)
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:696: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight, training)`.
#   warnings.warn(
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:671: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# (500,)
# (500, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - DE: 0.2705 - E: 2.7649 - I: 4.5970 - Kinetic: 0.0712 - Potential: 2.6937 - mse_odd_even_sol: 0.4655 - loss: 14.4725 - ymax: -0.7950 - ymin: 0.7950
# Epoch 1: loss improved from None to 14.47252, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - DE: 0.2705 - E: 2.7649 - I: 4.5970 - Kinetic: 0.0712 - Potential: 2.6937 - mse_odd_even_sol: 0.4655 - loss: 14.4725 - ymax: -0.7950 - ymin: 0.7950
# Epoch 2/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.1048 - E: 2.7626 - I: 1.7667 - Kinetic: 0.0723 - Potential: 2.6903 - mse_odd_even_sol: 0.2300 - loss: 1.1738 - ymax: -0.4904 - ymin: 0.4906
# Epoch 2: loss improved from 14.47252 to 1.17380, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 2: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - DE: 0.1048 - E: 2.7626 - I: 1.7667 - Kinetic: 0.0723 - Potential: 2.6903 - mse_odd_even_sol: 0.2300 - loss: 1.1738 - ymax: -0.4904 - ymin: 0.4906
# Epoch 3/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0298 - E: 2.7520 - I: 0.4857 - Kinetic: 0.0746 - Potential: 2.6773 - mse_odd_even_sol: 0.1182 - loss: 0.4233 - ymax: -0.2628 - ymin: 0.2448
# Epoch 3: loss improved from 1.17380 to 0.42333, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 3: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - DE: 0.0298 - E: 2.7520 - I: 0.4857 - Kinetic: 0.0746 - Potential: 2.6773 - mse_odd_even_sol: 0.1182 - loss: 0.4233 - ymax: -0.2628 - ymin: 0.2448
# Epoch 4/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0052 - E: 2.5848 - I: 0.0565 - Kinetic: 0.0778 - Potential: 2.5070 - mse_odd_even_sol: 0.0774 - loss: 0.9080 - ymax: -0.0946 - ymin: 0.0601
# Epoch 4: loss did not improve from 0.42333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0052 - E: 2.5848 - I: 0.0565 - Kinetic: 0.0778 - Potential: 2.5070 - mse_odd_even_sol: 0.0774 - loss: 0.9080 - ymax: -0.0946 - ymin: 0.0601
# Epoch 5/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0051 - E: 2.3047 - I: 0.0387 - Kinetic: 0.0360 - Potential: 2.2687 - mse_odd_even_sol: 0.0707 - loss: 0.9382 - ymax: 0.0366 - ymin: -0.0883
# Epoch 5: loss did not improve from 0.42333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0051 - E: 2.3047 - I: 0.0387 - Kinetic: 0.0360 - Potential: 2.2687 - mse_odd_even_sol: 0.0707 - loss: 0.9382 - ymax: 0.0366 - ymin: -0.0883
# Epoch 6/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0210 - E: 2.6390 - I: 0.2552 - Kinetic: 0.0578 - Potential: 2.5812 - mse_odd_even_sol: 0.0828 - loss: 0.6448 - ymax: 0.1470 - ymin: -0.2178
# Epoch 6: loss did not improve from 0.42333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.0210 - E: 2.6390 - I: 0.2552 - Kinetic: 0.0578 - Potential: 2.5812 - mse_odd_even_sol: 0.0828 - loss: 0.6448 - ymax: 0.1470 - ymin: -0.2178
# Epoch 7/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0479 - E: 2.6790 - I: 0.6388 - Kinetic: 0.0622 - Potential: 2.6168 - mse_odd_even_sol: 0.1082 - loss: 0.3519 - ymax: 0.2451 - ymin: -0.3367
# Epoch 7: loss improved from 0.42333 to 0.35188, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 7: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - DE: 0.0479 - E: 2.6790 - I: 0.6388 - Kinetic: 0.0622 - Potential: 2.6168 - mse_odd_even_sol: 0.1082 - loss: 0.3519 - ymax: 0.2451 - ymin: -0.3367
# Epoch 8/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0829 - E: 2.6902 - I: 1.1363 - Kinetic: 0.0641 - Potential: 2.6261 - mse_odd_even_sol: 0.1431 - loss: 0.4091 - ymax: 0.3321 - ymin: -0.4442
# Epoch 8: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.0829 - E: 2.6902 - I: 1.1363 - Kinetic: 0.0641 - Potential: 2.6261 - mse_odd_even_sol: 0.1431 - loss: 0.4091 - ymax: 0.3321 - ymin: -0.4442
# Epoch 9/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.1155 - E: 2.7026 - I: 1.6347 - Kinetic: 0.0654 - Potential: 2.6372 - mse_odd_even_sol: 0.1814 - loss: 0.9614 - ymax: 0.4058 - ymin: -0.5276
# Epoch 9: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.1155 - E: 2.7026 - I: 1.6347 - Kinetic: 0.0654 - Potential: 2.6372 - mse_odd_even_sol: 0.1814 - loss: 0.9614 - ymax: 0.4058 - ymin: -0.5276
# Epoch 10/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.1342 - E: 2.7171 - I: 1.9767 - Kinetic: 0.0666 - Potential: 2.6505 - mse_odd_even_sol: 0.2113 - loss: 1.6262 - ymax: 0.4568 - ymin: -0.5739
# Epoch 10: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - DE: 0.1342 - E: 2.7171 - I: 1.9767 - Kinetic: 0.0666 - Potential: 2.6505 - mse_odd_even_sol: 0.2113 - loss: 1.6262 - ymax: 0.4568 - ymin: -0.5739
# Epoch 11/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.1357 - E: 2.7279 - I: 2.0611 - Kinetic: 0.0674 - Potential: 2.6605 - mse_odd_even_sol: 0.2221 - loss: 1.8247 - ymax: 0.4753 - ymin: -0.5806
# Epoch 11: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - DE: 0.1357 - E: 2.7279 - I: 2.0611 - Kinetic: 0.0674 - Potential: 2.6605 - mse_odd_even_sol: 0.2221 - loss: 1.8247 - ymax: 0.4753 - ymin: -0.5806
# Epoch 12/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.1221 - E: 2.7361 - I: 1.8986 - Kinetic: 0.0679 - Potential: 2.6682 - mse_odd_even_sol: 0.2134 - loss: 1.4497 - ymax: 0.4631 - ymin: -0.5529
# Epoch 12: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.1221 - E: 2.7361 - I: 1.8986 - Kinetic: 0.0679 - Potential: 2.6682 - mse_odd_even_sol: 0.2134 - loss: 1.4497 - ymax: 0.4631 - ymin: -0.5529
# Epoch 13/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0999 - E: 2.7430 - I: 1.5869 - Kinetic: 0.0683 - Potential: 2.6747 - mse_odd_even_sol: 0.1930 - loss: 0.8804 - ymax: 0.4292 - ymin: -0.5017
# Epoch 13: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0999 - E: 2.7430 - I: 1.5869 - Kinetic: 0.0683 - Potential: 2.6747 - mse_odd_even_sol: 0.1930 - loss: 0.8804 - ymax: 0.4292 - ymin: -0.5017
# Epoch 14/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0763 - E: 2.7495 - I: 1.2362 - Kinetic: 0.0687 - Potential: 2.6809 - mse_odd_even_sol: 0.1694 - loss: 0.4725 - ymax: 0.3843 - ymin: -0.4390
# Epoch 14: loss did not improve from 0.35188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.0763 - E: 2.7495 - I: 1.2362 - Kinetic: 0.0687 - Potential: 2.6809 - mse_odd_even_sol: 0.1694 - loss: 0.4725 - ymax: 0.3843 - ymin: -0.4390
# Epoch 15/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0558 - E: 2.7555 - I: 0.9210 - Kinetic: 0.0691 - Potential: 2.6864 - mse_odd_even_sol: 0.1485 - loss: 0.3160 - ymax: 0.3369 - ymin: -0.3748
# Epoch 15: loss improved from 0.35188 to 0.31597, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 15: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - DE: 0.0558 - E: 2.7555 - I: 0.9210 - Kinetic: 0.0691 - Potential: 2.6864 - mse_odd_even_sol: 0.1485 - loss: 0.3160 - ymax: 0.3369 - ymin: -0.3748
# Epoch 16/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0401 - E: 2.7603 - I: 0.6723 - Kinetic: 0.0696 - Potential: 2.6907 - mse_odd_even_sol: 0.1327 - loss: 0.3328 - ymax: 0.2930 - ymin: -0.3154
# Epoch 16: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0401 - E: 2.7603 - I: 0.6723 - Kinetic: 0.0696 - Potential: 2.6907 - mse_odd_even_sol: 0.1327 - loss: 0.3328 - ymax: 0.2930 - ymin: -0.3154
# Epoch 17/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.0290 - E: 2.7626 - I: 0.4914 - Kinetic: 0.0703 - Potential: 2.6923 - mse_odd_even_sol: 0.1220 - loss: 0.4228 - ymax: 0.2555 - ymin: -0.2641
# Epoch 17: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0290 - E: 2.7626 - I: 0.4914 - Kinetic: 0.0703 - Potential: 2.6923 - mse_odd_even_sol: 0.1220 - loss: 0.4228 - ymax: 0.2555 - ymin: -0.2641
# Epoch 18/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.0219 - E: 2.7601 - I: 0.3669 - Kinetic: 0.0709 - Potential: 2.6891 - mse_odd_even_sol: 0.1119 - loss: 0.5228 - ymax: 0.2256 - ymin: -0.2218
# Epoch 18: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0219 - E: 2.7601 - I: 0.3669 - Kinetic: 0.0709 - Potential: 2.6891 - mse_odd_even_sol: 0.1119 - loss: 0.5228 - ymax: 0.2256 - ymin: -0.2218
# Epoch 19/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0175 - E: 2.7499 - I: 0.2851 - Kinetic: 0.0715 - Potential: 2.6784 - mse_odd_even_sol: 0.1016 - loss: 0.6054 - ymax: 0.2034 - ymin: -0.1883
# Epoch 19: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.0175 - E: 2.7499 - I: 0.2851 - Kinetic: 0.0715 - Potential: 2.6784 - mse_odd_even_sol: 0.1016 - loss: 0.6054 - ymax: 0.2034 - ymin: -0.1883
# Epoch 20/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.0153 - E: 2.7295 - I: 0.2343 - Kinetic: 0.0718 - Potential: 2.6576 - mse_odd_even_sol: 0.0940 - loss: 0.6634 - ymax: 0.1883 - ymin: -0.1626
# Epoch 20: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0153 - E: 2.7295 - I: 0.2343 - Kinetic: 0.0718 - Potential: 2.6576 - mse_odd_even_sol: 0.0940 - loss: 0.6634 - ymax: 0.1883 - ymin: -0.1626
# Epoch 21/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0147 - E: 2.6977 - I: 0.2061 - Kinetic: 0.0717 - Potential: 2.6260 - mse_odd_even_sol: 0.0885 - loss: 0.6980 - ymax: 0.1799 - ymin: -0.1439
# Epoch 21: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.0147 - E: 2.6977 - I: 0.2061 - Kinetic: 0.0717 - Potential: 2.6260 - mse_odd_even_sol: 0.0885 - loss: 0.6980 - ymax: 0.1799 - ymin: -0.1439
# Epoch 22/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.0153 - E: 2.6567 - I: 0.1951 - Kinetic: 0.0711 - Potential: 2.5857 - mse_odd_even_sol: 0.0843 - loss: 0.7119 - ymax: 0.1776 - ymin: -0.1311
# Epoch 22: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - DE: 0.0153 - E: 2.6567 - I: 0.1951 - Kinetic: 0.0711 - Potential: 2.5857 - mse_odd_even_sol: 0.0843 - loss: 0.7119 - ymax: 0.1776 - ymin: -0.1311
# Epoch 23/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0171 - E: 2.6113 - I: 0.1982 - Kinetic: 0.0700 - Potential: 2.5413 - mse_odd_even_sol: 0.0812 - loss: 0.7079 - ymax: 0.1807 - ymin: -0.1234
# Epoch 23: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0171 - E: 2.6113 - I: 0.1982 - Kinetic: 0.0700 - Potential: 2.5413 - mse_odd_even_sol: 0.0812 - loss: 0.7079 - ymax: 0.1807 - ymin: -0.1234
# Epoch 24/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.0201 - E: 2.5670 - I: 0.2141 - Kinetic: 0.0687 - Potential: 2.4983 - mse_odd_even_sol: 0.0789 - loss: 0.6879 - ymax: 0.1890 - ymin: -0.1202
# Epoch 24: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.0201 - E: 2.5670 - I: 0.2141 - Kinetic: 0.0687 - Potential: 2.4983 - mse_odd_even_sol: 0.0789 - loss: 0.6879 - ymax: 0.1890 - ymin: -0.1202
# Epoch 25/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.0243 - E: 2.5281 - I: 0.2430 - Kinetic: 0.0673 - Potential: 2.4608 - mse_odd_even_sol: 0.0774 - loss: 0.6528 - ymax: 0.2021 - ymin: -0.1209
# Epoch 25: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.0243 - E: 2.5281 - I: 0.2430 - Kinetic: 0.0673 - Potential: 2.4608 - mse_odd_even_sol: 0.0774 - loss: 0.6528 - ymax: 0.2021 - ymin: -0.1209
# Epoch 26/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.0300 - E: 2.4967 - I: 0.2859 - Kinetic: 0.0660 - Potential: 2.4306 - mse_odd_even_sol: 0.0768 - loss: 0.6038 - ymax: 0.2197 - ymin: -0.1252
# Epoch 26: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - DE: 0.0300 - E: 2.4967 - I: 0.2859 - Kinetic: 0.0660 - Potential: 2.4306 - mse_odd_even_sol: 0.0768 - loss: 0.6038 - ymax: 0.2197 - ymin: -0.1252
# Epoch 27/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.0373 - E: 2.4729 - I: 0.3443 - Kinetic: 0.0650 - Potential: 2.4080 - mse_odd_even_sol: 0.0772 - loss: 0.5432 - ymax: 0.2415 - ymin: -0.1326
# Epoch 27: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - DE: 0.0373 - E: 2.4729 - I: 0.3443 - Kinetic: 0.0650 - Potential: 2.4080 - mse_odd_even_sol: 0.0772 - loss: 0.5432 - ymax: 0.2415 - ymin: -0.1326
# Epoch 28/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0465 - E: 2.4560 - I: 0.4196 - Kinetic: 0.0641 - Potential: 2.3919 - mse_odd_even_sol: 0.0786 - loss: 0.4750 - ymax: 0.2669 - ymin: -0.1427
# Epoch 28: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.0465 - E: 2.4560 - I: 0.4196 - Kinetic: 0.0641 - Potential: 2.3919 - mse_odd_even_sol: 0.0786 - loss: 0.4750 - ymax: 0.2669 - ymin: -0.1427
# Epoch 29/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0577 - E: 2.4444 - I: 0.5128 - Kinetic: 0.0635 - Potential: 2.3809 - mse_odd_even_sol: 0.0813 - loss: 0.4064 - ymax: 0.2953 - ymin: -0.1551
# Epoch 29: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0577 - E: 2.4444 - I: 0.5128 - Kinetic: 0.0635 - Potential: 2.3809 - mse_odd_even_sol: 0.0813 - loss: 0.4064 - ymax: 0.2953 - ymin: -0.1551
# Epoch 30/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0708 - E: 2.4366 - I: 0.6229 - Kinetic: 0.0630 - Potential: 2.3736 - mse_odd_even_sol: 0.0853 - loss: 0.3476 - ymax: 0.3258 - ymin: -0.1690
# Epoch 30: loss did not improve from 0.31597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.0708 - E: 2.4366 - I: 0.6229 - Kinetic: 0.0630 - Potential: 2.3736 - mse_odd_even_sol: 0.0853 - loss: 0.3476 - ymax: 0.3258 - ymin: -0.1690
# Epoch 31/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.0854 - E: 2.4311 - I: 0.7464 - Kinetic: 0.0627 - Potential: 2.3684 - mse_odd_even_sol: 0.0903 - loss: 0.3107 - ymax: 0.3568 - ymin: -0.1835
# Epoch 31: loss improved from 0.31597 to 0.31066, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 31: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - DE: 0.0854 - E: 2.4311 - I: 0.7464 - Kinetic: 0.0627 - Potential: 2.3684 - mse_odd_even_sol: 0.0903 - loss: 0.3107 - ymax: 0.3568 - ymin: -0.1835
# Epoch 32/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.1007 - E: 2.4268 - I: 0.8755 - Kinetic: 0.0625 - Potential: 2.3643 - mse_odd_even_sol: 0.0961 - loss: 0.3046 - ymax: 0.3865 - ymin: -0.1975
# Epoch 32: loss improved from 0.31066 to 0.30457, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 32: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - DE: 0.1007 - E: 2.4268 - I: 0.8755 - Kinetic: 0.0625 - Potential: 2.3643 - mse_odd_even_sol: 0.0961 - loss: 0.3046 - ymax: 0.3865 - ymin: -0.1975
# Epoch 33/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.1152 - E: 2.4231 - I: 0.9979 - Kinetic: 0.0623 - Potential: 2.3607 - mse_odd_even_sol: 0.1019 - loss: 0.3295 - ymax: 0.4126 - ymin: -0.2097
# Epoch 33: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - DE: 0.1152 - E: 2.4231 - I: 0.9979 - Kinetic: 0.0623 - Potential: 2.3607 - mse_odd_even_sol: 0.1019 - loss: 0.3295 - ymax: 0.4126 - ymin: -0.2097
# Epoch 34/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.1274 - E: 2.4196 - I: 1.0983 - Kinetic: 0.0623 - Potential: 2.3572 - mse_odd_even_sol: 0.1067 - loss: 0.3720 - ymax: 0.4326 - ymin: -0.2187
# Epoch 34: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - DE: 0.1274 - E: 2.4196 - I: 1.0983 - Kinetic: 0.0623 - Potential: 2.3572 - mse_odd_even_sol: 0.1067 - loss: 0.3720 - ymax: 0.4326 - ymin: -0.2187
# Epoch 35/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.1353 - E: 2.4159 - I: 1.1621 - Kinetic: 0.0624 - Potential: 2.3535 - mse_odd_even_sol: 0.1098 - loss: 0.4092 - ymax: 0.4446 - ymin: -0.2235
# Epoch 35: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.1353 - E: 2.4159 - I: 1.1621 - Kinetic: 0.0624 - Potential: 2.3535 - mse_odd_even_sol: 0.1098 - loss: 0.4092 - ymax: 0.4446 - ymin: -0.2235
# Epoch 36/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.1381 - E: 2.4116 - I: 1.1810 - Kinetic: 0.0626 - Potential: 2.3490 - mse_odd_even_sol: 0.1105 - loss: 0.4211 - ymax: 0.4475 - ymin: -0.2235
# Epoch 36: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.1381 - E: 2.4116 - I: 1.1810 - Kinetic: 0.0626 - Potential: 2.3490 - mse_odd_even_sol: 0.1105 - loss: 0.4211 - ymax: 0.4475 - ymin: -0.2235
# Epoch 37/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.1360 - E: 2.4060 - I: 1.1555 - Kinetic: 0.0629 - Potential: 2.3431 - mse_odd_even_sol: 0.1087 - loss: 0.4031 - ymax: 0.4417 - ymin: -0.2187
# Epoch 37: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.1360 - E: 2.4060 - I: 1.1555 - Kinetic: 0.0629 - Potential: 2.3431 - mse_odd_even_sol: 0.1087 - loss: 0.4031 - ymax: 0.4417 - ymin: -0.2187
# Epoch 38/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.1298 - E: 2.3986 - I: 1.0946 - Kinetic: 0.0633 - Potential: 2.3353 - mse_odd_even_sol: 0.1050 - loss: 0.3665 - ymax: 0.4286 - ymin: -0.2098
# Epoch 38: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.1298 - E: 2.3986 - I: 1.0946 - Kinetic: 0.0633 - Potential: 2.3353 - mse_odd_even_sol: 0.1050 - loss: 0.3665 - ymax: 0.4286 - ymin: -0.2098
# Epoch 39/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.1212 - E: 2.3893 - I: 1.0119 - Kinetic: 0.0637 - Potential: 2.3256 - mse_odd_even_sol: 0.1001 - loss: 0.3292 - ymax: 0.4107 - ymin: -0.1981
# Epoch 39: loss did not improve from 0.30457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.1212 - E: 2.3893 - I: 1.0119 - Kinetic: 0.0637 - Potential: 2.3256 - mse_odd_even_sol: 0.1001 - loss: 0.3292 - ymax: 0.4107 - ymin: -0.1981
# Epoch 40/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.1116 - E: 2.3785 - I: 0.9216 - Kinetic: 0.0642 - Potential: 2.3143 - mse_odd_even_sol: 0.0950 - loss: 0.3042 - ymax: 0.3902 - ymin: -0.1849
# Epoch 40: loss improved from 0.30457 to 0.30419, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 40: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - DE: 0.1116 - E: 2.3785 - I: 0.9216 - Kinetic: 0.0642 - Potential: 2.3143 - mse_odd_even_sol: 0.0950 - loss: 0.3042 - ymax: 0.3902 - ymin: -0.1849
# Epoch 41/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.1023 - E: 2.3667 - I: 0.8350 - Kinetic: 0.0648 - Potential: 2.3019 - mse_odd_even_sol: 0.0902 - loss: 0.2956 - ymax: 0.3696 - ymin: -0.1718
# Epoch 41: loss improved from 0.30419 to 0.29564, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 41: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - DE: 0.1023 - E: 2.3667 - I: 0.8350 - Kinetic: 0.0648 - Potential: 2.3019 - mse_odd_even_sol: 0.0902 - loss: 0.2956 - ymax: 0.3696 - ymin: -0.1718
# Epoch 42/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0942 - E: 2.3545 - I: 0.7602 - Kinetic: 0.0655 - Potential: 2.2890 - mse_odd_even_sol: 0.0861 - loss: 0.3003 - ymax: 0.3508 - ymin: -0.1597
# Epoch 42: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0942 - E: 2.3545 - I: 0.7602 - Kinetic: 0.0655 - Potential: 2.2890 - mse_odd_even_sol: 0.0861 - loss: 0.3003 - ymax: 0.3508 - ymin: -0.1597
# Epoch 43/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0879 - E: 2.3424 - I: 0.7011 - Kinetic: 0.0661 - Potential: 2.2763 - mse_odd_even_sol: 0.0829 - loss: 0.3118 - ymax: 0.3351 - ymin: -0.1494
# Epoch 43: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.0879 - E: 2.3424 - I: 0.7011 - Kinetic: 0.0661 - Potential: 2.2763 - mse_odd_even_sol: 0.0829 - loss: 0.3118 - ymax: 0.3351 - ymin: -0.1494
# Epoch 44/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.0835 - E: 2.3313 - I: 0.6595 - Kinetic: 0.0668 - Potential: 2.2645 - mse_odd_even_sol: 0.0807 - loss: 0.3239 - ymax: 0.3233 - ymin: -0.1413
# Epoch 44: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.0835 - E: 2.3313 - I: 0.6595 - Kinetic: 0.0668 - Potential: 2.2645 - mse_odd_even_sol: 0.0807 - loss: 0.3239 - ymax: 0.3233 - ymin: -0.1413
# Epoch 45/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.0811 - E: 2.3216 - I: 0.6352 - Kinetic: 0.0674 - Potential: 2.2542 - mse_odd_even_sol: 0.0792 - loss: 0.3323 - ymax: 0.3159 - ymin: -0.1356
# Epoch 45: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.0811 - E: 2.3216 - I: 0.6352 - Kinetic: 0.0674 - Potential: 2.2542 - mse_odd_even_sol: 0.0792 - loss: 0.3323 - ymax: 0.3159 - ymin: -0.1356
# Epoch 46/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.0806 - E: 2.3138 - I: 0.6275 - Kinetic: 0.0679 - Potential: 2.2459 - mse_odd_even_sol: 0.0786 - loss: 0.3347 - ymax: 0.3127 - ymin: -0.1323
# Epoch 46: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0806 - E: 2.3138 - I: 0.6275 - Kinetic: 0.0679 - Potential: 2.2459 - mse_odd_even_sol: 0.0786 - loss: 0.3347 - ymax: 0.3127 - ymin: -0.1323
# Epoch 47/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.0820 - E: 2.3081 - I: 0.6350 - Kinetic: 0.0683 - Potential: 2.2398 - mse_odd_even_sol: 0.0786 - loss: 0.3308 - ymax: 0.3137 - ymin: -0.1313
# Epoch 47: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.0820 - E: 2.3081 - I: 0.6350 - Kinetic: 0.0683 - Potential: 2.2398 - mse_odd_even_sol: 0.0786 - loss: 0.3308 - ymax: 0.3137 - ymin: -0.1313
# Epoch 48/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.0850 - E: 2.3045 - I: 0.6563 - Kinetic: 0.0686 - Potential: 2.2359 - mse_odd_even_sol: 0.0792 - loss: 0.3219 - ymax: 0.3183 - ymin: -0.1323
# Epoch 48: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0850 - E: 2.3045 - I: 0.6563 - Kinetic: 0.0686 - Potential: 2.2359 - mse_odd_even_sol: 0.0792 - loss: 0.3219 - ymax: 0.3183 - ymin: -0.1323
# Epoch 49/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.0894 - E: 2.3027 - I: 0.6896 - Kinetic: 0.0688 - Potential: 2.2338 - mse_odd_even_sol: 0.0805 - loss: 0.3102 - ymax: 0.3259 - ymin: -0.1350
# Epoch 49: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.0894 - E: 2.3027 - I: 0.6896 - Kinetic: 0.0688 - Potential: 2.2338 - mse_odd_even_sol: 0.0805 - loss: 0.3102 - ymax: 0.3259 - ymin: -0.1350
# Epoch 50/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.0950 - E: 2.3021 - I: 0.7323 - Kinetic: 0.0690 - Potential: 2.2331 - mse_odd_even_sol: 0.0822 - loss: 0.2986 - ymax: 0.3356 - ymin: -0.1389
# Epoch 50: loss did not improve from 0.29564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - DE: 0.0950 - E: 2.3021 - I: 0.7323 - Kinetic: 0.0690 - Potential: 2.2331 - mse_odd_even_sol: 0.0822 - loss: 0.2986 - ymax: 0.3356 - ymin: -0.1389
# Epoch 51/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.1013 - E: 2.3022 - I: 0.7813 - Kinetic: 0.0691 - Potential: 2.2331 - mse_odd_even_sol: 0.0843 - loss: 0.2899 - ymax: 0.3466 - ymin: -0.1435
# Epoch 51: loss improved from 0.29564 to 0.28985, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 51: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - DE: 0.1013 - E: 2.3022 - I: 0.7813 - Kinetic: 0.0691 - Potential: 2.2331 - mse_odd_even_sol: 0.0843 - loss: 0.2899 - ymax: 0.3466 - ymin: -0.1435
# Epoch 52/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.1079 - E: 2.3024 - I: 0.8324 - Kinetic: 0.0692 - Potential: 2.2332 - mse_odd_even_sol: 0.0865 - loss: 0.2859 - ymax: 0.3577 - ymin: -0.1482
# Epoch 52: loss improved from 0.28985 to 0.28586, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 52: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - DE: 0.1079 - E: 2.3024 - I: 0.8324 - Kinetic: 0.0692 - Potential: 2.2332 - mse_odd_even_sol: 0.0865 - loss: 0.2859 - ymax: 0.3577 - ymin: -0.1482
# Epoch 53/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.1141 - E: 2.3022 - I: 0.8808 - Kinetic: 0.0694 - Potential: 2.2328 - mse_odd_even_sol: 0.0887 - loss: 0.2868 - ymax: 0.3677 - ymin: -0.1524
# Epoch 53: loss did not improve from 0.28586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.1141 - E: 2.3022 - I: 0.8808 - Kinetic: 0.0694 - Potential: 2.2328 - mse_odd_even_sol: 0.0887 - loss: 0.2868 - ymax: 0.3677 - ymin: -0.1524
# Epoch 54/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.1195 - E: 2.3011 - I: 0.9213 - Kinetic: 0.0696 - Potential: 2.2315 - mse_odd_even_sol: 0.0905 - loss: 0.2910 - ymax: 0.3757 - ymin: -0.1554
# Epoch 54: loss did not improve from 0.28586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.1195 - E: 2.3011 - I: 0.9213 - Kinetic: 0.0696 - Potential: 2.2315 - mse_odd_even_sol: 0.0905 - loss: 0.2910 - ymax: 0.3757 - ymin: -0.1554
# Epoch 55/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.1233 - E: 2.2989 - I: 0.9496 - Kinetic: 0.0699 - Potential: 2.2290 - mse_odd_even_sol: 0.0917 - loss: 0.2955 - ymax: 0.3809 - ymin: -0.1569
# Epoch 55: loss did not improve from 0.28586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.1233 - E: 2.2989 - I: 0.9496 - Kinetic: 0.0699 - Potential: 2.2290 - mse_odd_even_sol: 0.0917 - loss: 0.2955 - ymax: 0.3809 - ymin: -0.1569
# Epoch 56/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.1254 - E: 2.2952 - I: 0.9627 - Kinetic: 0.0703 - Potential: 2.2250 - mse_odd_even_sol: 0.0921 - loss: 0.2976 - ymax: 0.3826 - ymin: -0.1566
# Epoch 56: loss did not improve from 0.28586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - DE: 0.1254 - E: 2.2952 - I: 0.9627 - Kinetic: 0.0703 - Potential: 2.2250 - mse_odd_even_sol: 0.0921 - loss: 0.2976 - ymax: 0.3826 - ymin: -0.1566
# Epoch 57/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.1255 - E: 2.2901 - I: 0.9600 - Kinetic: 0.0708 - Potential: 2.2193 - mse_odd_even_sol: 0.0917 - loss: 0.2960 - ymax: 0.3808 - ymin: -0.1543
# Epoch 57: loss did not improve from 0.28586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - DE: 0.1255 - E: 2.2901 - I: 0.9600 - Kinetic: 0.0708 - Potential: 2.2193 - mse_odd_even_sol: 0.0917 - loss: 0.2960 - ymax: 0.3808 - ymin: -0.1543
# Epoch 58/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.1240 - E: 2.2835 - I: 0.9435 - Kinetic: 0.0714 - Potential: 2.2121 - mse_odd_even_sol: 0.0906 - loss: 0.2912 - ymax: 0.3760 - ymin: -0.1504
# Epoch 58: loss did not improve from 0.28586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.1240 - E: 2.2835 - I: 0.9435 - Kinetic: 0.0714 - Potential: 2.2121 - mse_odd_even_sol: 0.0906 - loss: 0.2912 - ymax: 0.3760 - ymin: -0.1504
# Epoch 59/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.1212 - E: 2.2755 - I: 0.9166 - Kinetic: 0.0721 - Potential: 2.2034 - mse_odd_even_sol: 0.0890 - loss: 0.2852 - ymax: 0.3688 - ymin: -0.1452
# Epoch 59: loss improved from 0.28586 to 0.28523, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 59: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - DE: 0.1212 - E: 2.2755 - I: 0.9166 - Kinetic: 0.0721 - Potential: 2.2034 - mse_odd_even_sol: 0.0890 - loss: 0.2852 - ymax: 0.3688 - ymin: -0.1452
# Epoch 60/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.1176 - E: 2.2666 - I: 0.8839 - Kinetic: 0.0730 - Potential: 2.1936 - mse_odd_even_sol: 0.0871 - loss: 0.2802 - ymax: 0.3602 - ymin: -0.1393
# Epoch 60: loss improved from 0.28523 to 0.28023, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 60: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - DE: 0.1176 - E: 2.2666 - I: 0.8839 - Kinetic: 0.0730 - Potential: 2.1936 - mse_odd_even_sol: 0.0871 - loss: 0.2802 - ymax: 0.3602 - ymin: -0.1393
# Epoch 61/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.1139 - E: 2.2571 - I: 0.8500 - Kinetic: 0.0739 - Potential: 2.1832 - mse_odd_even_sol: 0.0852 - loss: 0.2774 - ymax: 0.3511 - ymin: -0.1331
# Epoch 61: loss improved from 0.28023 to 0.27738, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 61: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - DE: 0.1139 - E: 2.2571 - I: 0.8500 - Kinetic: 0.0739 - Potential: 2.1832 - mse_odd_even_sol: 0.0852 - loss: 0.2774 - ymax: 0.3511 - ymin: -0.1331
# Epoch 62/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.1104 - E: 2.2474 - I: 0.8188 - Kinetic: 0.0748 - Potential: 2.1727 - mse_odd_even_sol: 0.0834 - loss: 0.2768 - ymax: 0.3425 - ymin: -0.1271
# Epoch 62: loss improved from 0.27738 to 0.27676, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 62: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.1104 - E: 2.2474 - I: 0.8188 - Kinetic: 0.0748 - Potential: 2.1727 - mse_odd_even_sol: 0.0834 - loss: 0.2768 - ymax: 0.3425 - ymin: -0.1271
# Epoch 63/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.1077 - E: 2.2381 - I: 0.7933 - Kinetic: 0.0757 - Potential: 2.1624 - mse_odd_even_sol: 0.0819 - loss: 0.2776 - ymax: 0.3351 - ymin: -0.1218
# Epoch 63: loss did not improve from 0.27676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.1077 - E: 2.2381 - I: 0.7933 - Kinetic: 0.0757 - Potential: 2.1624 - mse_odd_even_sol: 0.0819 - loss: 0.2776 - ymax: 0.3351 - ymin: -0.1218
# Epoch 64/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.1059 - E: 2.2294 - I: 0.7752 - Kinetic: 0.0765 - Potential: 2.1529 - mse_odd_even_sol: 0.0807 - loss: 0.2787 - ymax: 0.3294 - ymin: -0.1174
# Epoch 64: loss did not improve from 0.27676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - DE: 0.1059 - E: 2.2294 - I: 0.7752 - Kinetic: 0.0765 - Potential: 2.1529 - mse_odd_even_sol: 0.0807 - loss: 0.2787 - ymax: 0.3294 - ymin: -0.1174
# Epoch 65/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.1051 - E: 2.2218 - I: 0.7656 - Kinetic: 0.0773 - Potential: 2.1445 - mse_odd_even_sol: 0.0800 - loss: 0.2791 - ymax: 0.3257 - ymin: -0.1140
# Epoch 65: loss did not improve from 0.27676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.1051 - E: 2.2218 - I: 0.7656 - Kinetic: 0.0773 - Potential: 2.1445 - mse_odd_even_sol: 0.0800 - loss: 0.2791 - ymax: 0.3257 - ymin: -0.1140
# Epoch 66/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.1053 - E: 2.2153 - I: 0.7645 - Kinetic: 0.0779 - Potential: 2.1374 - mse_odd_even_sol: 0.0797 - loss: 0.2783 - ymax: 0.3241 - ymin: -0.1118
# Epoch 66: loss did not improve from 0.27676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.1053 - E: 2.2153 - I: 0.7645 - Kinetic: 0.0779 - Potential: 2.1374 - mse_odd_even_sol: 0.0797 - loss: 0.2783 - ymax: 0.3241 - ymin: -0.1118
# Epoch 67/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.1066 - E: 2.2101 - I: 0.7712 - Kinetic: 0.0784 - Potential: 2.1316 - mse_odd_even_sol: 0.0797 - loss: 0.2764 - ymax: 0.3243 - ymin: -0.1105
# Epoch 67: loss improved from 0.27676 to 0.27635, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 67: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.1066 - E: 2.2101 - I: 0.7712 - Kinetic: 0.0784 - Potential: 2.1316 - mse_odd_even_sol: 0.0797 - loss: 0.2764 - ymax: 0.3243 - ymin: -0.1105
# Epoch 68/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.1087 - E: 2.2058 - I: 0.7846 - Kinetic: 0.0788 - Potential: 2.1270 - mse_odd_even_sol: 0.0800 - loss: 0.2737 - ymax: 0.3262 - ymin: -0.1101
# Epoch 68: loss improved from 0.27635 to 0.27367, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 68: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - DE: 0.1087 - E: 2.2058 - I: 0.7846 - Kinetic: 0.0788 - Potential: 2.1270 - mse_odd_even_sol: 0.0800 - loss: 0.2737 - ymax: 0.3262 - ymin: -0.1101
# Epoch 69/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.1115 - E: 2.2024 - I: 0.8029 - Kinetic: 0.0792 - Potential: 2.1232 - mse_odd_even_sol: 0.0806 - loss: 0.2709 - ymax: 0.3292 - ymin: -0.1102
# Epoch 69: loss improved from 0.27367 to 0.27091, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 69: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.1115 - E: 2.2024 - I: 0.8029 - Kinetic: 0.0792 - Potential: 2.1232 - mse_odd_even_sol: 0.0806 - loss: 0.2709 - ymax: 0.3292 - ymin: -0.1102
# Epoch 70/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.1147 - E: 2.1993 - I: 0.8240 - Kinetic: 0.0795 - Potential: 2.1198 - mse_odd_even_sol: 0.0813 - loss: 0.2687 - ymax: 0.3328 - ymin: -0.1107
# Epoch 70: loss improved from 0.27091 to 0.26868, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 70: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.1147 - E: 2.1993 - I: 0.8240 - Kinetic: 0.0795 - Potential: 2.1198 - mse_odd_even_sol: 0.0813 - loss: 0.2687 - ymax: 0.3328 - ymin: -0.1107
# Epoch 71/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.1179 - E: 2.1963 - I: 0.8455 - Kinetic: 0.0798 - Potential: 2.1165 - mse_odd_even_sol: 0.0820 - loss: 0.2673 - ymax: 0.3365 - ymin: -0.1111
# Epoch 71: loss improved from 0.26868 to 0.26732, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 71: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.1179 - E: 2.1963 - I: 0.8455 - Kinetic: 0.0798 - Potential: 2.1165 - mse_odd_even_sol: 0.0820 - loss: 0.2673 - ymax: 0.3365 - ymin: -0.1111
# Epoch 72/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - DE: 0.1208 - E: 2.1930 - I: 0.8651 - Kinetic: 0.0801 - Potential: 2.1129 - mse_odd_even_sol: 0.0827 - loss: 0.2668 - ymax: 0.3396 - ymin: -0.1113
# Epoch 72: loss improved from 0.26732 to 0.26677, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 72: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - DE: 0.1208 - E: 2.1930 - I: 0.8651 - Kinetic: 0.0801 - Potential: 2.1129 - mse_odd_even_sol: 0.0827 - loss: 0.2668 - ymax: 0.3396 - ymin: -0.1113
# Epoch 73/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.1233 - E: 2.1890 - I: 0.8805 - Kinetic: 0.0805 - Potential: 2.1085 - mse_odd_even_sol: 0.0831 - loss: 0.2666 - ymax: 0.3417 - ymin: -0.1110
# Epoch 73: loss improved from 0.26677 to 0.26664, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 73: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - DE: 0.1233 - E: 2.1890 - I: 0.8805 - Kinetic: 0.0805 - Potential: 2.1085 - mse_odd_even_sol: 0.0831 - loss: 0.2666 - ymax: 0.3417 - ymin: -0.1110
# Epoch 74/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - DE: 0.1250 - E: 2.1842 - I: 0.8901 - Kinetic: 0.0809 - Potential: 2.1033 - mse_odd_even_sol: 0.0833 - loss: 0.2664 - ymax: 0.3425 - ymin: -0.1100
# Epoch 74: loss improved from 0.26664 to 0.26641, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 74: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.1250 - E: 2.1842 - I: 0.8901 - Kinetic: 0.0809 - Potential: 2.1033 - mse_odd_even_sol: 0.0833 - loss: 0.2664 - ymax: 0.3425 - ymin: -0.1100
# Epoch 75/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.1258 - E: 2.1785 - I: 0.8933 - Kinetic: 0.0815 - Potential: 2.0969 - mse_odd_even_sol: 0.0832 - loss: 0.2657 - ymax: 0.3417 - ymin: -0.1081
# Epoch 75: loss improved from 0.26641 to 0.26566, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 75: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - DE: 0.1258 - E: 2.1785 - I: 0.8933 - Kinetic: 0.0815 - Potential: 2.0969 - mse_odd_even_sol: 0.0832 - loss: 0.2657 - ymax: 0.3417 - ymin: -0.1081
# Epoch 76/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.1259 - E: 2.1717 - I: 0.8901 - Kinetic: 0.0822 - Potential: 2.0895 - mse_odd_even_sol: 0.0827 - loss: 0.2643 - ymax: 0.3395 - ymin: -0.1056
# Epoch 76: loss improved from 0.26566 to 0.26432, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 76: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - DE: 0.1259 - E: 2.1717 - I: 0.8901 - Kinetic: 0.0822 - Potential: 2.0895 - mse_odd_even_sol: 0.0827 - loss: 0.2643 - ymax: 0.3395 - ymin: -0.1056
# Epoch 77/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - DE: 0.1252 - E: 2.1640 - I: 0.8817 - Kinetic: 0.0830 - Potential: 2.0811 - mse_odd_even_sol: 0.0820 - loss: 0.2626 - ymax: 0.3360 - ymin: -0.1024
# Epoch 77: loss improved from 0.26432 to 0.26257, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 77: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - DE: 0.1252 - E: 2.1640 - I: 0.8817 - Kinetic: 0.0830 - Potential: 2.0811 - mse_odd_even_sol: 0.0820 - loss: 0.2626 - ymax: 0.3360 - ymin: -0.1024
# Epoch 78/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.1241 - E: 2.1557 - I: 0.8696 - Kinetic: 0.0839 - Potential: 2.0718 - mse_odd_even_sol: 0.0811 - loss: 0.2608 - ymax: 0.3316 - ymin: -0.0987
# Epoch 78: loss improved from 0.26257 to 0.26080, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 78: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.1241 - E: 2.1557 - I: 0.8696 - Kinetic: 0.0839 - Potential: 2.0718 - mse_odd_even_sol: 0.0811 - loss: 0.2608 - ymax: 0.3316 - ymin: -0.0987
# Epoch 79/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.1227 - E: 2.1468 - I: 0.8559 - Kinetic: 0.0848 - Potential: 2.0620 - mse_odd_even_sol: 0.0801 - loss: 0.2593 - ymax: 0.3269 - ymin: -0.0949
# Epoch 79: loss improved from 0.26080 to 0.25929, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 79: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.1227 - E: 2.1468 - I: 0.8559 - Kinetic: 0.0848 - Potential: 2.0620 - mse_odd_even_sol: 0.0801 - loss: 0.2593 - ymax: 0.3269 - ymin: -0.0949
# Epoch 80/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.1213 - E: 2.1376 - I: 0.8424 - Kinetic: 0.0857 - Potential: 2.0519 - mse_odd_even_sol: 0.0792 - loss: 0.2582 - ymax: 0.3221 - ymin: -0.0910
# Epoch 80: loss improved from 0.25929 to 0.25818, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 80: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - DE: 0.1213 - E: 2.1376 - I: 0.8424 - Kinetic: 0.0857 - Potential: 2.0519 - mse_odd_even_sol: 0.0792 - loss: 0.2582 - ymax: 0.3221 - ymin: -0.0910
# Epoch 81/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.1202 - E: 2.1286 - I: 0.8308 - Kinetic: 0.0866 - Potential: 2.0420 - mse_odd_even_sol: 0.0783 - loss: 0.2574 - ymax: 0.3177 - ymin: -0.0873
# Epoch 81: loss improved from 0.25818 to 0.25739, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 81: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - DE: 0.1202 - E: 2.1286 - I: 0.8308 - Kinetic: 0.0866 - Potential: 2.0420 - mse_odd_even_sol: 0.0783 - loss: 0.2574 - ymax: 0.3177 - ymin: -0.0873
# Epoch 82/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.1195 - E: 2.1199 - I: 0.8224 - Kinetic: 0.0875 - Potential: 2.0324 - mse_odd_even_sol: 0.0776 - loss: 0.2567 - ymax: 0.3140 - ymin: -0.0839
# Epoch 82: loss improved from 0.25739 to 0.25672, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 82: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - DE: 0.1195 - E: 2.1199 - I: 0.8224 - Kinetic: 0.0875 - Potential: 2.0324 - mse_odd_even_sol: 0.0776 - loss: 0.2567 - ymax: 0.3140 - ymin: -0.0839
# Epoch 83/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.1193 - E: 2.1117 - I: 0.8178 - Kinetic: 0.0883 - Potential: 2.0234 - mse_odd_even_sol: 0.0770 - loss: 0.2560 - ymax: 0.3112 - ymin: -0.0810
# Epoch 83: loss improved from 0.25672 to 0.25597, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 83: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - DE: 0.1193 - E: 2.1117 - I: 0.8178 - Kinetic: 0.0883 - Potential: 2.0234 - mse_odd_even_sol: 0.0770 - loss: 0.2560 - ymax: 0.3112 - ymin: -0.0810
# Epoch 84/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.1197 - E: 2.1041 - I: 0.8172 - Kinetic: 0.0890 - Potential: 2.0151 - mse_odd_even_sol: 0.0766 - loss: 0.2550 - ymax: 0.3094 - ymin: -0.0785
# Epoch 84: loss improved from 0.25597 to 0.25499, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 84: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - DE: 0.1197 - E: 2.1041 - I: 0.8172 - Kinetic: 0.0890 - Potential: 2.0151 - mse_odd_even_sol: 0.0766 - loss: 0.2550 - ymax: 0.3094 - ymin: -0.0785
# Epoch 85/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.1206 - E: 2.0970 - I: 0.8205 - Kinetic: 0.0896 - Potential: 2.0074 - mse_odd_even_sol: 0.0764 - loss: 0.2538 - ymax: 0.3084 - ymin: -0.0765
# Epoch 85: loss improved from 0.25499 to 0.25378, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 85: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - DE: 0.1206 - E: 2.0970 - I: 0.8205 - Kinetic: 0.0896 - Potential: 2.0074 - mse_odd_even_sol: 0.0764 - loss: 0.2538 - ymax: 0.3084 - ymin: -0.0765
# Epoch 86/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.1219 - E: 2.0905 - I: 0.8269 - Kinetic: 0.0901 - Potential: 2.0004 - mse_odd_even_sol: 0.0763 - loss: 0.2524 - ymax: 0.3082 - ymin: -0.0748
# Epoch 86: loss improved from 0.25378 to 0.25245, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 86: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - DE: 0.1219 - E: 2.0905 - I: 0.8269 - Kinetic: 0.0901 - Potential: 2.0004 - mse_odd_even_sol: 0.0763 - loss: 0.2524 - ymax: 0.3082 - ymin: -0.0748
# Epoch 87/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.1235 - E: 2.0843 - I: 0.8354 - Kinetic: 0.0906 - Potential: 1.9937 - mse_odd_even_sol: 0.0763 - loss: 0.2511 - ymax: 0.3085 - ymin: -0.0733
# Epoch 87: loss improved from 0.25245 to 0.25112, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 87: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - DE: 0.1235 - E: 2.0843 - I: 0.8354 - Kinetic: 0.0906 - Potential: 1.9937 - mse_odd_even_sol: 0.0763 - loss: 0.2511 - ymax: 0.3085 - ymin: -0.0733
# Epoch 88/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.1253 - E: 2.0783 - I: 0.8450 - Kinetic: 0.0910 - Potential: 1.9873 - mse_odd_even_sol: 0.0763 - loss: 0.2499 - ymax: 0.3089 - ymin: -0.0718
# Epoch 88: loss improved from 0.25112 to 0.24992, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 88: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - DE: 0.1253 - E: 2.0783 - I: 0.8450 - Kinetic: 0.0910 - Potential: 1.9873 - mse_odd_even_sol: 0.0763 - loss: 0.2499 - ymax: 0.3089 - ymin: -0.0718
# Epoch 89/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.1270 - E: 2.0721 - I: 0.8543 - Kinetic: 0.0915 - Potential: 1.9807 - mse_odd_even_sol: 0.0764 - loss: 0.2489 - ymax: 0.3093 - ymin: -0.0704
# Epoch 89: loss improved from 0.24992 to 0.24888, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 89: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - DE: 0.1270 - E: 2.0721 - I: 0.8543 - Kinetic: 0.0915 - Potential: 1.9807 - mse_odd_even_sol: 0.0764 - loss: 0.2489 - ymax: 0.3093 - ymin: -0.0704
# Epoch 90/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.1286 - E: 2.0656 - I: 0.8623 - Kinetic: 0.0919 - Potential: 1.9737 - mse_odd_even_sol: 0.0763 - loss: 0.2480 - ymax: 0.3094 - ymin: -0.0687
# Epoch 90: loss improved from 0.24888 to 0.24797, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 90: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - DE: 0.1286 - E: 2.0656 - I: 0.8623 - Kinetic: 0.0919 - Potential: 1.9737 - mse_odd_even_sol: 0.0763 - loss: 0.2480 - ymax: 0.3094 - ymin: -0.0687
# Epoch 91/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.1298 - E: 2.0587 - I: 0.8680 - Kinetic: 0.0924 - Potential: 1.9662 - mse_odd_even_sol: 0.0762 - loss: 0.2471 - ymax: 0.3088 - ymin: -0.0668
# Epoch 91: loss improved from 0.24797 to 0.24709, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 91: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - DE: 0.1298 - E: 2.0587 - I: 0.8680 - Kinetic: 0.0924 - Potential: 1.9662 - mse_odd_even_sol: 0.0762 - loss: 0.2471 - ymax: 0.3088 - ymin: -0.0668
# Epoch 92/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.1307 - E: 2.0511 - I: 0.8709 - Kinetic: 0.0930 - Potential: 1.9581 - mse_odd_even_sol: 0.0759 - loss: 0.2461 - ymax: 0.3076 - ymin: -0.0646
# Epoch 92: loss improved from 0.24709 to 0.24615, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 92: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - DE: 0.1307 - E: 2.0511 - I: 0.8709 - Kinetic: 0.0930 - Potential: 1.9581 - mse_odd_even_sol: 0.0759 - loss: 0.2461 - ymax: 0.3076 - ymin: -0.0646
# Epoch 93/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.1311 - E: 2.0429 - I: 0.8710 - Kinetic: 0.0937 - Potential: 1.9492 - mse_odd_even_sol: 0.0755 - loss: 0.2451 - ymax: 0.3057 - ymin: -0.0620
# Epoch 93: loss improved from 0.24615 to 0.24509, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 93: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - DE: 0.1311 - E: 2.0429 - I: 0.8710 - Kinetic: 0.0937 - Potential: 1.9492 - mse_odd_even_sol: 0.0755 - loss: 0.2451 - ymax: 0.3057 - ymin: -0.0620
# Epoch 94/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.1312 - E: 2.0341 - I: 0.8685 - Kinetic: 0.0945 - Potential: 1.9396 - mse_odd_even_sol: 0.0750 - loss: 0.2439 - ymax: 0.3032 - ymin: -0.0592
# Epoch 94: loss improved from 0.24509 to 0.24394, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 94: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - DE: 0.1312 - E: 2.0341 - I: 0.8685 - Kinetic: 0.0945 - Potential: 1.9396 - mse_odd_even_sol: 0.0750 - loss: 0.2439 - ymax: 0.3032 - ymin: -0.0592
# Epoch 95/2000
# ...
# Epoch 1975/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.0045 - E: 0.3714 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2400e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.5332e-04
# Epoch 1975: loss improved from 0.00450 to 0.00449, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1975: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - DE: 0.0045 - E: 0.3714 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2400e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.5332e-04
# Epoch 1976/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2286e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.4588e-04
# Epoch 1976: loss improved from 0.00449 to 0.00449, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1976: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2286e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.4588e-04
# Epoch 1977/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2172e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.3830e-04
# Epoch 1977: loss improved from 0.00449 to 0.00449, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1977: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2172e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.3830e-04
# Epoch 1978/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2059e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.3092e-04
# Epoch 1978: loss improved from 0.00449 to 0.00448, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1978: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.2059e-05 - loss: 0.0045 - ymax: 0.0020 - ymin: 2.3092e-04
# Epoch 1979/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.1947e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.2361e-04
# Epoch 1979: loss improved from 0.00448 to 0.00448, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1979: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.1947e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.2361e-04
# Epoch 1980/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.1835e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.1618e-04
# Epoch 1980: loss improved from 0.00448 to 0.00448, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1980: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2952 - Potential: 0.0762 - mse_odd_even_sol: 6.1835e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.1618e-04
# Epoch 1981/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1723e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.0861e-04
# Epoch 1981: loss improved from 0.00448 to 0.00447, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1981: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1723e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.0861e-04
# Epoch 1982/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1611e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.0127e-04
# Epoch 1982: loss improved from 0.00447 to 0.00447, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1982: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1611e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 2.0127e-04
# Epoch 1983/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1500e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 1.9369e-04
# Epoch 1983: loss improved from 0.00447 to 0.00446, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1983: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1500e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 1.9369e-04
# Epoch 1984/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1389e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 1.8595e-04
# Epoch 1984: loss improved from 0.00446 to 0.00446, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1984: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - DE: 0.0045 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1389e-05 - loss: 0.0045 - ymax: 0.0019 - ymin: 1.8595e-04
# Epoch 1985/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1278e-05 - loss: 0.0045 - ymax: 0.0018 - ymin: 1.7848e-04
# Epoch 1985: loss improved from 0.00446 to 0.00446, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1985: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1278e-05 - loss: 0.0045 - ymax: 0.0018 - ymin: 1.7848e-04
# Epoch 1986/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1168e-05 - loss: 0.0045 - ymax: 0.0018 - ymin: 1.7118e-04
# Epoch 1986: loss improved from 0.00446 to 0.00445, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1986: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1168e-05 - loss: 0.0045 - ymax: 0.0018 - ymin: 1.7118e-04
# Epoch 1987/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1059e-05 - loss: 0.0045 - ymax: 0.0018 - ymin: 1.6385e-04
# Epoch 1987: loss improved from 0.00445 to 0.00445, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1987: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.1059e-05 - loss: 0.0045 - ymax: 0.0018 - ymin: 1.6385e-04
# Epoch 1988/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0950e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.5640e-04
# Epoch 1988: loss improved from 0.00445 to 0.00445, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1988: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0950e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.5640e-04
# Epoch 1989/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0842e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.4904e-04
# Epoch 1989: loss improved from 0.00445 to 0.00444, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1989: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0842e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.4904e-04
# Epoch 1990/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0734e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.4175e-04
# Epoch 1990: loss improved from 0.00444 to 0.00444, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1990: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0734e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.4175e-04
# Epoch 1991/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0626e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.3427e-04
# Epoch 1991: loss improved from 0.00444 to 0.00444, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1991: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9977 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0626e-05 - loss: 0.0044 - ymax: 0.0018 - ymin: 1.3427e-04
# Epoch 1992/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0518e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.2696e-04
# Epoch 1992: loss improved from 0.00444 to 0.00443, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1992: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0518e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.2696e-04
# Epoch 1993/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0411e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.1950e-04
# Epoch 1993: loss improved from 0.00443 to 0.00443, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1993: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0411e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.1950e-04
# Epoch 1994/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0304e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.1195e-04
# Epoch 1994: loss improved from 0.00443 to 0.00443, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1994: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0304e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.1195e-04
# Epoch 1995/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0197e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.0456e-04
# Epoch 1995: loss improved from 0.00443 to 0.00442, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1995: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0197e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 1.0456e-04
# Epoch 1996/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0091e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 9.7173e-05
# Epoch 1996: loss improved from 0.00442 to 0.00442, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1996: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2951 - Potential: 0.0762 - mse_odd_even_sol: 6.0091e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 9.7173e-05
# Epoch 1997/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9986e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 8.9910e-05
# Epoch 1997: loss improved from 0.00442 to 0.00442, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1997: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9986e-05 - loss: 0.0044 - ymax: 0.0017 - ymin: 8.9910e-05
# Epoch 1998/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9881e-05 - loss: 0.0044 - ymax: 0.0016 - ymin: 8.2633e-05
# Epoch 1998: loss improved from 0.00442 to 0.00441, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1998: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9881e-05 - loss: 0.0044 - ymax: 0.0016 - ymin: 8.2633e-05
# Epoch 1999/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9777e-05 - loss: 0.0044 - ymax: 0.0016 - ymin: 7.5313e-05
# Epoch 1999: loss improved from 0.00441 to 0.00441, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 1999: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9777e-05 - loss: 0.0044 - ymax: 0.0016 - ymin: 7.5313e-05
# Epoch 2000/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9672e-05 - loss: 0.0044 - ymax: 0.0016 - ymin: 6.8080e-05
# Epoch 2000: loss improved from 0.00441 to 0.00441, saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
#
# Epoch 2000: finished saving model to E_fund_pozo_finito_L_4_V0_3_xmax_6_n_500.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - DE: 0.0044 - E: 0.3713 - I: 0.9978 - Kinetic: 0.2950 - Potential: 0.0762 - mse_odd_even_sol: 5.9672e-05 - loss: 0.0044 - ymax: 0.0016 - ymin: 6.8080e-05

# %%
name=f'E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.keras'
model.save(name)

# %%
#plt.plot(loss_true,label='loss')
plt.plot(history.history['loss'],label='Loss')
plt.plot(history.history['I'],label= 'norm')
plt.plot(history.history['mse_odd_even_sol'],label='MSE')
plt.title('Pozo finito')
plt.xlabel('epoch')
plt.yscale("log")
plt.legend()
Imagen_metricas=f'Métricas_E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}'
plt.savefig(Imagen_metricas, dpi=300, bbox_inches='tight')

# %%
neurons_layer=[1, 50, 50, 50, 1]
n_layers=5

# Define the model
activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

cloned_model = EVE_PINN(input,output)
cloned_model.set_max_min(xmax,xmin)
cloned_model.set_step_dx(step_dx)
cloned_model.set_V(V)

#Define the metrics, optimizer and loss
#metrics = [mse_odd_even_sol] #tf.keras.metrics.MeanSquaredError()
lr=0.0001
optimizer = Adam(learning_rate=lr)

cloned_model.compile(loss='mse',
          optimizer=optimizer,
          run_eagerly=False)
cloned_model.load_weights(f"E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}.weights.h5")
# Out:
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\saving_lib.py:843: UserWarning: Skipping variable loading for optimizer 'adam_6', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
#hard=(x_train - xmin)*(xmax - x_train)/((xmax - xmin)**2/4)
#print(np.shape(hard))
#plt.plot(x_train,hard)
#y_train = np.sqrt(2/1.0)*np.sin(np.pi*x/1.0)
#modelo_p=keras.models.load_model('variacional_E_fundamental.weights.h5')
y_NN_cloned_model=cloned_model.predict(x_train)
y_NN_cloned_model=np.reshape(y_NN_cloned_model,x_train.shape)
y_NN=model.predict(x_train)
y_NN=np.reshape(y_NN,x_train.shape)
print(np.shape(y_NN),np.shape(x_train))
#y_NN=np.reshape(y_NN,n_train)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# (500,) (500,)

# %%
plt.plot(x_train,y_NN, lw=8, label='y_NN (x)')
#plt.plot(x_train,y_NN_cloned_model,label='y_predict_best_model')
plt.plot(x_train,fi,lw=4,linestyle='--',label='y_true (x)')
#plt.plot(x_train,V,label='V')
#plt.axvline(-L / 2, linestyle="--", color="k")
#plt.axvline(L / 2, linestyle="--", color="k")
plt.title('Pozo finito')
plt.xlabel('x')
plt.legend()
Imagen_y_NN=f'E_fund_pozo_finito_L_{L}_V0_{V0}_xmax_{xmax}_n_{n_train}'
plt.savefig(Imagen_y_NN, dpi=300, bbox_inches='tight')
