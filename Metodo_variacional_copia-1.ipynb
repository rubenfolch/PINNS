# %%
# Tensorflow Keras and rest of the packages
import tensorflow as tf
import keras as keras
from tensorflow.keras import models,Model
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def nn_model(activation,neurons_layer,n_layers):
    input=Input(shape=(neurons_layer[0],))
    x=input
    for hidden_layer_neurons in neurons_layer[1:-1]: 
        x=Dense(hidden_layer_neurons,activation=activation)(x)
    output=Dense(neurons_layer[n_layers-1],activation)(x)
    return input,output

# %%
@keras.saving.register_keras_serializable()#Esto hace que se pueda guardar el modelo y cargarlo sin problemas despues
class EVE_PINN(tf.keras.Model):# Esta clase va a heredar de la clase Model de Keras, lo que nos permite usar todos los metodos de la clase Model y ademas definir nuestros propios metodos
    def set_step_dx(self,dx): #Este metodo inicializa la clase
      self.dx=dx #Lo que hace esto es que al objeto que luego instanciamos le asigna el atributo dx, que va a ser espaciado entre puntos

    def train_step(self, data):#Metodo que tiene internamente la clase Model del API de Keras
        x, y_exact = data

        # Use only for run_eagerly=True
        pi = tf.constant(np.pi)
        M0 = tf.square(pi)

        #Change initial conditions for the PINN
        x0 = tf.constant([0.0], dtype=tf.float32)
        xL = tf.constant([1.0], dtype=tf.float32) # We consider L=1
        y0_exact = tf.constant([0.0], dtype=tf.float32)
        yL_exact = tf.constant([0.0], dtype=tf.float32)
        xi = tf.reshape(x,(x.shape[0],1))#Reconversion del batch de entrada a un vector columna
        unit = tf.constant(1.0, dtype=tf.float32)
        unit = tf.reshape(unit,shape=xi[0].shape)

        # loss set to zero
        lossDE = tf.constant(0.0, dtype=tf.float32)

        # Averaged eigenvalue
        M = tf.constant(0.0, dtype=tf.float32)

        # Spatial mesh
        dx = tf.constant(self.dx,dtype=tf.float32)

        with tf.GradientTape() as tape:

            # Calculate the second derivative dy2/dx2
            with tf.GradientTape() as tape1:
                tape1.watch(xi)
                with tf.GradientTape() as tape2:
                    tape2.watch(xi)#Watch le dice en que tensor se tiene que fijar para los calculos, aqui le decimos que mire el batch de entrada porque luego lo utilizamos para calcular la salida, esto es asi porque tape solo se fija en tensores variables y xi es constante 
                    y_NN = xi*(unit-xi)*self(xi,training=False)#Cálculo de la y_NN para todos los datos, self(xi) hace el paso hacia delante del batch de entrada, y multplicamos por x*(1-x) para asegurar que la salida cumple las condiciones de contorno. Training=false porque esto solo sirve para calcular la funcion de perdida, es decir, estamos haciendo un predict de los datos xi de entrada
                    print(y_NN.shape)#Esto devolvera cual es el tamaño de la salida, que sera de otro vector columna, cada elemento la salida de cada dato de entrada del batch
                    tape2.watch(y_NN)#Ahora que esta calculada la salida, nos fijamos en el tensor de salida, de forma que ya podremos hacer la derivada
                dy_dx_NN = tape2.gradient(y_NN, xi)#Calcula la derivada de la salida respecto a la entrada, nos devolvera otro vector
                tape1.watch(y_NN)#De nuevo, se tiene que fijar
                tape1.watch(dy_dx_NN)#...
            d2y_dx2_NN = tf.squeeze(tape1.gradient(dy_dx_NN, xi))#Segunda derivada
            y_NN = tf.squeeze(y_NN)#Squeeze elimina las dimensiones de tamaño a 1 en lso tensores, osea si tenemos un vector que seria un tensor de shape(y,1) al hacer squeeze pasa a ser solo de shape(y,)
            tape.watch(xi)
            tape.watch(y_NN)
            tape.watch(dy_dx_NN)
            tape.watch(d2y_dx2_NN)

            num = tf.reduce_sum(tf.math.multiply(y_NN,-d2y_dx2_NN))#Esto es el producto escalar de y con la segunda derivada de y, no se multiplica por dx porque se va a ir luego al ser un cociente num/den
            den = tf.reduce_sum(tf.math.pow(y_NN,2)) # Could this be zero? #Norma al cuadrado de y
            M = num/den #Funcio de perdidad, que intentamos que cuando sea minima coincida con el autoestado fundamental
            M = tf.reshape(M,shape=xi[0].shape)#Reconvertimos en tensor de tamaño 0 porque era un esacalar, a un tensor de tamaño, que solo tiene un elemento que es el escalar.

            I = tf.constant(0.0, dtype=tf.float32)
            I = tf.math.reduce_sum(tf.math.pow(y_NN,2))
            I = tf.multiply(I,dx)
            I = tf.reshape(I,shape=xi[0].shape)#Se van creando copias de I hasta que llegamos al tensor que es ahora si la morma al cuadrado multiplicada por el factor dx de discretizacion, tambien es de dimension 1con el reshape

            big = tf.constant(1.0, dtype=tf.float32)
            big = tf.reshape(big,shape=xi[0].shape)#Se crea un tensor con todos 1 de una dimension, osea un uno

            #Loss= ODE+ boundary/initial conditions
            lossDE = self.compiled_loss(d2y_dx2_NN, -M*y_NN) #Esta loss lo que tiene interesante es que self.compiled_loss va a recibir como primer argumento el valor real bueno, y como segundo al valor predicho. Luego, cuando llamamos al metodo compile y le pasamos que tipo de metrica queremos, hara cuentas con ello
            loss = tf.reduce_mean(M + big*self.compiled_loss(I,unit))# Esta loss es el autovalor mas la condicion de normalizacion, esta es con la que entrenamos

        gradients = tape.gradient(loss, self.trainable_weights)#Calcula la derivada de la funcion de perdida respecto a los parametros entrenables
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))#Zip empareja cada derivada de la lista gradientes con el parametro respecto al que se ha derivad0, de forma que le pasamos este tensor al optimizador que aplicara los gradientes y actualiza los parametros
        self.compiled_metrics.update_state(y_exact, y_NN)#Por ultimo, se actualiza el estado respecto al paso anterior con la y_NN calculada en este nuevo paso con los parametros anteriores
        metrics = {m.name: m.result() for m in self.metrics}#Dado que entiendo que el metodo self.compiled_metrics.updatestate actualiza las metricas como atributo del objeto en self.metrics. {} Crea un diccionario, en el que el formato_:_ indica clave:valor asociado 
        metrics['DE']=lossDE
        metrics['loss']=loss
        metrics['I']=I
        metrics['E']=M
        return metrics#Este diccionario creado que devuelve el metodo traning_step es el que utiliza model.fit para calcular las metricas

# %%
# Custom metric
@keras.saving.register_keras_serializable()#La serializamos para que despues al cargar el modelo, no tnegamos que haber definido previamente la funcion, simplemente la habra guardado ya.
def mse_odd_even_sol(y_true, y_pred):
    return tf.minimum(tf.reduce_mean(tf.square(y_pred - y_true)),tf.reduce_mean(tf.square(y_pred + y_true)))#Devuelve el minimo entre y_NN con +-y_real

# %%
# Build the model
checkpoint_callback = ModelCheckpoint(
    filepath=f"variacional_E_fundamental.weights.h5",
    monitor="loss",
    save_best_only=True,
    save_weights_only=True,
    mode="min",
    verbose=1,
)#Esto hace que cuando se lo pasemos a model.fit nos guarde solo los parametros del modelo en variacional_E_fundamental.h5 siempre que la perdida sea menor que en la anterior epoca

# %%
n_train = 500  # 500 for Sergio's estimation, 10 for Javi's
# Avoid the boundaries: ¿derivaties ill-defined at the boundaries?
xmin = 0.0 + (1.0-0.0)/(2*n_train)#xmin que no es cero, es cero mas un delta
xmax = 0.0 + (1.0-0.0)/(2*n_train) + (n_train-1)*(1.0-0.0)/n_train  #1 menos ese mismo delta, es decir, 1-xmin
# Definition of the function domain
x_train,step_dx = np.linspace(xmin,xmax,n_train,retstep=True)#No se coge ni el cero ni el uno porque los hemos forzad a ser cero al multiplicar por x*(1-x) a la yNN
print("dx=",step_dx)

# The solution y(x) for training and validation datasets
n = 1
y_train = np.sqrt(2/1.0)*np.sin(n*np.pi*x_train/1.0)#Funcion solucion real al problema del autovalor fund

print("x(0)=",x_train[0])
print("y(0)=",y_train[0])

# Input and output neurons (from the data)
neurons_layer=[1, 50, 50, 50,1]
n_layers=5


# Define the model
activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

model = EVE_PINN(input,output)
model.set_step_dx(step_dx)

#Define the metrics, optimizer and loss
metrics = [mse_odd_even_sol] #tf.keras.metrics.MeanSquaredError()
optimizer = Adam(learning_rate=0.01)

model.compile(loss='mse',
          optimizer=optimizer,
          metrics=metrics, run_eagerly=False)


# Just use `fit` as usual
callback = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            patience=5000,
                                            restore_best_weights=True)
model.summary()
# Out:
# dx= 0.002
# x(0)= 0.001
# y(0)= 0.0044428756299124735
# Model: "eve_pinn_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,251 (20.51 KB)
#  Trainable params: 5,251 (20.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 5000 # 5000        
history = model.fit(x_train, y_train, batch_size=n_train, epochs=epochs,
                  callbacks=[checkpoint_callback,callback])#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca 

# Save ground model
# Out:
# Epoch 1/5000
# (500, 1)
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:696: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight, training)`.
#   warnings.warn(
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:671: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# (500, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - DE: 0.0213 - E: 14.3234 - I: 8.6128e-05 - mse_odd_even_sol: 0.9828 - loss: 15.3232
# Epoch 1: loss improved from None to 15.32321, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 1: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - DE: 0.0213 - E: 14.3234 - I: 8.6128e-05 - mse_odd_even_sol: 0.9828 - loss: 15.3232
# Epoch 2/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 1.1582 - E: 10.4741 - I: 0.0226 - mse_odd_even_sol: 0.7246 - loss: 11.4294
# Epoch 2: loss improved from 15.32321 to 11.42942, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 2: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - DE: 1.1582 - E: 10.4741 - I: 0.0226 - mse_odd_even_sol: 0.7246 - loss: 11.4294
# Epoch 3/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 1.1055 - E: 10.0270 - I: 0.0303 - mse_odd_even_sol: 0.6829 - loss: 10.9674
# Epoch 3: loss improved from 11.42942 to 10.96741, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 3: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - DE: 1.1055 - E: 10.0270 - I: 0.0303 - mse_odd_even_sol: 0.6829 - loss: 10.9674
# Epoch 4/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.8505 - E: 9.9572 - I: 0.0322 - mse_odd_even_sol: 0.6733 - loss: 10.8938
# Epoch 4: loss improved from 10.96741 to 10.89375, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - DE: 0.8505 - E: 9.9572 - I: 0.0322 - mse_odd_even_sol: 0.6733 - loss: 10.8938
# Epoch 5/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6350 - E: 9.9576 - I: 0.0329 - mse_odd_even_sol: 0.6704 - loss: 10.8929
# Epoch 5: loss improved from 10.89375 to 10.89287, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 5: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - DE: 0.6350 - E: 9.9576 - I: 0.0329 - mse_odd_even_sol: 0.6704 - loss: 10.8929
# Epoch 6/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.5254 - E: 9.9684 - I: 0.0331 - mse_odd_even_sol: 0.6694 - loss: 10.9032
# Epoch 6: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.5254 - E: 9.9684 - I: 0.0331 - mse_odd_even_sol: 0.6694 - loss: 10.9032
# Epoch 7/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.4921 - E: 9.9778 - I: 0.0332 - mse_odd_even_sol: 0.6689 - loss: 10.9125
# Epoch 7: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.4921 - E: 9.9778 - I: 0.0332 - mse_odd_even_sol: 0.6689 - loss: 10.9125
# Epoch 8/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.4966 - E: 9.9845 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9191
# Epoch 8: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.4966 - E: 9.9845 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9191
# Epoch 9/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.5150 - E: 9.9890 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9235
# Epoch 9: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.5150 - E: 9.9890 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9235
# Epoch 10/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.5361 - E: 9.9920 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9265
# Epoch 10: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.5361 - E: 9.9920 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9265
# Epoch 11/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.5556 - E: 9.9940 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9285
# Epoch 11: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.5556 - E: 9.9940 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9285
# Epoch 12/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.5722 - E: 9.9954 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9299
# Epoch 12: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.5722 - E: 9.9954 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9299
# Epoch 13/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.5857 - E: 9.9964 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9308
# Epoch 13: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.5857 - E: 9.9964 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9308
# Epoch 14/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.5967 - E: 9.9971 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9315
# Epoch 14: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.5967 - E: 9.9971 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9315
# Epoch 15/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.6054 - E: 9.9976 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9320
# Epoch 15: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6054 - E: 9.9976 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9320
# Epoch 16/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6125 - E: 9.9980 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9324
# Epoch 16: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6125 - E: 9.9980 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9324
# Epoch 17/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6182 - E: 9.9982 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9327
# Epoch 17: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6182 - E: 9.9982 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9327
# Epoch 18/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6229 - E: 9.9985 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9329
# Epoch 18: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6229 - E: 9.9985 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9329
# Epoch 19/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6266 - E: 9.9986 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9331
# Epoch 19: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6266 - E: 9.9986 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9331
# Epoch 20/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6297 - E: 9.9988 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9332
# Epoch 20: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6297 - E: 9.9988 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9332
# Epoch 21/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.6323 - E: 9.9989 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9333
# Epoch 21: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6323 - E: 9.9989 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9333
# Epoch 22/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6344 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 22: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6344 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 23/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6361 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 23: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6361 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 24/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6376 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 24: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6376 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 25/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6388 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 25: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6388 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 26/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6398 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 26: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6398 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 27/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6406 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 27: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6406 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 28/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6413 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 28: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6413 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 29/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6419 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 29: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6419 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 30/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6423 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 30: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6423 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 31/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6427 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 31: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6427 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 32/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6429 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 32: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6429 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 33/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6431 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 33: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6431 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 34/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6432 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 34: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6432 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 35/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6433 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 35: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6433 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 36/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6433 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 36: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6433 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 37/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6433 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 37: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6433 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 38/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6432 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 38: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6432 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 39/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6431 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 39: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6431 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 40/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6429 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 40: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6429 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 41/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6427 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 41: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6427 - E: 9.9994 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 42/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6425 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 42: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6425 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 43/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6422 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 43: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6422 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 44/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6418 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 44: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6418 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 45/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6415 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 45: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6415 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 46/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6411 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 46: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6411 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9338
# Epoch 47/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6407 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 47: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.6407 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 48/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6402 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 48: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6402 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 49/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6397 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 49: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6397 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 50/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6392 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 50: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6392 - E: 9.9993 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 51/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6386 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 51: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - DE: 0.6386 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 52/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6380 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 52: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6380 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9337
# Epoch 53/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6374 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 53: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6374 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 54/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6367 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 54: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6367 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 55/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6359 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 55: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6359 - E: 9.9992 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 56/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6351 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 56: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6351 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 57/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6343 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 57: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6343 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9336
# Epoch 58/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6334 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 58: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.6334 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 59/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6324 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 59: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6324 - E: 9.9991 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 60/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6314 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 60: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6314 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 61/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6303 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 61: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6303 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 62/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6291 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 62: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6291 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 63/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6279 - E: 9.9989 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 63: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6279 - E: 9.9989 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9334
# Epoch 64/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6265 - E: 9.9989 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9333
# Epoch 64: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6265 - E: 9.9989 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9333
# Epoch 65/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6251 - E: 9.9988 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9333
# Epoch 65: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - DE: 0.6251 - E: 9.9988 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9333
# Epoch 66/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6235 - E: 9.9988 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9332
# Epoch 66: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - DE: 0.6235 - E: 9.9988 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9332
# Epoch 67/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6219 - E: 9.9987 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9332
# Epoch 67: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6219 - E: 9.9987 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9332
# Epoch 68/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6201 - E: 9.9987 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9331
# Epoch 68: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.6201 - E: 9.9987 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9331
# Epoch 69/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6182 - E: 9.9986 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9330
# Epoch 69: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6182 - E: 9.9986 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9330
# Epoch 70/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6161 - E: 9.9985 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9330
# Epoch 70: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6161 - E: 9.9985 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9330
# Epoch 71/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6138 - E: 9.9984 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9329
# Epoch 71: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6138 - E: 9.9984 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9329
# Epoch 72/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6114 - E: 9.9984 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9328
# Epoch 72: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6114 - E: 9.9984 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9328
# Epoch 73/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6087 - E: 9.9983 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9327
# Epoch 73: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6087 - E: 9.9983 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9327
# Epoch 74/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6059 - E: 9.9981 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9326
# Epoch 74: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6059 - E: 9.9981 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9326
# Epoch 75/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6027 - E: 9.9980 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9325
# Epoch 75: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6027 - E: 9.9980 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9325
# Epoch 76/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.5994 - E: 9.9979 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9323
# Epoch 76: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.5994 - E: 9.9979 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9323
# Epoch 77/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.5957 - E: 9.9977 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9322
# Epoch 77: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.5957 - E: 9.9977 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9322
# Epoch 78/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.5917 - E: 9.9976 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9320
# Epoch 78: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.5917 - E: 9.9976 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9320
# Epoch 79/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.5874 - E: 9.9974 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9318
# Epoch 79: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.5874 - E: 9.9974 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9318
# Epoch 80/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.5827 - E: 9.9971 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9316
# Epoch 80: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.5827 - E: 9.9971 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9316
# Epoch 81/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.5778 - E: 9.9969 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9313
# Epoch 81: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.5778 - E: 9.9969 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9313
# Epoch 82/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.5727 - E: 9.9966 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9310
# Epoch 82: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.5727 - E: 9.9966 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9310
# Epoch 83/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.5675 - E: 9.9962 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9307
# Epoch 83: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.5675 - E: 9.9962 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9307
# Epoch 84/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.5626 - E: 9.9958 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9303
# Epoch 84: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.5626 - E: 9.9958 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9303
# Epoch 85/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.5584 - E: 9.9953 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9298
# Epoch 85: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.5584 - E: 9.9953 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9298
# Epoch 86/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.5558 - E: 9.9947 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9292
# Epoch 86: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.5558 - E: 9.9947 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9292
# Epoch 87/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.5566 - E: 9.9940 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9285
# Epoch 87: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.5566 - E: 9.9940 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9285
# Epoch 88/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.5636 - E: 9.9932 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9277
# Epoch 88: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.5636 - E: 9.9932 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9277
# Epoch 89/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.5817 - E: 9.9922 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9267
# Epoch 89: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.5817 - E: 9.9922 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9267
# Epoch 90/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6196 - E: 9.9911 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9255
# Epoch 90: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6196 - E: 9.9911 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9255
# Epoch 91/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6918 - E: 9.9898 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9243
# Epoch 91: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6918 - E: 9.9898 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9243
# Epoch 92/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.8209 - E: 9.9884 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9229
# Epoch 92: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.8209 - E: 9.9884 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9229
# Epoch 93/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 1.0371 - E: 9.9873 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9218
# Epoch 93: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 1.0371 - E: 9.9873 - I: 0.0333 - mse_odd_even_sol: 0.6686 - loss: 10.9218
# Epoch 94/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 1.3645 - E: 9.9868 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9213
# Epoch 94: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 1.3645 - E: 9.9868 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9213
# Epoch 95/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 1.7775 - E: 9.9872 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9218
# Epoch 95: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 1.7775 - E: 9.9872 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9218
# Epoch 96/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 2.1425 - E: 9.9882 - I: 0.0333 - mse_odd_even_sol: 0.6688 - loss: 10.9228
# Epoch 96: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 2.1425 - E: 9.9882 - I: 0.0333 - mse_odd_even_sol: 0.6688 - loss: 10.9228
# Epoch 97/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 2.2710 - E: 9.9885 - I: 0.0332 - mse_odd_even_sol: 0.6688 - loss: 10.9232
# Epoch 97: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 2.2710 - E: 9.9885 - I: 0.0332 - mse_odd_even_sol: 0.6688 - loss: 10.9232
# Epoch 98/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 2.1093 - E: 9.9876 - I: 0.0332 - mse_odd_even_sol: 0.6688 - loss: 10.9222
# Epoch 98: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 2.1093 - E: 9.9876 - I: 0.0332 - mse_odd_even_sol: 0.6688 - loss: 10.9222
# Epoch 99/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 1.7847 - E: 9.9861 - I: 0.0333 - mse_odd_even_sol: 0.6688 - loss: 10.9207
# Epoch 99: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 1.7847 - E: 9.9861 - I: 0.0333 - mse_odd_even_sol: 0.6688 - loss: 10.9207
# Epoch 100/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 1.4545 - E: 9.9850 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9196
# Epoch 100: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 1.4545 - E: 9.9850 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9196
# Epoch 101/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 1.1987 - E: 9.9845 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9191
# Epoch 101: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 1.1987 - E: 9.9845 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9191
# Epoch 102/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 1.0274 - E: 9.9844 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9190
# Epoch 102: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - DE: 1.0274 - E: 9.9844 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9190
# Epoch 103/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.9235 - E: 9.9843 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9189
# Epoch 103: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.9235 - E: 9.9843 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9189
# Epoch 104/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.8682 - E: 9.9841 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9187
# Epoch 104: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.8682 - E: 9.9841 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9187
# Epoch 105/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.8493 - E: 9.9837 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9183
# Epoch 105: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.8493 - E: 9.9837 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9183
# Epoch 106/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.8609 - E: 9.9830 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9176
# Epoch 106: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.8609 - E: 9.9830 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9176
# Epoch 107/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.9026 - E: 9.9821 - I: 0.0333 - mse_odd_even_sol: 0.6688 - loss: 10.9167
# Epoch 107: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.9026 - E: 9.9821 - I: 0.0333 - mse_odd_even_sol: 0.6688 - loss: 10.9167
# Epoch 108/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.9771 - E: 9.9810 - I: 0.0332 - mse_odd_even_sol: 0.6688 - loss: 10.9156
# Epoch 108: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.9771 - E: 9.9810 - I: 0.0332 - mse_odd_even_sol: 0.6688 - loss: 10.9156
# Epoch 109/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 1.0862 - E: 9.9799 - I: 0.0332 - mse_odd_even_sol: 0.6689 - loss: 10.9145
# Epoch 109: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 1.0862 - E: 9.9799 - I: 0.0332 - mse_odd_even_sol: 0.6689 - loss: 10.9145
# Epoch 110/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 1.2235 - E: 9.9789 - I: 0.0332 - mse_odd_even_sol: 0.6690 - loss: 10.9136
# Epoch 110: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 1.2235 - E: 9.9789 - I: 0.0332 - mse_odd_even_sol: 0.6690 - loss: 10.9136
# Epoch 111/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 1.3641 - E: 9.9782 - I: 0.0332 - mse_odd_even_sol: 0.6691 - loss: 10.9129
# Epoch 111: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 1.3641 - E: 9.9782 - I: 0.0332 - mse_odd_even_sol: 0.6691 - loss: 10.9129
# Epoch 112/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 1.4624 - E: 9.9775 - I: 0.0332 - mse_odd_even_sol: 0.6692 - loss: 10.9123
# Epoch 112: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 1.4624 - E: 9.9775 - I: 0.0332 - mse_odd_even_sol: 0.6692 - loss: 10.9123
# Epoch 113/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 1.4740 - E: 9.9767 - I: 0.0331 - mse_odd_even_sol: 0.6692 - loss: 10.9115
# Epoch 113: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 1.4740 - E: 9.9767 - I: 0.0331 - mse_odd_even_sol: 0.6692 - loss: 10.9115
# Epoch 114/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 1.3920 - E: 9.9753 - I: 0.0331 - mse_odd_even_sol: 0.6693 - loss: 10.9102
# Epoch 114: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 1.3920 - E: 9.9753 - I: 0.0331 - mse_odd_even_sol: 0.6693 - loss: 10.9102
# Epoch 115/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 1.2544 - E: 9.9738 - I: 0.0331 - mse_odd_even_sol: 0.6693 - loss: 10.9087
# Epoch 115: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 1.2544 - E: 9.9738 - I: 0.0331 - mse_odd_even_sol: 0.6693 - loss: 10.9087
# Epoch 116/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 1.1114 - E: 9.9724 - I: 0.0331 - mse_odd_even_sol: 0.6693 - loss: 10.9073
# Epoch 116: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 1.1114 - E: 9.9724 - I: 0.0331 - mse_odd_even_sol: 0.6693 - loss: 10.9073
# Epoch 117/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.9953 - E: 9.9711 - I: 0.0331 - mse_odd_even_sol: 0.6694 - loss: 10.9060
# Epoch 117: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.9953 - E: 9.9711 - I: 0.0331 - mse_odd_even_sol: 0.6694 - loss: 10.9060
# Epoch 118/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.9166 - E: 9.9698 - I: 0.0331 - mse_odd_even_sol: 0.6695 - loss: 10.9047
# Epoch 118: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.9166 - E: 9.9698 - I: 0.0331 - mse_odd_even_sol: 0.6695 - loss: 10.9047
# Epoch 119/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.8739 - E: 9.9682 - I: 0.0331 - mse_odd_even_sol: 0.6696 - loss: 10.9032
# Epoch 119: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - DE: 0.8739 - E: 9.9682 - I: 0.0331 - mse_odd_even_sol: 0.6696 - loss: 10.9032
# Epoch 120/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.8614 - E: 9.9664 - I: 0.0330 - mse_odd_even_sol: 0.6697 - loss: 10.9014
# Epoch 120: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.8614 - E: 9.9664 - I: 0.0330 - mse_odd_even_sol: 0.6697 - loss: 10.9014
# Epoch 121/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.8715 - E: 9.9643 - I: 0.0330 - mse_odd_even_sol: 0.6700 - loss: 10.8995
# Epoch 121: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.8715 - E: 9.9643 - I: 0.0330 - mse_odd_even_sol: 0.6700 - loss: 10.8995
# Epoch 122/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.8914 - E: 9.9623 - I: 0.0329 - mse_odd_even_sol: 0.6703 - loss: 10.8976
# Epoch 122: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.8914 - E: 9.9623 - I: 0.0329 - mse_odd_even_sol: 0.6703 - loss: 10.8976
# Epoch 123/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.8989 - E: 9.9604 - I: 0.0328 - mse_odd_even_sol: 0.6708 - loss: 10.8959
# Epoch 123: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.8989 - E: 9.9604 - I: 0.0328 - mse_odd_even_sol: 0.6708 - loss: 10.8959
# Epoch 124/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.8688 - E: 9.9586 - I: 0.0327 - mse_odd_even_sol: 0.6712 - loss: 10.8943
# Epoch 124: loss did not improve from 10.89287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.8688 - E: 9.9586 - I: 0.0327 - mse_odd_even_sol: 0.6712 - loss: 10.8943
# Epoch 125/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - DE: 0.7937 - E: 9.9567 - I: 0.0326 - mse_odd_even_sol: 0.6716 - loss: 10.8925
# Epoch 125: loss improved from 10.89287 to 10.89250, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 125: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - DE: 0.7937 - E: 9.9567 - I: 0.0326 - mse_odd_even_sol: 0.6716 - loss: 10.8925
# Epoch 126/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6952 - E: 9.9547 - I: 0.0325 - mse_odd_even_sol: 0.6719 - loss: 10.8907
# Epoch 126: loss improved from 10.89250 to 10.89070, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 126: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - DE: 0.6952 - E: 9.9547 - I: 0.0325 - mse_odd_even_sol: 0.6719 - loss: 10.8907
# Epoch 127/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6038 - E: 9.9532 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8893
# Epoch 127: loss improved from 10.89070 to 10.88927, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 127: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - DE: 0.6038 - E: 9.9532 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8893
# Epoch 128/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.5355 - E: 9.9520 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8883
# Epoch 128: loss improved from 10.88927 to 10.88829, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 128: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - DE: 0.5355 - E: 9.9520 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8883
# Epoch 129/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.4896 - E: 9.9511 - I: 0.0323 - mse_odd_even_sol: 0.6732 - loss: 10.8876
# Epoch 129: loss improved from 10.88829 to 10.88762, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 129: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - DE: 0.4896 - E: 9.9511 - I: 0.0323 - mse_odd_even_sol: 0.6732 - loss: 10.8876
# Epoch 130/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.4592 - E: 9.9504 - I: 0.0321 - mse_odd_even_sol: 0.6739 - loss: 10.8872
# Epoch 130: loss improved from 10.88762 to 10.88723, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 130: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - DE: 0.4592 - E: 9.9504 - I: 0.0321 - mse_odd_even_sol: 0.6739 - loss: 10.8872
# Epoch 131/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.4371 - E: 9.9500 - I: 0.0319 - mse_odd_even_sol: 0.6748 - loss: 10.8872
# Epoch 131: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.4371 - E: 9.9500 - I: 0.0319 - mse_odd_even_sol: 0.6748 - loss: 10.8872
# Epoch 132/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.4178 - E: 9.9501 - I: 0.0317 - mse_odd_even_sol: 0.6757 - loss: 10.8876
# Epoch 132: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.4178 - E: 9.9501 - I: 0.0317 - mse_odd_even_sol: 0.6757 - loss: 10.8876
# Epoch 133/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.3996 - E: 9.9503 - I: 0.0316 - mse_odd_even_sol: 0.6762 - loss: 10.8881
# Epoch 133: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.3996 - E: 9.9503 - I: 0.0316 - mse_odd_even_sol: 0.6762 - loss: 10.8881
# Epoch 134/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.3844 - E: 9.9506 - I: 0.0316 - mse_odd_even_sol: 0.6764 - loss: 10.8884
# Epoch 134: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.3844 - E: 9.9506 - I: 0.0316 - mse_odd_even_sol: 0.6764 - loss: 10.8884
# Epoch 135/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.3749 - E: 9.9508 - I: 0.0316 - mse_odd_even_sol: 0.6762 - loss: 10.8886
# Epoch 135: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.3749 - E: 9.9508 - I: 0.0316 - mse_odd_even_sol: 0.6762 - loss: 10.8886
# Epoch 136/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.3705 - E: 9.9510 - I: 0.0317 - mse_odd_even_sol: 0.6760 - loss: 10.8887
# Epoch 136: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.3705 - E: 9.9510 - I: 0.0317 - mse_odd_even_sol: 0.6760 - loss: 10.8887
# Epoch 137/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.3695 - E: 9.9509 - I: 0.0317 - mse_odd_even_sol: 0.6758 - loss: 10.8885
# Epoch 137: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.3695 - E: 9.9509 - I: 0.0317 - mse_odd_even_sol: 0.6758 - loss: 10.8885
# Epoch 138/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.3709 - E: 9.9505 - I: 0.0317 - mse_odd_even_sol: 0.6758 - loss: 10.8881
# Epoch 138: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.3709 - E: 9.9505 - I: 0.0317 - mse_odd_even_sol: 0.6758 - loss: 10.8881
# Epoch 139/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.3754 - E: 9.9500 - I: 0.0317 - mse_odd_even_sol: 0.6758 - loss: 10.8875
# Epoch 139: loss did not improve from 10.88723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.3754 - E: 9.9500 - I: 0.0317 - mse_odd_even_sol: 0.6758 - loss: 10.8875
# Epoch 140/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.3836 - E: 9.9495 - I: 0.0317 - mse_odd_even_sol: 0.6757 - loss: 10.8870
# Epoch 140: loss improved from 10.88723 to 10.88704, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 140: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - DE: 0.3836 - E: 9.9495 - I: 0.0317 - mse_odd_even_sol: 0.6757 - loss: 10.8870
# Epoch 141/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.3937 - E: 9.9492 - I: 0.0318 - mse_odd_even_sol: 0.6755 - loss: 10.8866
# Epoch 141: loss improved from 10.88704 to 10.88661, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 141: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - DE: 0.3937 - E: 9.9492 - I: 0.0318 - mse_odd_even_sol: 0.6755 - loss: 10.8866
# Epoch 142/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.4031 - E: 9.9489 - I: 0.0319 - mse_odd_even_sol: 0.6750 - loss: 10.8862
# Epoch 142: loss improved from 10.88661 to 10.88621, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 142: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - DE: 0.4031 - E: 9.9489 - I: 0.0319 - mse_odd_even_sol: 0.6750 - loss: 10.8862
# Epoch 143/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.4106 - E: 9.9488 - I: 0.0320 - mse_odd_even_sol: 0.6745 - loss: 10.8859
# Epoch 143: loss improved from 10.88621 to 10.88590, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 143: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - DE: 0.4106 - E: 9.9488 - I: 0.0320 - mse_odd_even_sol: 0.6745 - loss: 10.8859
# Epoch 144/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.4173 - E: 9.9489 - I: 0.0321 - mse_odd_even_sol: 0.6741 - loss: 10.8857
# Epoch 144: loss improved from 10.88590 to 10.88575, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 144: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.4173 - E: 9.9489 - I: 0.0321 - mse_odd_even_sol: 0.6741 - loss: 10.8857
# Epoch 145/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.4250 - E: 9.9490 - I: 0.0321 - mse_odd_even_sol: 0.6737 - loss: 10.8857
# Epoch 145: loss improved from 10.88575 to 10.88569, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 145: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.4250 - E: 9.9490 - I: 0.0321 - mse_odd_even_sol: 0.6737 - loss: 10.8857
# Epoch 146/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.4349 - E: 9.9490 - I: 0.0322 - mse_odd_even_sol: 0.6735 - loss: 10.8857
# Epoch 146: loss improved from 10.88569 to 10.88566, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 146: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - DE: 0.4349 - E: 9.9490 - I: 0.0322 - mse_odd_even_sol: 0.6735 - loss: 10.8857
# Epoch 147/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.4466 - E: 9.9490 - I: 0.0322 - mse_odd_even_sol: 0.6734 - loss: 10.8856
# Epoch 147: loss improved from 10.88566 to 10.88564, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 147: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - DE: 0.4466 - E: 9.9490 - I: 0.0322 - mse_odd_even_sol: 0.6734 - loss: 10.8856
# Epoch 148/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.4578 - E: 9.9490 - I: 0.0322 - mse_odd_even_sol: 0.6734 - loss: 10.8856
# Epoch 148: loss did not improve from 10.88564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.4578 - E: 9.9490 - I: 0.0322 - mse_odd_even_sol: 0.6734 - loss: 10.8856
# Epoch 149/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.4651 - E: 9.9491 - I: 0.0322 - mse_odd_even_sol: 0.6734 - loss: 10.8857
# Epoch 149: loss did not improve from 10.88564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.4651 - E: 9.9491 - I: 0.0322 - mse_odd_even_sol: 0.6734 - loss: 10.8857
# Epoch 150/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.4658 - E: 9.9491 - I: 0.0322 - mse_odd_even_sol: 0.6733 - loss: 10.8856
# Epoch 150: loss improved from 10.88564 to 10.88561, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 150: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.4658 - E: 9.9491 - I: 0.0322 - mse_odd_even_sol: 0.6733 - loss: 10.8856
# Epoch 151/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.4609 - E: 9.9490 - I: 0.0323 - mse_odd_even_sol: 0.6732 - loss: 10.8855
# Epoch 151: loss improved from 10.88561 to 10.88552, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 151: finished saving model to variacional_E_fundamental.weights.h5
# ...
# Epoch 4951: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.3453 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8735
# Epoch 4952/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.3485 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8734
# Epoch 4952: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.3485 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8734
# Epoch 4953/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.3450 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4953: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.3450 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4954/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.3478 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8734
# Epoch 4954: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.3478 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8734
# Epoch 4955/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.3448 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4955: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.3448 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4956/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.3471 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8734
# Epoch 4956: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.3471 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8734
# Epoch 4957/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4957: loss did not improve from 10.87336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4958/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.3465 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4958: loss improved from 10.87336 to 10.87335, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4958: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - DE: 0.3465 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4959/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.3445 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4959: loss improved from 10.87335 to 10.87334, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4959: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - DE: 0.3445 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4960/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.3459 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4960: loss improved from 10.87334 to 10.87334, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4960: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - DE: 0.3459 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4961/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.3445 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4961: loss improved from 10.87334 to 10.87333, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4961: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - DE: 0.3445 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4962/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.3455 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4962: loss improved from 10.87333 to 10.87333, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4962: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - DE: 0.3455 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4963/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8733
# Epoch 4963: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8733
# Epoch 4964/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.3453 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4964: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - DE: 0.3453 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4965/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.3447 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8733
# Epoch 4965: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - DE: 0.3447 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8733
# Epoch 4966/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - DE: 0.3452 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6728 - loss: 10.8734
# Epoch 4966: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - DE: 0.3452 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6728 - loss: 10.8734
# Epoch 4967/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - DE: 0.3449 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6724 - loss: 10.8734
# Epoch 4967: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - DE: 0.3449 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6724 - loss: 10.8734
# Epoch 4968/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - DE: 0.3453 - E: 9.9370 - I: 0.0323 - mse_odd_even_sol: 0.6728 - loss: 10.8734
# Epoch 4968: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - DE: 0.3453 - E: 9.9370 - I: 0.0323 - mse_odd_even_sol: 0.6728 - loss: 10.8734
# Epoch 4969/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - DE: 0.3452 - E: 9.9373 - I: 0.0324 - mse_odd_even_sol: 0.6724 - loss: 10.8734
# Epoch 4969: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - DE: 0.3452 - E: 9.9373 - I: 0.0324 - mse_odd_even_sol: 0.6724 - loss: 10.8734
# Epoch 4970/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - DE: 0.3455 - E: 9.9371 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8734
# Epoch 4970: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - DE: 0.3455 - E: 9.9371 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8734
# Epoch 4971/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - DE: 0.3454 - E: 9.9374 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8735
# Epoch 4971: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - DE: 0.3454 - E: 9.9374 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8735
# Epoch 4972/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - DE: 0.3460 - E: 9.9371 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8735
# Epoch 4972: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - DE: 0.3460 - E: 9.9371 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8735
# Epoch 4973/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - DE: 0.3455 - E: 9.9375 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8736
# Epoch 4973: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - DE: 0.3455 - E: 9.9375 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8736
# Epoch 4974/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - DE: 0.3466 - E: 9.9371 - I: 0.0323 - mse_odd_even_sol: 0.6730 - loss: 10.8736
# Epoch 4974: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - DE: 0.3466 - E: 9.9371 - I: 0.0323 - mse_odd_even_sol: 0.6730 - loss: 10.8736
# Epoch 4975/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - DE: 0.3455 - E: 9.9375 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8737
# Epoch 4975: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - DE: 0.3455 - E: 9.9375 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8737
# Epoch 4976/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - DE: 0.3475 - E: 9.9372 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8736
# Epoch 4976: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - DE: 0.3475 - E: 9.9372 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8736
# Epoch 4977/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - DE: 0.3454 - E: 9.9375 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8737
# Epoch 4977: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - DE: 0.3454 - E: 9.9375 - I: 0.0325 - mse_odd_even_sol: 0.6723 - loss: 10.8737
# Epoch 4978/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.3485 - E: 9.9372 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8736
# Epoch 4978: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - DE: 0.3485 - E: 9.9372 - I: 0.0323 - mse_odd_even_sol: 0.6729 - loss: 10.8736
# Epoch 4979/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - DE: 0.3455 - E: 9.9375 - I: 0.0324 - mse_odd_even_sol: 0.6724 - loss: 10.8736
# Epoch 4979: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - DE: 0.3455 - E: 9.9375 - I: 0.0324 - mse_odd_even_sol: 0.6724 - loss: 10.8736
# Epoch 4980/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - DE: 0.3493 - E: 9.9372 - I: 0.0323 - mse_odd_even_sol: 0.6728 - loss: 10.8735
# Epoch 4980: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - DE: 0.3493 - E: 9.9372 - I: 0.0323 - mse_odd_even_sol: 0.6728 - loss: 10.8735
# Epoch 4981/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.3456 - E: 9.9374 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8736
# Epoch 4981: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.3456 - E: 9.9374 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8736
# Epoch 4982/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.3498 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8735
# Epoch 4982: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - DE: 0.3498 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8735
# Epoch 4983/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.3457 - E: 9.9373 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8736
# Epoch 4983: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - DE: 0.3457 - E: 9.9373 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8736
# Epoch 4984/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - DE: 0.3499 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8735
# Epoch 4984: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - DE: 0.3499 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8735
# Epoch 4985/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.3456 - E: 9.9373 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8735
# Epoch 4985: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - DE: 0.3456 - E: 9.9373 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8735
# Epoch 4986/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.3496 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8735
# Epoch 4986: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.3496 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8735
# Epoch 4987/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.3454 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8735
# Epoch 4987: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - DE: 0.3454 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8735
# Epoch 4988/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - DE: 0.3488 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4988: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - DE: 0.3488 - E: 9.9372 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4989/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.3450 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4989: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.3450 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4990/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.3478 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4990: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - DE: 0.3478 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4991/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.3448 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4991: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.3448 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8734
# Epoch 4992/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.3468 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4992: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.3468 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4993/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4993: loss did not improve from 10.87333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4994/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.3460 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4994: loss improved from 10.87333 to 10.87333, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4994: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - DE: 0.3460 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4995/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4995: loss improved from 10.87333 to 10.87332, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4995: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - DE: 0.3446 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4996/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.3454 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4996: loss improved from 10.87332 to 10.87331, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4996: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - DE: 0.3454 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4997/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.3448 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4997: loss did not improve from 10.87331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - DE: 0.3448 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6726 - loss: 10.8733
# Epoch 4998/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.3451 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4998: loss did not improve from 10.87331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - DE: 0.3451 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6727 - loss: 10.8733
# Epoch 4999/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.3450 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8733
# Epoch 4999: loss did not improve from 10.87331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.3450 - E: 9.9371 - I: 0.0324 - mse_odd_even_sol: 0.6725 - loss: 10.8733
# Epoch 5000/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.3449 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6728 - loss: 10.8733
# Epoch 5000: loss did not improve from 10.87331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.3449 - E: 9.9370 - I: 0.0324 - mse_odd_even_sol: 0.6728 - loss: 10.8733

# %%
print('Hola mundo')
# Out:
# Hola mundo
