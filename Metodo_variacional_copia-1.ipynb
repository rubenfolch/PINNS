# %%
# Tensorflow Keras and rest of the packages
import tensorflow as tf
import keras as keras
from tensorflow.keras import models,Model
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def nn_model(activation,neurons_layer,n_layers):
    input=Input(shape=(neurons_layer[0],))
    x=input
    for hidden_layer_neurons in neurons_layer[1:-1]: 
        x=Dense(hidden_layer_neurons,activation=activation)(x)
    output=Dense(neurons_layer[n_layers-1])(x)
    return input,output

# %%
@keras.saving.register_keras_serializable()#Esto hace que se pueda guardar el modelo y cargarlo sin problemas despues
class EVE_PINN(tf.keras.Model):# Esta clase va a heredar de la clase Model de Keras, lo que nos permite usar todos los metodos de la clase Model y ademas definir nuestros propios metodos
    def set_step_dx(self,dx): #Este metodo inicializa la clase
      self.dx=dx #Lo que hace esto es que al objeto que luego instanciamos le asigna el atributo dx, que va a ser espaciado entre puntos

    def train_step(self, data):#Metodo que tiene internamente la clase Model del API de Keras
        x, y_exact = data

        # Use only for run_eagerly=True
        pi = tf.constant(np.pi)
        M0 = tf.square(pi)

        #Change initial conditions for the PINN
        x0 = tf.constant([0.0], dtype=tf.float32)
        xL = tf.constant([1.0], dtype=tf.float32) # We consider L=1
        y0_exact = tf.constant([0.0], dtype=tf.float32)
        yL_exact = tf.constant([0.0], dtype=tf.float32)
        xi = tf.reshape(x,(x.shape[0],1))#Reconversion del batch de entrada a un vector columna
        unit = tf.constant(1.0, dtype=tf.float32)
        unit = tf.reshape(unit,shape=xi[0].shape)

        # loss set to zero
        lossDE = tf.constant(0.0, dtype=tf.float32)

        # Averaged eigenvalue
        M = tf.constant(0.0, dtype=tf.float32)

        # Spatial mesh
        dx = tf.constant(self.dx,dtype=tf.float32)

        with tf.GradientTape() as tape:

            # Calculate the second derivative dy2/dx2
            with tf.GradientTape() as tape1:
                tape1.watch(xi)
                with tf.GradientTape() as tape2:
                    tape2.watch(xi)#Watch le dice en que tensor se tiene que fijar para los calculos, aqui le decimos que mire el batch de entrada porque luego lo utilizamos para calcular la salida, esto es asi porque tape solo se fija en tensores variables y xi es constante 
                    y_NN = xi*(unit-xi)*self(xi,training=False)#Cálculo de la y_NN para todos los datos, self(xi) hace el paso hacia delante del batch de entrada, y multplicamos por x*(1-x) para asegurar que la salida cumple las condiciones de contorno. Training=false porque esto solo sirve para calcular la funcion de perdida, es decir, estamos haciendo un predict de los datos xi de entrada
                    print(y_NN.shape)#Esto devolvera cual es el tamaño de la salida, que sera de otro vector columna, cada elemento la salida de cada dato de entrada del batch
                    tape2.watch(y_NN)#Ahora que esta calculada la salida, nos fijamos en el tensor de salida, de forma que ya podremos hacer la derivada
                dy_dx_NN = tape2.gradient(y_NN, xi)#Calcula la derivada de la salida respecto a la entrada, nos devolvera otro vector
                tape1.watch(y_NN)#De nuevo, se tiene que fijar
                tape1.watch(dy_dx_NN)#...
            d2y_dx2_NN = tf.squeeze(tape1.gradient(dy_dx_NN, xi))#Segunda derivada
            y_NN = tf.squeeze(y_NN)#Squeeze elimina las dimensiones de tamaño a 1 en lso tensores, osea si tenemos un vector que seria un tensor de shape(y,1) al hacer squeeze pasa a ser solo de shape(y,)
            tape.watch(xi)
            tape.watch(y_NN)
            tape.watch(dy_dx_NN)
            tape.watch(d2y_dx2_NN)

            num = tf.reduce_sum(tf.math.multiply(y_NN,-d2y_dx2_NN))#Esto es el producto escalar de y con la segunda derivada de y, no se multiplica por dx porque se va a ir luego al ser un cociente num/den
            den = tf.reduce_sum(tf.math.pow(y_NN,2)) # Could this be zero? #Norma al cuadrado de y
            M = num/den #Funcio de perdidad, que intentamos que cuando sea minima coincida con el autoestado fundamental
            M = tf.reshape(M,shape=xi[0].shape)#Reconvertimos en tensor de tamaño 0 porque era un esacalar, a un tensor de tamaño, que solo tiene un elemento que es el escalar.

            I = tf.constant(0.0, dtype=tf.float32)
            I = tf.math.reduce_sum(tf.math.pow(y_NN,2))
            I = tf.multiply(I,dx)
            I = tf.reshape(I,shape=xi[0].shape)#Se van creando copias de I hasta que llegamos al tensor que es ahora si la morma al cuadrado multiplicada por el factor dx de discretizacion, tambien es de dimension 1con el reshape

            big = tf.constant(1.0, dtype=tf.float32)
            big = tf.reshape(big,shape=xi[0].shape)#Se crea un tensor con todos 1 de una dimension, osea un uno

            #Loss= ODE+ boundary/initial conditions
            lossDE = self.compiled_loss(d2y_dx2_NN, -M*y_NN) #Esta loss lo que tiene interesante es que self.compiled_loss va a recibir como primer argumento el valor real bueno, y como segundo al valor predicho. Luego, cuando llamamos al metodo compile y le pasamos que tipo de metrica queremos, hara cuentas con ello
            loss = tf.reduce_mean(M + big*self.compiled_loss(I,unit))# Esta loss es el autovalor mas la condicion de normalizacion, esta es con la que entrenamos

        gradients = tape.gradient(loss, self.trainable_weights)#Calcula la derivada de la funcion de perdida respecto a los parametros entrenables
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))#Zip empareja cada derivada de la lista gradientes con el parametro respecto al que se ha derivad0, de forma que le pasamos este tensor al optimizador que aplicara los gradientes y actualiza los parametros
        self.compiled_metrics.update_state(y_exact, y_NN)#Por ultimo, se actualiza el estado respecto al paso anterior con la y_NN calculada en este nuevo paso con los parametros anteriores
        metrics = {m.name: m.result() for m in self.metrics}#Dado que entiendo que el metodo self.compiled_metrics.updatestate actualiza las metricas como atributo del objeto en self.metrics. {} Crea un diccionario, en el que el formato_:_ indica clave:valor asociado 
        metrics['DE']=lossDE
        metrics['loss']=loss
        metrics['I']=I
        metrics['E']=M
        return metrics#Este diccionario creado que devuelve el metodo traning_step es el que utiliza model.fit para calcular las metricas

# %%
## Custom metric
@keras.saving.register_keras_serializable()#La serializamos para que despues al cargar el modelo, no tengamos que haber definido previamente la funcion, simplemente la habra guardado ya.
def mse_odd_even_sol(y_true, y_pred):
    return tf.minimum(tf.reduce_mean(tf.square(y_pred - y_true)),tf.reduce_mean(tf.square(y_pred + y_true)))#Devuelve el minimo entre y_NN con +-y_real

# %%
# Build the model
checkpoint_callback = ModelCheckpoint(
    filepath=f"variacional_E_fundamental.weights.h5",
    monitor="loss",
    save_best_only=True,
    save_weights_only=True,
    mode="min",
    verbose=1,
)#Esto hace que cuando se lo pasemos a model.fit nos guarde solo los parametros del modelo en variacional_E_fundamental.h5 siempre que la perdida sea menor que en la anterior epoca

# %%
n_train = 500  # 500 for Sergio's estimation, 10 for Javi's
# Avoid the boundaries: ¿derivaties ill-defined at the boundaries?
xmin = 0.0 + (1.0-0.0)/(2*n_train)#xmin que no es cero, es cero mas un delta
xmax = 0.0 + (1.0-0.0)/(2*n_train) + (n_train-1)*(1.0-0.0)/n_train  #1 menos ese mismo delta, es decir, 1-xmin
# Definition of the function domain
x_train,step_dx = np.linspace(xmin,xmax,n_train,retstep=True)#No se coge ni el cero ni el uno porque los hemos forzad a ser cero al multiplicar por x*(1-x) a la yNN
print("dx=",step_dx)

# The solution y(x) for training and validation datasets
n = 1
y_train = np.sqrt(2/1.0)*np.sin(n*np.pi*x_train/1.0)#Funcion solucion real al problema del autovalor fund

print("x(0)=",x_train[0])
print("y(0)=",y_train[0])

# Input and output neurons (from the data)
neurons_layer=[1, 50, 50, 50,1]
n_layers=5


# Define the model
activation = 'tanh'
input,output = nn_model(activation,neurons_layer,n_layers)

model = EVE_PINN(input,output)
model.set_step_dx(step_dx)

#Define the metrics, optimizer and loss
metrics = [mse_odd_even_sol] #tf.keras.metrics.MeanSquaredError()
lr=0.01
optimizer = Adam(learning_rate=lr)

model.compile(loss='mse',
          optimizer=optimizer,
          metrics=metrics, run_eagerly=False)


# Just use `fit` as usual
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            #patience=5000,
                                            #restore_best_weights=True)
model.summary()
# Out:
# dx= 0.002
# x(0)= 0.001
# y(0)= 0.0044428756299124735
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "eve_pinn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,251 (20.51 KB)
#  Trainable params: 5,251 (20.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
pochs = 2000 # 5000        
history = model.fit(x_train, y_train, batch_size=n_train, epochs=epochs,
                  callbacks=[checkpoint_callback])#Evidentemente sin validacion, tamaño del batch=n_train, cada batch es una epoca 

name='Estado_fundamental_copia-1.keras'
model.save(name)
# Out:
# Epoch 1/5000
# (500, 1)
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:696: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight, training)`.
#   warnings.warn(
# c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:671: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# (500, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - DE: 0.2562 - E: 13.3144 - I: 0.0015 - mse_odd_even_sol: 0.9292 - loss: 14.3115
# Epoch 1: loss improved from None to 14.31146, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 1: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - DE: 0.2562 - E: 13.3144 - I: 0.0015 - mse_odd_even_sol: 0.9292 - loss: 14.3115
# Epoch 2/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 1.2459 - E: 10.4514 - I: 0.0231 - mse_odd_even_sol: 0.7215 - loss: 11.4057
# Epoch 2: loss improved from 14.31146 to 11.40568, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 2: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - DE: 1.2459 - E: 10.4514 - I: 0.0231 - mse_odd_even_sol: 0.7215 - loss: 11.4057
# Epoch 3/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 1.1070 - E: 9.9766 - I: 0.0317 - mse_odd_even_sol: 0.6759 - loss: 10.9143
# Epoch 3: loss improved from 11.40568 to 10.91426, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 3: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - DE: 1.1070 - E: 9.9766 - I: 0.0317 - mse_odd_even_sol: 0.6759 - loss: 10.9143
# Epoch 4/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6380 - E: 9.9639 - I: 0.0330 - mse_odd_even_sol: 0.6697 - loss: 10.8989
# Epoch 4: loss improved from 10.91426 to 10.89887, saving model to variacional_E_fundamental.weights.h5
#
# Epoch 4: finished saving model to variacional_E_fundamental.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - DE: 0.6380 - E: 9.9639 - I: 0.0330 - mse_odd_even_sol: 0.6697 - loss: 10.8989
# Epoch 5/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.5073 - E: 9.9839 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9185
# Epoch 5: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.5073 - E: 9.9839 - I: 0.0333 - mse_odd_even_sol: 0.6687 - loss: 10.9185
# Epoch 6/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.5475 - E: 9.9937 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9282
# Epoch 6: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.5475 - E: 9.9937 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9282
# Epoch 7/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.5993 - E: 9.9976 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9320
# Epoch 7: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.5993 - E: 9.9976 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9320
# Epoch 8/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6315 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 8: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - DE: 0.6315 - E: 9.9990 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9335
# Epoch 9/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6485 - E: 9.9996 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9340
# Epoch 9: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.6485 - E: 9.9996 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9340
# Epoch 10/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6571 - E: 9.9998 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9343
# Epoch 10: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6571 - E: 9.9998 - I: 0.0333 - mse_odd_even_sol: 0.6685 - loss: 10.9343
# Epoch 11/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6615 - E: 9.9999 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 11: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6615 - E: 9.9999 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 12/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - DE: 0.6637 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 12: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - DE: 0.6637 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 13/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6650 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 13: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6650 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 14/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6656 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 14: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.6656 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9344
# Epoch 15/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6660 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 15: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6660 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 16/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6662 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 16: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6662 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 17/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6664 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 17: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.6664 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 18/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6665 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 18: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6665 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 19/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6665 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 19: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6665 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 20/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6665 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 20: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6665 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 21/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 21: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 22/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 22: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 23/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 23: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 24/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 24: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 25/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 25: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 26/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 26: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 27/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 27: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 28/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 28: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 29/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 29: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 30/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 30: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 31/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 31: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 32/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 32: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 33/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 33: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 34/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 34: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 35/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 35: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 36/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 36: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 37/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 37: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 38/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 38: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 39/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 39: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 40/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 40: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 41/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 41: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 42/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 42: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 43/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 43: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 44/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 44: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 45/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 45: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 46/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 46: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 47/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 47: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 48/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 48: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 49/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 49: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 50/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 50: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 51/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 51: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 52/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 52: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 53/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 53: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 54/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 54: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 55/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 55: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 56/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 56: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 57/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 57: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 58/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 58: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 59/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 59: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 60/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 60: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 61/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 61: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 62/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 62: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 63/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 63: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 64/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 64: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 65/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 65: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 66/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 66: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 67/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 67: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 68/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 68: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 69/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 69: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 70/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 70: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 71/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 71: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 72/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 72: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 73/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 73: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 74/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 74: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 75/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 75: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 76/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 76: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 77/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 77: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 78/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 78: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 79/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 79: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 80/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 80: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 81/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 81: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 82/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 82: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 83/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 83: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 84/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 84: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 85/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 85: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 86/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 86: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 87/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 87: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 88/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 88: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 89/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 89: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 90/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 90: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 91/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 91: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 92/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 92: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 93/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 93: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 94/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 94: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 95/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 95: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 96/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 96: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 97/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 97: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 98/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 98: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 99/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 99: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 100/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 100: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 101/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 101: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 102/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 102: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 103/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 103: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 104/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 104: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 105/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 105: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 106/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 106: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 107/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 107: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 108/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 108: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 109/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 109: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 110/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 110: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 111/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 111: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 112/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 112: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 113/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 113: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 114/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 114: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 115/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 115: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 116/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 116: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 117/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 117: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 118/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 118: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 119/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 119: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 120/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 120: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 121/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 121: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 122/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 122: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 123/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 123: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 124/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 124: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 125/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 125: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 126/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 126: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 127/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 127: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 128/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 128: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 129/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 129: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 130/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 130: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 131/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 131: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 132/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 132: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 133/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 133: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 134/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 134: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 135/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 135: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 136/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 136: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 137/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 137: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 138/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 138: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 139/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 139: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 140/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 140: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 141/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 141: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 142/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 142: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 143/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 143: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 144/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 144: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 145/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 145: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 146/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 146: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 147/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 147: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 148/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 148: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 149/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 149: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 150/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 150: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 151/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 151: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 152/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 152: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 153/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 153: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 154/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 154: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 155/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 155: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 156/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 156: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 157/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 157: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 158/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6666 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 158: loss did not improve from 10.89887
# ...
# Epoch 4948/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4948: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4949/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4949: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4950/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4950: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4951/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4951: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4952/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4952: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4953/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4953: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4954/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4954: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4955/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4955: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4956/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4956: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4957/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4957: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4958/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4958: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4959/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4959: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4960/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4960: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4961/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4961: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4962/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4962: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4963/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4963: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4964/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4964: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4965/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4965: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4966/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4966: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4967/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4967: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4968/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4968: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4969/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4969: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4970/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4970: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4971/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4971: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4972/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4972: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4973/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4973: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4974/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4974: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4975/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4975: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4976/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4976: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4977/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4977: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4978/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4978: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4979/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4979: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4980/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4980: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4981/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4981: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4982/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4982: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4983/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4983: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4984/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4984: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4985/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4985: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4986/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4986: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4987/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4987: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4988/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4988: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4989/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4989: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4990/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4990: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4991/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4991: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4992/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4992: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4993/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4993: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4994/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4994: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4995/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4995: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4996/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4996: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4997/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4997: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4998/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4998: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4999/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 4999: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 5000/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345
# Epoch 5000: loss did not improve from 10.89887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - DE: 0.6667 - E: 10.0000 - I: 0.0333 - mse_odd_even_sol: 0.6684 - loss: 10.9345

# %%
loss_true=np.array(history.history['mse_odd_even_sol'])
physics_loss=np.array(history.history['loss'])
x=np.linspace(0,1,n_train)
print(np.shape(loss_true),np.shape(physics_loss))
#print(eigen_value)
print(loss_true)
# Out:
# (5000,) (5000,)
# [0.92916101 0.72151643 0.67593569 ... 0.66844893 0.66844887 0.66844887]

# %%
plt.plot(loss_true,label='loss')
plt.plot(physics_loss,label='physics_loss')
plt.plot(history.history['I'],label= 'norm')
plt.yscale("log")
plt.legend()
plt.show()

# %%
#model=keras.models.clone_model(name)
#set_weights(get_weights())
n_points=1000
x=np.linspace(-2,2,n_train)
y_train = np.sqrt(2/1.0)*np.sin(np.pi*x/1.0)
y_NN=model.predict(x)
y_NN=np.reshape(y_NN,n_train)
factor=x-x**2
y=y_NN*factor
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
plt.plot(x,y,label='y_predict')
plt.plot(x,-y_train,label='y_true')
plt.xlabel('x')
plt.legend()

# %% [markdown]
# PRIMER EXCITADO

# %%
# Tensorflow Keras and rest of the packages
import tensorflow as tf
import keras as keras
from tensorflow.keras import models,Model
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def nn_model(activation,neurons_layer,n_layers):
    input=Input(shape=(neurons_layer[0],))
    x=input
    for hidden_layer_neurons in neurons_layer[1:-1]: 
        x=Dense(hidden_layer_neurons,activation=activation)(x)
    output=Dense(neurons_layer[n_layers-1],activation)(x)
    return input,output

# %%
@keras.saving.register_keras_serializable()#Esto hace que se pueda guardar el modelo y cargarlo sin problemas despues
class EVE_PINN(tf.keras.Model):# Esta clase va a heredar de la clase Model de Keras, lo que nos permite usar todos los metodos de la clase Model y ademas definir nuestros propios metodos
    def set_step_dx(self,dx): #Este metodo inicializa la clase
      self.dx=dx #Lo que hace esto es que al objeto que luego instanciamos le asigna el atributo dx, que va a ser espaciado entre puntos

    def fi_0(self,fi_0):
        self.fi_0=fi_0
    def train_step(self, data):#Metodo que tiene internamente la clase Model del API de Keras
        x, y_exact = data

        # Use only for run_eagerly=True
        pi = tf.constant(np.pi)
        M0 = tf.square(pi)

        #Change initial conditions for the PINN
        x0 = tf.constant([0.0], dtype=tf.float32)
        xL = tf.constant([1.0], dtype=tf.float32) # We consider L=1
        y0_exact = tf.constant([0.0], dtype=tf.float32)
        yL_exact = tf.constant([0.0], dtype=tf.float32)
        xi = tf.reshape(x,(x.shape[0],1))#Reconversion del batch de entrada a un vector columna, ya que x.shape[0] nos da el numero de elementos que tiene el array de los datos de entrada
        unit = tf.constant(1.0, dtype=tf.float32)
        unit = tf.reshape(unit,shape=xi[0].shape)#Define un tensor de un elemento, que es el uno, ya que xi[0] tiene un shape que es (1,)

        # loss set to zero
        lossDE = tf.constant(0.0, dtype=tf.float32)

        #Set the fundamental_state to a tensor dtype
        fi_0=tf.reshape(self.fi_0,(shape(self.fi_0)))

        # Averaged eigenvalue
        M = tf.constant(0.0, dtype=tf.float32)

        # Spatial mesh
        dx = tf.constant(self.dx,dtype=tf.float32)

        with tf.GradientTape() as tape:

            # Calculate the second derivative dy2/dx2
            with tf.GradientTape() as tape1:
                tape1.watch(xi)
                with tf.GradientTape() as tape2:
                    tape2.watch(xi)#Watch le dice en que tensor se tiene que fijar para los calculos, aqui le decimos que mire el batch de entrada porque luego lo utilizamos para calcular la salida, esto es asi porque tape solo se fija en tensores variables y xi es constante 
                    y_NN = xi*(unit-xi)*self(xi,training=False)#Self es el objeto, al ponerlo asi, busca el metodo call, que esta definido en la clase padre#Cálculo de la y_NN para todos los datos, self(xi) hace el paso hacia delante del batch de entrada, y multplicamos por x*(1-x) para asegurar que la salida cumple las condiciones de contorno. Training=false porque esto solo sirve para calcular la funcion de perdida, es decir, estamos haciendo un predict de los datos xi de entrada
                    print(y_NN.shape)#Esto devolvera cual es el tamaño de la salida, que sera de otro vector columna, cada elemento la salida de cada dato de entrada del batch
                    tape2.watch(y_NN)#Ahora que esta calculada la salida, nos fijamos en el tensor de salida, de forma que ya podremos hacer la derivada
                dy_dx_NN = tape2.gradient(y_NN, xi)#Calcula la derivada de la salida respecto a la entrada, nos devolvera otro vector
                tape1.watch(y_NN)#De nuevo, se tiene que fijar
                tape1.watch(dy_dx_NN)#...
            d2y_dx2_NN = tf.squeeze(tape1.gradient(dy_dx_NN, xi))#Segunda derivada
            y_NN = tf.squeeze(y_NN)#Squeeze elimina las dimensiones de tamaño a 1 en los tensores, osea si tenemos un vector que seria un tensor de shape(y,1) al hacer squeeze pasa a ser solo de shape(y,)
            tape.watch(xi)
            tape.watch(y_NN)
            tape.watch(dy_dx_NN)
            tape.watch(d2y_dx2_NN)

            num = tf.reduce_sum(tf.math.multiply(y_NN,-d2y_dx2_NN))#Esto es el producto escalar de y con la segunda derivada de y, no se multiplica por dx porque se va a ir luego al ser un cociente num/den
            den = tf.reduce_sum(tf.math.pow(y_NN,2)) # Could this be zero? #Norma al cuadrado de y
            M = num/den #Funcion de perdida, que intentamos que cuando sea minima coincida con el autoestado fundamental
            M = tf.reshape(M,shape=xi[0].shape)#Reconvertimos en tensor de tamaño 0 porque era un esacalar, a un tensor de tamaño, que solo tiene un elemento que es el escalar.

            I = tf.constant(0.0, dtype=tf.float32)
            I = tf.math.reduce_sum(tf.math.pow(y_NN,2))
            I = tf.multiply(I,dx)
            I = tf.reshape(I,shape=xi[0].shape)#Se van creando copias de I hasta que llegamos al tensor que es ahora si la morma al cuadrado multiplicada por el factor dx de discretizacion, tambien es de dimension 1con el reshape

            big = tf.constant(1.0, dtype=tf.float32)
            big = tf.reshape(big,shape=xi[0].shape)#Se crea un tensor con todos 1 de una dimension, osea un uno
            
            H=tf.constant(100000000000000.0,dtype=tf.float32)
            num_1=H*(tf.reduce_sum(y_NN*fi_0))**2
            den_1=tf.reduce_sum(tf.math.pow(y_NN,2))*tf.reduce_sum(fi_0**2)
            Schwartz=tf.reshape(num_1/den,_1,shape=xi[0].shape)

            #Loss= ODE+ boundary/initial conditions
            lossDE = self.compiled_loss(d2y_dx2_NN, -M*y_NN) #Esta loss lo que tiene interesante es que self.compiled_loss va a recibir como primer argumento el valor real bueno, y como segundo al valor predicho. Luego, cuando llamamos al metodo compile y le pasamos que tipo de metrica queremos, hara cuentas con ello
            loss = tf.reduce_mean(M + big*self.compiled_loss(I,unit)+Schwartz)# Esta loss es el autovalor mas la condicion de normalizacion mas el termino de Schwart, esta es con la que entrenamos

        gradients = tape.gradient(loss, self.trainable_weights)#Calcula la derivada de la funcion de perdida respecto a los parametros entrenables
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))#Zip empareja cada derivada de la lista gradientes con el parametro respecto al que se ha derivad0, de forma que le pasamos este tensor al optimizador que aplicara los gradientes y actualiza los parametros
        self.compiled_metrics.update_state(y_exact, y_NN)#Por ultimo, se actualiza el estado respecto al paso anterior con la y_NN calculada en este nuevo paso con los parametros anteriores
        metrics = {m.name: m.result() for m in self.metrics}#Dado que entiendo que el metodo self.compiled_metrics.updatestate actualiza las metricas como atributo del objeto en self.metrics. {} Crea un diccionario, en el que el formato_:_ indica clave:valor asociado 
        metrics['DE']=lossDE
        metrics['loss']=loss
        metrics['I']=I
        metrics['E']=M
        return metrics#Este diccionario creado que devuelve el metodo traning_step es el que utiliza model.fit para calcular las metricas
